# %% [markdown]
# <a href="https://colab.research.google.com/github/zniihgnexy/DL_code/blob/main/02_CNN_Introduction_xinyi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Convolutional Neural Networks
#
# This tutorial addresses the basic concepts regarding Convolutional Neural Networks and their implementation using the Keras framework.
# Convolutional Neural Networks (CNNs) are a class of feed-forward artificial neural architecture. They are applied to analyse visual 2D imagery, meaning that we can feed images directly into a CNN without the need to flatten them into a 1D vector as done in the previous tutorial.
# CNNs have revolutionised the field of computer vision in the last decade. In 2012 Alex Krizhevsky introduced the AlexNet architecture to win the ImageNet Challenge (one of the most important competitions on image classification within the Computer Vision community), by reducing the top-5 error more than 10 percentage points, which was an incredible improvement at that time. As of now, CNNs are used not only on image classification but in many other computer vision tasks.
#
# ![](https://cdn-5f733ed3c1ac190fbc56ef88.closte.com/wp-content/uploads/2017/03/alexnet_small-1.png)
#
# The image above is from [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/) and shows the proposed AlexNet architecture. It is composed of 5 convolutional layers followed by 3 fully connected layers. Nowadays, we can find much deeper and more complex architectures, which outperform AlexNet on the ImageNet Challenge.

# %% [markdown]
# ## CNN Structure
#
# The basic pipeline of common CNNs consists of an image as input and a stack of convolutional layers that extract a feature representation from the input image. The final shape of the image representation is conditioned on the type of problem/task that the architecture is facing. For instance, the output of the last layer in a classification problem is a probability vector. Each dimension of the probability vector represents how likely is that the input image belongs to a specific class. However, the architecture design is up to us, and therefore, we could code a network that outputs a single value for regression problems, or that generates a new image map for semantic segmentation. Now, let's dig in a bit into CNN and introduce some layers that are widely used.

# %% [markdown]
# ### 2D Convolutional Layer
#
# The most common layer in any CNN architecture is the 2D convolutional layer. Convolutional layers are specifically designed to extract features from images or even extract features from previously extracted features. As shown in the following illustration, 2D convolutions apply the same filter to the full image. And therefore, due to its nature, 2D convolutional filters exploit the local information presented in images, making them a powerful tool for image analysis.
#
# ![](https://cdn-images-1.medium.com/max/800/1*Fw-ehcNBR9byHtho-Rxbtw.gif)
#
# Image [source](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1).
#
# The latest deep learning frameworks have made possible the integration of convolutional layers easily on our architectures with only a single line of code. We will address here how 2D convolutions work since full understanding is needed to comprehend how any CNN operates. The following images and some explanations can be further explored on the original [Irhum Shafkat's blog](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1) or in the [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/) book. Both are strongly recommended.
#
# To understand 2D convolutions, we need to define first what a kernel is. Kernels are simply matrices of numbers. The numbers on the kernels are the so-called weights, and the weights on the kernels change as we train the network. Hence, network training aims to optimise the network's parameters (update the kernel weights) such that the cost function is minimised.
#
# The 2D convolution operation takes the network's kernels and "slides" them over the input image (alike to a sliding window) as in the following image from [PyImageSearch](https://www.pyimagesearch.com/2015/03/23/sliding-windows-for-object-detection-with-python-and-opencv/) blog:
#
# ![](https://pyimagesearch.com/wp-content/uploads/2014/10/sliding_window_example.gif)
#
# In each step, the network performs an element-wise multiplication with the elements that are currently on. The results of this elementwise multiplication are added to obtain the output value of the operation. CNNs repeat previous step for all the positions of the sliding window, composing at the end the feature map. This generated feature map can go through another 2D convolutional layer and create more powerful features.
#
# >
#
# ![](https://cdn-images-1.medium.com/max/800/1*Zx-ZMLKab7VOCQTxdZ1OAw.gif)
#
# >
# The previous image shows the 2D convolution operation. Thus, the new feature values are the weighted sum of all the elements in the sliding window after the elementwise multiplication between input and kernel.  The bigger the size of the kernel is, the more feature elements contribute to the final output value. In contrast to fully connected layers, where a new feature value is a weighted sum over **all** input values, as mentioned, 2D convolutions compute features based on local areas. In other words, instead of looking at every input component, they consider only features coming from close locations.
#
# In the above example, the input image on the left has a size of 5x5 and the dimension of the resulting feature map is 3x3, showing that the size of the output maps is not always equal to the input. Hence, the output size can be computed by doing:
#
# $O = W - K + 1$,
#
# where $O$ is the output height/length, $W$ is the input height/length and $K$ is the kernel size. The output size is not only conditioned on the input size but also on the kernel size. Check in the following code cell how the output feature map shape changes as you increase the kernel size. In Keras, we define the layer by using `Conv2D` from `keras.layers` (documentation [here](https://keras.io/layers/convolutional/#conv2d)).

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1)))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# Input size: (100, 100)
# Output size: (98, 98)

# %% [markdown]
# Moreover, the kernel size and the input size are not the only parameters affecting the output size. We are going to introduce two extra elements that change the size of the output map: the padding and the stride.

# %% [markdown]
# ### Adding Padding to Input Features
#
# In some tasks, such as [image translation](https://arxiv.org/pdf/1611.07004.pdf), we need the output size to be equal to the input size. The solution to that is using padding, where extra edges are added to the input features so that the dimension is not reduced after the convolutional layer. Normally those pixels have $0$ value (termed zero-padding), but depending on the application other methods could be used, e.g., reflection or symmetric padding.
#
# ![](https://cdn-images-1.medium.com/max/800/1*1okwhewf5KCtIPaFib4XaA.gif)
#
# If padding is used, the new output size can be computed by doing:
#
# $O = W - K + 2P+ 1$,
#
# where $P$ is the padding value. $P$ must be set in concordance with the kernel size if dimensionality wants to be preserved. Padding can be added to the `Conv2d` layer in Keras by using the padding argument and selecting one of the two settings: `valid`, which is the default value and means no padding; and `same`, which adapts the padding value to have the same output size as input size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Input size: (100, 100)
# Output size: (100, 100)

# %% [markdown]
# ### Using Stride in Convolutional Layers
#
# The stride operation allows the convolutional layers to skip some of the sliding windows explained above. Hence, instead of jumping one pixel apart, we can define the number of skipped elements before computing the weighting sum between the kernel's weights and input features. A stride of 1 means that features will be extracted from all windows a pixel apart, so basically, every single window is computed. A stride of 2 means that we are selecting windows 2 pixels apart, skipping every other window in the process. Strides reduce the number of computations and consequently the size of the output map. In practice, as we go deeper into the CNN, the spatial size of the feature map gets smaller while the number of channels increases. Moreover, we can further reduce the size of the feature map using pooling operations, which we introduce later in this tutorial.
#
# ![](https://cdn-images-1.medium.com/max/800/1*BMngs93_rm2_BpJFH2mS0Q.gif)
#
# If strides are used, the new output size can be computed as:
#
# $O = \dfrac{W - K + 2P}{S}+ 1$,
#
# where $S$ is the stride value. The stride is set in the layer by using the `strides` argument.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Input size: (100, 100)
# Output size: (50, 50)

# %% [markdown]
# ## Differences Between Kernel and Filters
#
# The examples above take as input a single-channel image and compute a feature map with also one channel. However, when dealing with RGB images or feature maps, the input is no longer a single-channel map but, instead, they can have multiple channels. In the case of an RGB image, for each 2D convolution, we will need to define 3 kernels to interact with each of the image's channel colours. This group of kernels is called a filter. Thus, a filter is a collection of kernels that produces a single output.
#
# As a regular practice when defining Deep Learning models, we increase the number of filters in each convolutional layer as we go deeper into the model. Due to the element-wise multiplication, the number of kernels on each filter must be the same that the number of channels in the input feature map. Keras already deals with the number of kernels inside each filter. Keras keeps track of the input size in each convolutional layer unlike other frameworks (Pytorch or TensorFlow). Hence, in Keras, we must only decide the number of filters (output channels) in each layer.
#
# The next figure shows how the convolution is performed when having three input channels. First, one filter uses its three independent kernels to convolve with the RGB channels of the input image:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*8dx6nxpUh2JqvYWPadTwMQ.gif)
#
# Next, each of the processed feature maps is added together to obtain a single channel:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*CYB2dyR3EhFs1xNLK8ewiA.gif)
#
# Finally, we add the bias term to obtain the feature map. There is a single bias for the full output channel map. This operation is repeated for all the filters inside the convolutional layer.
#
# Now, we show how to use a `Conv2D` layer that takes an input image with 3 channels and generates an output map with 32 channels.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# ## Activation Functions
#
# As seen in previous tutorials, after a `Dense` layer we usually can find an activation function. We introduce here how to use them after `Conv2D` layers. Those activation functions are a set of operators that maps the feature values to a new set of values, the mapping depends on the function at hand. The main reason for using activation functions is that they add non-linearities to the network, giving more expressive power to the network, which will be able to reproduce more complex functions.
#
#
# The complete list of activation functions that Keras offers can be found [here](https://keras.io/activations/). We introduce here some of them:
#
# *  **Sigmoid Function** sets the output in the range (0, 1). The sigmoid function is widely used in binary classification problems since its output can be taken as a probability value. `keras.activations.sigmoid(x)`:
#
# >![](https://i.ibb.co/Ph8dsTv/sigmoid.png)
#
# *  **Tanh Function** is a logistic function as sigmoid, but the range of the tanh function is (-1, 1). Contrary to sigmoid function, where the values close to 0 are set around 0.5, in the tanh function they will be still mapped around the 0 value. `keras.activations.tanh(x)`:
#
# >![](https://i.ibb.co/68g7LpL/tanh.png)
#
# *  **ReLU Function** is the most common activation function you can find in any current CNN as in general works better than the rest. The range of this function is in \[0, inf). It sets all negative values to 0 and hence is computationally easy to implement. As a drawback, during training some neurons *die*, meaning that the output is 0 for all available data points and no gradient is propagated there. `keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)`:
#
# >![](https://i.ibb.co/Zd9H8Z4/relu.png)
#
# *  **LeakyReLU Function** is a modified version of the ReLU activation above, which attempts to solve the problem of dying neurons that ReLU has. While ReLU does not backpropagate negative values, Leaky ReLU smooths those values without setting them to 0. That allows the gradients to backpropagate through the network even for negative values. `keras.layers.LeakyReLU(alpha=0.3)`:
#
# >![](https://i.ibb.co/dmnJ6h1/leakyrelu.png)
#
# *  **Softmax Function** is another widely activation function for multi-class classification problems and usually is employed as the last activation function in the classification model. This function sets all of the output elements to the range (0, 1). However, the softmax function does not take independently the input values to map it into its probability value. Softmax Function takes an un-normalized vector, $s$, and normalizes it into a probability distribution, $p$, following the softmax expression. As the output is a probability, the output elements add up to 1. `keras.activations.softmax(x, axis=-1)`. Thus, the output value $p_i$ is computed as:
#
# > $p_{i} = \dfrac{e^{s_i}}{\sum_{\substack{j}}^{N} e^{s_j}}$

# %% [markdown]
# The following example shows the feature maps before and after of the ReLU activation function. All values that are negative are set to 0 after the activation function.

# %%
import numpy as np
import keras
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential, Model
from keras.layers import Conv2D, Activation

# Generate dummy data
input_feature = np.random.random((1, 3, 3, 1)) - 0.5

# input: 3x3 image with 1 channel -> (3, 3, 1) tensor.
# This applies a 1 convolution filter of size 3x3 each.
# This applies a ReLU activation function
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(3, 3, 1), padding='same', strides=1, name='conv'))
model.add(Activation('relu'))

model_before_ReLU = Model(inputs=model.input, outputs=model.get_layer('conv').output)

output_feature = model_before_ReLU.predict(input_feature)
output_ReLu_feature = model.predict(input_feature)

print('Output Network without activation function')
print(output_feature)

print('')
print('Output Network after ReLU activation function')
print(output_ReLu_feature)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# Output Network without activation function
# [[[[ 0.40398538]
#    [ 0.01319184]
#    [-0.06418546]]
#
#   [[-0.16383685]
#    [-0.40022048]
#    [-0.00307947]]
#
#   [[-0.60181457]
#    [ 0.14866754]
#    [-0.14245063]]]]
#
# Output Network after ReLU activation function
# [[[[0.40398538]
#    [0.01319184]
#    [0.        ]]
#
#   [[0.        ]
#    [0.        ]
#    [0.        ]]
#
#   [[0.        ]
#    [0.14866754]
#    [0.        ]]]]

# %% [markdown]
# ## Pooling Layer
#
# It is a common practice to insert a pooling layer between convolutional layers in CNNs. In a standard CNN architecture, we set the feature sizes to become smaller progressively to reduce the computation in the networks, and to merge the information from different spatial locations. To reduce the feature map sizes, we can either use bigger stride size in the convolutional layers or we can use pooling layers. Pooling layers perform a spatial sliding window and apply an operation to reduce the spatial size. Those operations vary depending on the architecture, being the max, mean and min pooling the most typical ones. Here, we will explain the max pooling, although all the others work similarly. Max pooling keeps only the max value in a neighbourhood, where the neighbourhood is defined by the size of the kernel. Let's visualise it, the next example shows the result of a Max Pooling layer with a 2x2 kernel and a stride of 2.
#
# ![](https://i.ibb.co/Xp454S4/MaxPool.png)
#
# As in convolutional layers, the final size is conditioned to the stride size of the pooling layer. However, contrary to convolutional layers, pooling layers operate independently on each of the input channels, without modifying the depth of the feature maps. To add max pooling to our model we need to import `MaxPooling2d` from `keras.layers` and define the stride and pooling size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=1 applies applies stride of 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# # Example: Classification on MNIST
#
# As opposed to the *Introduction to Keras* tutorial, in this section, we show how to perform image classification when the input data is a 2D image instead of a flat 1D vector.
#
# As discussed above, Convolutional Neural Networks aim to extract and exploit the local relationships on 2D maps, hence, CNNs are much more convenient for images than Multi-layer Perceptron models.
#
# First of all, we load the MNIST dataset from Keras' framework. The definition of the data is almost identical than in the Keras tutorial, although this time we are not reshaping the input images into a 1D vector.

# %%
# !pip install keras.utils
# Out:
# Requirement already satisfied: keras.utils in /usr/local/lib/python3.10/dist-packages (1.0.13)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras.utils) (2.15.0)

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from tensorflow.python.keras.utils import np_utils
from keras.datasets import mnist
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import numpy as np

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

shape = x_train.shape

# Normalize and reshape the input images
x_train = np.expand_dims(x_train.astype('float32'), -1)
x_test = np.expand_dims(x_test.astype('float32'), -1)

x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))
# Out:
# Image shape: (28, 28, 1)
# Total number of training samples: 60000
# Total number of validation samples: 10000

# %% [markdown]
# As illustrated in the cell, this time the input image before the model is 28x28x1.
#
# Now we can define a model composed of convolutional layers, activation functions, and maxpool operators:

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# As explained in the previous tutorial, in a classification problem, the output of the model is a probability vector. Each dimension of the vector indicates how likely is that the input image belongs to a specific class.
#
# Up to now, the resulting feature map of the model is a map with the shape *Batch x Weight' x Height' x Channel*, and it needs to be mapped into a vector with shape *Batch x Num Classes*. A common technique to process this mapping is to add a Flatten layer that will reshape the feature map to *Batch x (Weight' * Height' * Channel)*. Following the Flatten layer, we add a dense layer which maps this new feature map to the desired output size.

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# %% [markdown]
# Let's visualize the output shape in each layer.

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 28, 28, 16)        160
#
#  activation_9 (Activation)   (None, 28, 28, 16)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 16)        2320
#
#  activation_10 (Activation)  (None, 14, 14, 16)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 7, 7, 16)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_1 (Dense)             (None, 10)                7850
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 10330 (40.35 KB)
# Trainable params: 10330 (40.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Finally, we can train our CNN and check its performance on MNIST.

# %%
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)
# opt = tf.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=10,  verbose=0)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Validation loss: 0.08112094551324844
# Validation accuracy: 0.9739000201225281

# %% [markdown]
# # Coursework

# %% [markdown]
# ## Task 1: Classification
#
# At this point, we know what is a CNN, how they work, and the components needed to design them. In this first task, we want you to create a CNN that is able to outperform the Multi-layer Perceptron model from Tutorial 1. For the first part of the coursework, we train on CIFAR10, a  classical dataset for image classification. Note that in these tutorials, we mainly use the official test sets of several standard datasets as our validation data. The reason we use the given test sets as validation data for the tutorials is that is an easy way to make sure that we all work with the same split and report results using the same data. However, in a proper machine learning setup, your validation set should be separate from the test set, so you can tune the model/parameters on the validation set and then check the final performance in the test set. Thus, even though the variables are `x_test` and `y_test`, they represent our validation set.
#
# Let's first load the dataset and visualise some examples:

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(X_train.shape[1:]))
print('Total number of training samples: {0}'.format(X_train.shape[0]))
print('Total number of validation samples: {0}'.format(X_test.shape[0]))

# Let's visualize some examples
N=5
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
items = list(range(0, 10))
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    axes[row,col].imshow(X_train[idx], cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    y_target = int(y_train[idx])
    target = str(items[y_target])
    axes[row,col].set_title(target)
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000

# %% [markdown]
# CIFAR10 contains 50,000 32x32 color training images, labeled over 10 categories and 10,000 test images. As mentioned, we use those test images as our validation set in this tutorial. We need to preprocess the images for the 1D neural network defined in the previous tutorial:

# %%
# Preprocess dataset for a 1D neural network
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the image
X_train /= 255
X_test /= 255

X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2]*3)
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]*3)

print('New X_train shape: {0}'.format(X_train_flatten.shape))

Y_train_class = np_utils.to_categorical(y_train, 10)
Y_test_class = np_utils.to_categorical(y_test, 10)

print('New Y_train shape: {0}'.format(Y_train_class.shape))
# Out:
# New X_train shape: (50000, 3072)
# New Y_train shape: (50000, 10)

# %% [markdown]
# Now, we are ready to define the Multi-layer Perceptron model and train it.

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(X_train_flatten.shape[1:])))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(X_train_flatten, Y_train_class, batch_size=32, epochs=20)

score = model.evaluate(X_test_flatten, Y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9372 - accuracy: 0.2936
# Epoch 2/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.7503 - accuracy: 0.3682
# Epoch 3/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6762 - accuracy: 0.3974
# Epoch 4/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6218 - accuracy: 0.4176
# Epoch 5/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5815 - accuracy: 0.4342
# Epoch 6/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5505 - accuracy: 0.4463
# Epoch 7/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5239 - accuracy: 0.4540
# Epoch 8/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5002 - accuracy: 0.4631
# Epoch 9/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4785 - accuracy: 0.4694
# Epoch 10/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4586 - accuracy: 0.4768
# Epoch 11/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4418 - accuracy: 0.4826
# Epoch 12/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4253 - accuracy: 0.4908
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4100 - accuracy: 0.4941
# Epoch 14/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3959 - accuracy: 0.5008
# Epoch 15/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3829 - accuracy: 0.5054
# Epoch 16/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3691 - accuracy: 0.5090
# Epoch 17/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3573 - accuracy: 0.5149
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3460 - accuracy: 0.5172
# Epoch 19/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3346 - accuracy: 0.5206
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3237 - accuracy: 0.5268
# Validation loss: 1.4776495695114136
# Validation accuracy: 0.4749000072479248

# %% [markdown]
# ### Problem Definition
#
# In this exercise, you are asked to test several CNN architectures in the code provided below. Do not modify the optimizer, loss used or parameters related to the training such as the learning rate, they will be investigated in future tutorials. You must focus on the architecture itself: number of convolutional layers, number of filters in every layer, activation functions, pooling operators, among others. Batch Normalization and Dropout layers, which are quite used in CNN architectures, will be also investigated in a future tutorial so you do not have to discuss them.
#
#
# **Report**:
# *   Present a bar figure with the training and validation accuracies for different design choices. Discuss only the parameters that have a significant influence on the network's performance. Explain any discrepancy between training and validation accuracies.
# *   Present a sketch that introduces your best architecture. See some examples on how to display networks in [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)


# . . .
model = Sequential()

model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# . . .


# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# Epoch 1/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.0293 - accuracy: 0.2826
# Epoch 2/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7534 - accuracy: 0.3905
# Epoch 3/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6317 - accuracy: 0.4293
# Epoch 4/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5536 - accuracy: 0.4544
# Epoch 5/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4974 - accuracy: 0.4718
# Epoch 6/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4555 - accuracy: 0.4875
# Epoch 7/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4233 - accuracy: 0.4989
# Epoch 8/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3967 - accuracy: 0.5071
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3760 - accuracy: 0.5146
# Epoch 10/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3578 - accuracy: 0.5225
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3413 - accuracy: 0.5273
# Epoch 12/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3262 - accuracy: 0.5342
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3113 - accuracy: 0.5394
# Epoch 14/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2977 - accuracy: 0.5426
# Epoch 15/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2840 - accuracy: 0.5490
# Epoch 16/20
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.2727 - accuracy: 0.5549
# Epoch 17/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2600 - accuracy: 0.5593
# Epoch 18/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2493 - accuracy: 0.5638
# Epoch 19/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2386 - accuracy: 0.5681
# Epoch 20/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2286 - accuracy: 0.5731
# Validation loss: 1.249979019165039
# Validation accuracy: 0.5615000128746033

# %%
print(x_train.size)
print('Input size: ({:}, {:}, {:})'.format(x_train.shape[1], x_train.shape[2], x_train.shape[3]))

print(x_test.size)
print('Input size: ({:}, {:}, {:})'.format(x_test.shape[1], x_test.shape[2], x_test.shape[3]))
# Out:
# 153600000
# Input size: (32, 32, 3)
# 30720000
# Input size: (32, 32, 3)

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples : {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

# . . .

model = Sequential()

#layer 1
model.add(Conv2D(96, (11,11), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

#layer 2
model.add(Conv2D(96, (5,5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

#layer 3
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Activation('relu'))

#layer 4
model.add(Conv2D(256, (3,3), padding='same', strides=1))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# . . .


# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/20
# Exception ignored in: <function _xla_gc_callback at 0x78648c8a2dd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 1563/1563 [==============================] - 41s 7ms/step - loss: 1.7145 - accuracy: 0.3759
# Epoch 2/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3855 - accuracy: 0.5034
# Epoch 3/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.2214 - accuracy: 0.5643
# Epoch 4/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0955 - accuracy: 0.6144
# Epoch 5/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9934 - accuracy: 0.6513
# Epoch 6/20
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9113 - accuracy: 0.6791
# Epoch 7/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8405 - accuracy: 0.7043
# Epoch 8/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7736 - accuracy: 0.7299
# Epoch 9/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7163 - accuracy: 0.7491
# Epoch 10/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6584 - accuracy: 0.7700
# Epoch 11/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6059 - accuracy: 0.7892
# Epoch 12/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5532 - accuracy: 0.8072
# Epoch 13/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5060 - accuracy: 0.8255
# Epoch 14/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4574 - accuracy: 0.8424
# Epoch 15/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4150 - accuracy: 0.8571
# Epoch 16/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3720 - accuracy: 0.8707
# Epoch 17/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3319 - accuracy: 0.8855
# Epoch 18/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2917 - accuracy: 0.8994
# Epoch 19/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2578 - accuracy: 0.9109
# Epoch 20/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2265 - accuracy: 0.9214
# Validation loss: 1.1784065961837769
# Validation accuracy: 0.70660001039505

# %% [markdown]
# ---
# ---
#
# ## Task 2: Regression
#
# Now we face a regression task instead of a classification problem. Loss function, activations, and dataset will change in the following task. Thus, instead of having one vector with the probabilities of each class, in this regression problem, the output is a single scalar.
#
# For this second task, we chose the task of estimating house prices based on input images. To get the data run the following script, which clones Ahmed and Moustafa’s [repository](https://github.com/emanhamed/Houses-dataset) into colmap.

# %%
# !git clone https://github.com/emanhamed/Houses-dataset
# %cd /content/Houses-dataset/Houses\ Dataset
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165
# Receiving objects: 100% (2166/2166), 176.26 MiB | 45.69 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/Houses-dataset/Houses Dataset

# %% [markdown]
# This dataset contains four images of the house (kitchen, frontal, bedroom and bathroom), and attributes (number of bedrooms, number of bathrooms, zip code...). For our exercise, we only use the images of the house. We start with front door images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed

house_section = 'frontal' # select between: kitchen, frontal, bedroom or bathroom
print('We have selected {} images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.'.format(house_section))
images = []
for i_im in range(1, 536):
  image = cv2.imread(str(i_im)+'_'+house_section+'.jpg')
  image = cv2.resize(image, (64, 64))
  images.append(image)

labels = []
f = open('HousesInfo.txt', "r")
for x in f:
  label = (x).split(' ')[-1].split('\n')[0]
  labels.append(label)

# Let's visualize some examples
N=3
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    tmp = cv2.cvtColor(images[idx],cv2.COLOR_BGR2RGB)
    axes[row,col].imshow(tmp, cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    target = int(labels[idx])
    axes[row,col].set_title(str(target) + '$')
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# We have selected frontal images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.

# %% [markdown]
# Prepare the dataset for training the model:

# %%
seed(1234)
images = np.asarray(images).astype('float32')
labels = np.asarray(labels).astype('float32')

# Normalize the image
max_price = labels.max()
images /= 255.
labels /= max_price

random_idx = np.random.permutation(len(images))
images = images[random_idx]
labels = labels[random_idx]

split_size_val = int(0.8*len(images))
X_train, X_val = images[:split_size_val], images[split_size_val+1:]
Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

# Print shape of training and val images
print('X_train image shape: {0}'.format(X_train.shape))
print('X_val image shape: {0}'.format(X_val.shape))

# Print shape of training and val labels
print('Y_train labels shape: {0}'.format(Y_train.shape))
print('Y_val labels shape: {0}'.format(Y_val.shape))
# Out:
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)

# %% [markdown]
# ### Problem Definition
#
# Similar to the previous task, you are asked to design a CNN architecture able to perform the estimation of house prices based on the `frontal` house image. Design a new model by changing parameters such as the number of convolutional layers, activation functions, strides, or pooling operators, among others.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .

model.add(Conv2D(96, (3,3), padding='same', input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('softmax'))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_57"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_79 (Conv2D)          (None, 64, 64, 96)        2688
#
#  activation_78 (Activation)  (None, 64, 64, 96)        0
#
#  max_pooling2d_52 (MaxPooli  (None, 32, 32, 96)        0
#  ng2D)
#
#  conv2d_80 (Conv2D)          (None, 32, 32, 16)        13840
#
#  activation_79 (Activation)  (None, 32, 32, 16)        0
#
#  max_pooling2d_53 (MaxPooli  (None, 16, 16, 16)        0
#  ng2D)
#
#  flatten_15 (Flatten)        (None, 4096)              0
#
#  dense_32 (Dense)            (None, 1)                 4097
#
#  activation_80 (Activation)  (None, 1)                 0
#
#  flatten_16 (Flatten)        (None, 1)                 0
#
#  dense_33 (Dense)            (None, 1)                 2
#
#  activation_81 (Activation)  (None, 1)                 0
#
# =================================================================
# Total params: 20627 (80.57 KB)
# Trainable params: 20627 (80.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 14/14 [==============================] - 1s 44ms/step - loss: 3134.9250 - mean_absolute_percentage_error: 3134.9250 - val_loss: 2663.5247 - val_mean_absolute_percentage_error: 2663.5247
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 3075.1233 - mean_absolute_percentage_error: 3075.1233 - val_loss: 2612.6829 - val_mean_absolute_percentage_error: 2612.6829
# Epoch 3/100
# 14/14 [==============================] - 0s 9ms/step - loss: 3015.5586 - mean_absolute_percentage_error: 3015.5586 - val_loss: 2561.1077 - val_mean_absolute_percentage_error: 2561.1077
# Epoch 4/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2955.7705 - mean_absolute_percentage_error: 2955.7705 - val_loss: 2510.0667 - val_mean_absolute_percentage_error: 2510.0667
# Epoch 5/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2896.2139 - mean_absolute_percentage_error: 2896.2139 - val_loss: 2459.8625 - val_mean_absolute_percentage_error: 2459.8625
# Epoch 6/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2836.8960 - mean_absolute_percentage_error: 2836.8960 - val_loss: 2408.9089 - val_mean_absolute_percentage_error: 2408.9089
# Epoch 7/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2777.5488 - mean_absolute_percentage_error: 2777.5488 - val_loss: 2357.9861 - val_mean_absolute_percentage_error: 2357.9861
# Epoch 8/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2716.9302 - mean_absolute_percentage_error: 2716.9302 - val_loss: 2308.3164 - val_mean_absolute_percentage_error: 2308.3164
# Epoch 9/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2658.0686 - mean_absolute_percentage_error: 2658.0686 - val_loss: 2255.7866 - val_mean_absolute_percentage_error: 2255.7866
# Epoch 10/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2597.3506 - mean_absolute_percentage_error: 2597.3506 - val_loss: 2205.6465 - val_mean_absolute_percentage_error: 2205.6465
# Epoch 11/100
# 14/14 [==============================] - 0s 15ms/step - loss: 2539.6538 - mean_absolute_percentage_error: 2539.6538 - val_loss: 2154.6624 - val_mean_absolute_percentage_error: 2154.6624
# Epoch 12/100
# 14/14 [==============================] - 0s 12ms/step - loss: 2479.2661 - mean_absolute_percentage_error: 2479.2661 - val_loss: 2105.1003 - val_mean_absolute_percentage_error: 2105.1003
# Epoch 13/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2420.0564 - mean_absolute_percentage_error: 2420.0564 - val_loss: 2052.8281 - val_mean_absolute_percentage_error: 2052.8281
# Epoch 14/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2360.1003 - mean_absolute_percentage_error: 2360.1003 - val_loss: 2001.9199 - val_mean_absolute_percentage_error: 2001.9199
# Epoch 15/100
# 14/14 [==============================] - 0s 12ms/step - loss: 2301.4836 - mean_absolute_percentage_error: 2301.4836 - val_loss: 1951.8928 - val_mean_absolute_percentage_error: 1951.8928
# Epoch 16/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2242.8813 - mean_absolute_percentage_error: 2242.8813 - val_loss: 1902.1748 - val_mean_absolute_percentage_error: 1902.1748
# Epoch 17/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2183.7427 - mean_absolute_percentage_error: 2183.7427 - val_loss: 1851.6927 - val_mean_absolute_percentage_error: 1851.6927
# Epoch 18/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2125.6536 - mean_absolute_percentage_error: 2125.6536 - val_loss: 1801.3523 - val_mean_absolute_percentage_error: 1801.3523
# Epoch 19/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2067.4045 - mean_absolute_percentage_error: 2067.4045 - val_loss: 1751.2666 - val_mean_absolute_percentage_error: 1751.2666
# Epoch 20/100
# 14/14 [==============================] - 0s 11ms/step - loss: 2008.9626 - mean_absolute_percentage_error: 2008.9626 - val_loss: 1701.6562 - val_mean_absolute_percentage_error: 1701.6562
# Epoch 21/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1949.8313 - mean_absolute_percentage_error: 1949.8313 - val_loss: 1652.7526 - val_mean_absolute_percentage_error: 1652.7526
# Epoch 22/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1892.6802 - mean_absolute_percentage_error: 1892.6802 - val_loss: 1602.5963 - val_mean_absolute_percentage_error: 1602.5963
# Epoch 23/100
# 14/14 [==============================] - 0s 11ms/step - loss: 1833.5206 - mean_absolute_percentage_error: 1833.5206 - val_loss: 1552.3748 - val_mean_absolute_percentage_error: 1552.3748
# Epoch 24/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1775.2113 - mean_absolute_percentage_error: 1775.2113 - val_loss: 1502.2344 - val_mean_absolute_percentage_error: 1502.2344
# Epoch 25/100
# 14/14 [==============================] - 0s 11ms/step - loss: 1715.3137 - mean_absolute_percentage_error: 1715.3137 - val_loss: 1453.4785 - val_mean_absolute_percentage_error: 1453.4785
# Epoch 26/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1657.5702 - mean_absolute_percentage_error: 1657.5702 - val_loss: 1401.8927 - val_mean_absolute_percentage_error: 1401.8927
# Epoch 27/100
# 14/14 [==============================] - 0s 11ms/step - loss: 1598.0717 - mean_absolute_percentage_error: 1598.0717 - val_loss: 1349.8154 - val_mean_absolute_percentage_error: 1349.8154
# Epoch 28/100
# 14/14 [==============================] - 0s 12ms/step - loss: 1537.6027 - mean_absolute_percentage_error: 1537.6027 - val_loss: 1299.1433 - val_mean_absolute_percentage_error: 1299.1433
# Epoch 29/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1478.2981 - mean_absolute_percentage_error: 1478.2981 - val_loss: 1248.6202 - val_mean_absolute_percentage_error: 1248.6202
# Epoch 30/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1418.2894 - mean_absolute_percentage_error: 1418.2894 - val_loss: 1197.7421 - val_mean_absolute_percentage_error: 1197.7421
# Epoch 31/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1358.7933 - mean_absolute_percentage_error: 1358.7933 - val_loss: 1146.3163 - val_mean_absolute_percentage_error: 1146.3163
# Epoch 32/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1298.8080 - mean_absolute_percentage_error: 1298.8080 - val_loss: 1096.2480 - val_mean_absolute_percentage_error: 1096.2480
# Epoch 33/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1240.4987 - mean_absolute_percentage_error: 1240.4987 - val_loss: 1045.2966 - val_mean_absolute_percentage_error: 1045.2966
# Epoch 34/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1180.8149 - mean_absolute_percentage_error: 1180.8149 - val_loss: 995.8669 - val_mean_absolute_percentage_error: 995.8669
# Epoch 35/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1121.9064 - mean_absolute_percentage_error: 1121.9064 - val_loss: 943.8646 - val_mean_absolute_percentage_error: 943.8646
# Epoch 36/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1061.9657 - mean_absolute_percentage_error: 1061.9657 - val_loss: 893.1423 - val_mean_absolute_percentage_error: 893.1423
# Epoch 37/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1002.2236 - mean_absolute_percentage_error: 1002.2236 - val_loss: 843.2457 - val_mean_absolute_percentage_error: 843.2457
# Epoch 38/100
# 14/14 [==============================] - 0s 10ms/step - loss: 943.4385 - mean_absolute_percentage_error: 943.4385 - val_loss: 792.6938 - val_mean_absolute_percentage_error: 792.6938
# Epoch 39/100
# 14/14 [==============================] - 0s 9ms/step - loss: 884.7266 - mean_absolute_percentage_error: 884.7266 - val_loss: 742.0018 - val_mean_absolute_percentage_error: 742.0018
# Epoch 40/100
# 14/14 [==============================] - 0s 10ms/step - loss: 824.1874 - mean_absolute_percentage_error: 824.1874 - val_loss: 693.5182 - val_mean_absolute_percentage_error: 693.5182
# Epoch 41/100
# 14/14 [==============================] - 0s 9ms/step - loss: 767.9413 - mean_absolute_percentage_error: 767.9413 - val_loss: 639.4740 - val_mean_absolute_percentage_error: 639.4740
# Epoch 42/100
# 14/14 [==============================] - 0s 9ms/step - loss: 705.8459 - mean_absolute_percentage_error: 705.8459 - val_loss: 590.2345 - val_mean_absolute_percentage_error: 590.2345
# Epoch 43/100
# 14/14 [==============================] - 0s 9ms/step - loss: 648.1283 - mean_absolute_percentage_error: 648.1283 - val_loss: 540.3237 - val_mean_absolute_percentage_error: 540.3237
# Epoch 44/100
# 14/14 [==============================] - 0s 10ms/step - loss: 589.7145 - mean_absolute_percentage_error: 589.7145 - val_loss: 491.1456 - val_mean_absolute_percentage_error: 491.1456
# Epoch 45/100
# 14/14 [==============================] - 0s 9ms/step - loss: 532.0135 - mean_absolute_percentage_error: 532.0135 - val_loss: 439.6364 - val_mean_absolute_percentage_error: 439.6364
# Epoch 46/100
# 14/14 [==============================] - 0s 9ms/step - loss: 471.5436 - mean_absolute_percentage_error: 471.5436 - val_loss: 389.5513 - val_mean_absolute_percentage_error: 389.5513
# Epoch 47/100
# 14/14 [==============================] - 0s 9ms/step - loss: 412.0380 - mean_absolute_percentage_error: 412.0380 - val_loss: 339.3729 - val_mean_absolute_percentage_error: 339.3729
# Epoch 48/100
# 14/14 [==============================] - 0s 9ms/step - loss: 353.0657 - mean_absolute_percentage_error: 353.0657 - val_loss: 288.5375 - val_mean_absolute_percentage_error: 288.5375
# Epoch 49/100
# 14/14 [==============================] - 0s 10ms/step - loss: 293.4221 - mean_absolute_percentage_error: 293.4221 - val_loss: 238.5086 - val_mean_absolute_percentage_error: 238.5086
# Epoch 50/100
# 14/14 [==============================] - 0s 9ms/step - loss: 234.3294 - mean_absolute_percentage_error: 234.3294 - val_loss: 187.0440 - val_mean_absolute_percentage_error: 187.0440
# Epoch 51/100
# 14/14 [==============================] - 0s 9ms/step - loss: 175.8252 - mean_absolute_percentage_error: 175.8252 - val_loss: 136.3197 - val_mean_absolute_percentage_error: 136.3197
# Epoch 52/100
# 14/14 [==============================] - 0s 9ms/step - loss: 116.7855 - mean_absolute_percentage_error: 116.7855 - val_loss: 85.2454 - val_mean_absolute_percentage_error: 85.2454
# Epoch 53/100
# 14/14 [==============================] - 0s 9ms/step - loss: 75.0618 - mean_absolute_percentage_error: 75.0618 - val_loss: 66.6782 - val_mean_absolute_percentage_error: 66.6782
# Epoch 54/100
# 14/14 [==============================] - 0s 9ms/step - loss: 71.1555 - mean_absolute_percentage_error: 71.1555 - val_loss: 65.6996 - val_mean_absolute_percentage_error: 65.6996
# Epoch 55/100
# 14/14 [==============================] - 0s 9ms/step - loss: 71.1100 - mean_absolute_percentage_error: 71.1100 - val_loss: 66.6964 - val_mean_absolute_percentage_error: 66.6964
# Epoch 56/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4904 - mean_absolute_percentage_error: 70.4904 - val_loss: 68.2489 - val_mean_absolute_percentage_error: 68.2489
# Epoch 57/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3370 - mean_absolute_percentage_error: 70.3370 - val_loss: 69.2791 - val_mean_absolute_percentage_error: 69.2791
# Epoch 58/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2532 - mean_absolute_percentage_error: 70.2532 - val_loss: 69.2657 - val_mean_absolute_percentage_error: 69.2657
# Epoch 59/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2620 - mean_absolute_percentage_error: 70.2620 - val_loss: 69.3196 - val_mean_absolute_percentage_error: 69.3196
# Epoch 60/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2220 - mean_absolute_percentage_error: 70.2220 - val_loss: 69.3336 - val_mean_absolute_percentage_error: 69.3336
# Epoch 61/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2268 - mean_absolute_percentage_error: 70.2268 - val_loss: 69.0123 - val_mean_absolute_percentage_error: 69.0123
# Epoch 62/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2617 - mean_absolute_percentage_error: 70.2617 - val_loss: 69.6171 - val_mean_absolute_percentage_error: 69.6171
# Epoch 63/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2441 - mean_absolute_percentage_error: 70.2441 - val_loss: 69.2252 - val_mean_absolute_percentage_error: 69.2252
# Epoch 64/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2312 - mean_absolute_percentage_error: 70.2312 - val_loss: 69.4261 - val_mean_absolute_percentage_error: 69.4261
# Epoch 65/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2198 - mean_absolute_percentage_error: 70.2198 - val_loss: 68.8659 - val_mean_absolute_percentage_error: 68.8659
# Epoch 66/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2801 - mean_absolute_percentage_error: 70.2801 - val_loss: 68.6019 - val_mean_absolute_percentage_error: 68.6019
# Epoch 67/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2499 - mean_absolute_percentage_error: 70.2499 - val_loss: 69.5954 - val_mean_absolute_percentage_error: 69.5954
# Epoch 68/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2636 - mean_absolute_percentage_error: 70.2636 - val_loss: 69.9290 - val_mean_absolute_percentage_error: 69.9290
# Epoch 69/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3137 - mean_absolute_percentage_error: 70.3137 - val_loss: 69.9741 - val_mean_absolute_percentage_error: 69.9741
# Epoch 70/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4542 - mean_absolute_percentage_error: 70.4542 - val_loss: 70.4815 - val_mean_absolute_percentage_error: 70.4815
# Epoch 71/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3473 - mean_absolute_percentage_error: 70.3473 - val_loss: 70.2266 - val_mean_absolute_percentage_error: 70.2266
# Epoch 72/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2214 - mean_absolute_percentage_error: 70.2214 - val_loss: 69.4056 - val_mean_absolute_percentage_error: 69.4056
# Epoch 73/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3350 - mean_absolute_percentage_error: 70.3350 - val_loss: 68.3980 - val_mean_absolute_percentage_error: 68.3980
# Epoch 74/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3743 - mean_absolute_percentage_error: 70.3743 - val_loss: 69.0011 - val_mean_absolute_percentage_error: 69.0011
# Epoch 75/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2827 - mean_absolute_percentage_error: 70.2827 - val_loss: 69.3459 - val_mean_absolute_percentage_error: 69.3459
# Epoch 76/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.5138 - mean_absolute_percentage_error: 70.5138 - val_loss: 68.2616 - val_mean_absolute_percentage_error: 68.2616
# Epoch 77/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3260 - mean_absolute_percentage_error: 70.3260 - val_loss: 69.4029 - val_mean_absolute_percentage_error: 69.4029
# Epoch 78/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3815 - mean_absolute_percentage_error: 70.3815 - val_loss: 69.0612 - val_mean_absolute_percentage_error: 69.0612
# Epoch 79/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3316 - mean_absolute_percentage_error: 70.3316 - val_loss: 69.6324 - val_mean_absolute_percentage_error: 69.6324
# Epoch 80/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2385 - mean_absolute_percentage_error: 70.2385 - val_loss: 69.7092 - val_mean_absolute_percentage_error: 69.7092
# Epoch 81/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2781 - mean_absolute_percentage_error: 70.2781 - val_loss: 69.7803 - val_mean_absolute_percentage_error: 69.7803
# Epoch 82/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3310 - mean_absolute_percentage_error: 70.3310 - val_loss: 69.4392 - val_mean_absolute_percentage_error: 69.4392
# Epoch 83/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2282 - mean_absolute_percentage_error: 70.2282 - val_loss: 69.1304 - val_mean_absolute_percentage_error: 69.1304
# Epoch 84/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2883 - mean_absolute_percentage_error: 70.2883 - val_loss: 68.9098 - val_mean_absolute_percentage_error: 68.9098
# Epoch 85/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2423 - mean_absolute_percentage_error: 70.2423 - val_loss: 69.0189 - val_mean_absolute_percentage_error: 69.0189
# Epoch 86/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2364 - mean_absolute_percentage_error: 70.2364 - val_loss: 69.0871 - val_mean_absolute_percentage_error: 69.0871
# Epoch 87/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2693 - mean_absolute_percentage_error: 70.2693 - val_loss: 68.8469 - val_mean_absolute_percentage_error: 68.8469
# Epoch 88/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2532 - mean_absolute_percentage_error: 70.2532 - val_loss: 69.2770 - val_mean_absolute_percentage_error: 69.2770
# Epoch 89/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3830 - mean_absolute_percentage_error: 70.3830 - val_loss: 70.0991 - val_mean_absolute_percentage_error: 70.0991
# Epoch 90/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.6857 - mean_absolute_percentage_error: 70.6857 - val_loss: 68.1847 - val_mean_absolute_percentage_error: 68.1847
# Epoch 91/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2355 - mean_absolute_percentage_error: 70.2355 - val_loss: 69.6380 - val_mean_absolute_percentage_error: 69.6380
# Epoch 92/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4519 - mean_absolute_percentage_error: 70.4519 - val_loss: 70.1439 - val_mean_absolute_percentage_error: 70.1439
# Epoch 93/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2481 - mean_absolute_percentage_error: 70.2481 - val_loss: 68.1743 - val_mean_absolute_percentage_error: 68.1743
# Epoch 94/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4477 - mean_absolute_percentage_error: 70.4477 - val_loss: 68.1156 - val_mean_absolute_percentage_error: 68.1156
# Epoch 95/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.1663 - mean_absolute_percentage_error: 70.1663 - val_loss: 70.5187 - val_mean_absolute_percentage_error: 70.5187
# Epoch 96/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4266 - mean_absolute_percentage_error: 70.4266 - val_loss: 70.4171 - val_mean_absolute_percentage_error: 70.4171
# Epoch 97/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4820 - mean_absolute_percentage_error: 70.4820 - val_loss: 68.8595 - val_mean_absolute_percentage_error: 68.8595
# Epoch 98/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2106 - mean_absolute_percentage_error: 70.2106 - val_loss: 69.5805 - val_mean_absolute_percentage_error: 69.5805
# Epoch 99/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2843 - mean_absolute_percentage_error: 70.2843 - val_loss: 69.4916 - val_mean_absolute_percentage_error: 69.4916
# Epoch 100/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2302 - mean_absolute_percentage_error: 70.2302 - val_loss: 69.2444 - val_mean_absolute_percentage_error: 69.2444

# %% [markdown]
# The metric used in this problem to evaluate the performance is the same we used for training the model, the mean absolute percentage error. Mean absolute percentage error is defined as $\frac{100}{n} \sum_n \frac{|\hat{y} - y|}{|y|}$ where $y$ is the ground-truth, $\hat{y}$ is the estimation of the model and `n` the number of elements in the set we are evaluating.

# %%
prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 69.24%

# %% [markdown]
# **Report**:
#
#
# *   Propose a CNN architecture that has an estimation error in the validation set below 75%.
# *   Present a figure showing the training and validation loss vs the number of training epochs for different architectural design choices. Discuss the gap between the training and validation loss depending on the proposed architecture.
# *   Report a table with results when using any of the other images from the house (kitchen, bedroom, and bathroom).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
model.add(Conv2D(32, (3,3), padding='same', input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(650))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(784))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_63"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_100 (Conv2D)         (None, 64, 64, 32)        896
#
#  activation_114 (Activation  (None, 64, 64, 32)        0
#  )
#
#  max_pooling2d_73 (MaxPooli  (None, 32, 32, 32)        0
#  ng2D)
#
#  conv2d_101 (Conv2D)         (None, 32, 32, 64)        18496
#
#  activation_115 (Activation  (None, 32, 32, 64)        0
#  )
#
#  max_pooling2d_74 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  conv2d_102 (Conv2D)         (None, 16, 16, 128)       73856
#
#  activation_116 (Activation  (None, 16, 16, 128)       0
#  )
#
#  max_pooling2d_75 (MaxPooli  (None, 8, 8, 128)         0
#  ng2D)
#
#  flatten_27 (Flatten)        (None, 8192)              0
#
#  dense_47 (Dense)            (None, 650)               5325450
#
#  activation_117 (Activation  (None, 650)               0
#  )
#
#  dropout_3 (Dropout)         (None, 650)               0
#
#  dense_48 (Dense)            (None, 784)               510384
#
#  activation_118 (Activation  (None, 784)               0
#  )
#
#  flatten_28 (Flatten)        (None, 784)               0
#
#  dense_49 (Dense)            (None, 1)                 785
#
#  activation_119 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 5929867 (22.62 MB)
# Trainable params: 5929867 (22.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 25ms/step - loss: 599.6655 - mean_absolute_percentage_error: 599.6655 - val_loss: 68.5817 - val_mean_absolute_percentage_error: 68.5817
# Epoch 2/100
# 14/14 [==============================] - 0s 11ms/step - loss: 68.9819 - mean_absolute_percentage_error: 68.9819 - val_loss: 75.3574 - val_mean_absolute_percentage_error: 75.3574
# Epoch 3/100
# 14/14 [==============================] - 0s 11ms/step - loss: 71.2744 - mean_absolute_percentage_error: 71.2744 - val_loss: 63.0477 - val_mean_absolute_percentage_error: 63.0477
# Epoch 4/100
# 14/14 [==============================] - 0s 11ms/step - loss: 66.3972 - mean_absolute_percentage_error: 66.3972 - val_loss: 74.3760 - val_mean_absolute_percentage_error: 74.3760
# Epoch 5/100
# 14/14 [==============================] - 0s 10ms/step - loss: 66.0700 - mean_absolute_percentage_error: 66.0700 - val_loss: 59.5841 - val_mean_absolute_percentage_error: 59.5841
# Epoch 6/100
# 14/14 [==============================] - 0s 10ms/step - loss: 60.1728 - mean_absolute_percentage_error: 60.1728 - val_loss: 64.7190 - val_mean_absolute_percentage_error: 64.7190
# Epoch 7/100
# 14/14 [==============================] - 0s 10ms/step - loss: 63.5738 - mean_absolute_percentage_error: 63.5738 - val_loss: 66.8945 - val_mean_absolute_percentage_error: 66.8945
# Epoch 8/100
# 14/14 [==============================] - 0s 10ms/step - loss: 68.5309 - mean_absolute_percentage_error: 68.5309 - val_loss: 69.4877 - val_mean_absolute_percentage_error: 69.4877
# Epoch 9/100
# 14/14 [==============================] - 0s 9ms/step - loss: 63.8436 - mean_absolute_percentage_error: 63.8436 - val_loss: 64.9844 - val_mean_absolute_percentage_error: 64.9844
# Epoch 10/100
# 14/14 [==============================] - 0s 9ms/step - loss: 62.0720 - mean_absolute_percentage_error: 62.0720 - val_loss: 57.5210 - val_mean_absolute_percentage_error: 57.5210
# Epoch 11/100
# 14/14 [==============================] - 0s 11ms/step - loss: 60.6122 - mean_absolute_percentage_error: 60.6122 - val_loss: 56.2415 - val_mean_absolute_percentage_error: 56.2415
# Epoch 12/100
# 14/14 [==============================] - 0s 19ms/step - loss: 57.8586 - mean_absolute_percentage_error: 57.8586 - val_loss: 60.8867 - val_mean_absolute_percentage_error: 60.8867
# Epoch 13/100
# 14/14 [==============================] - 0s 25ms/step - loss: 56.6526 - mean_absolute_percentage_error: 56.6526 - val_loss: 54.7830 - val_mean_absolute_percentage_error: 54.7830
# Epoch 14/100
# 14/14 [==============================] - 0s 27ms/step - loss: 54.4055 - mean_absolute_percentage_error: 54.4055 - val_loss: 57.6693 - val_mean_absolute_percentage_error: 57.6693
# Epoch 15/100
# 14/14 [==============================] - 0s 24ms/step - loss: 50.8845 - mean_absolute_percentage_error: 50.8845 - val_loss: 55.9045 - val_mean_absolute_percentage_error: 55.9045
# Epoch 16/100
# 14/14 [==============================] - 0s 13ms/step - loss: 54.7154 - mean_absolute_percentage_error: 54.7154 - val_loss: 52.0931 - val_mean_absolute_percentage_error: 52.0931
# Epoch 17/100
# 14/14 [==============================] - 0s 11ms/step - loss: 54.0893 - mean_absolute_percentage_error: 54.0893 - val_loss: 55.7703 - val_mean_absolute_percentage_error: 55.7703
# Epoch 18/100
# 14/14 [==============================] - 0s 10ms/step - loss: 53.2059 - mean_absolute_percentage_error: 53.2059 - val_loss: 59.0373 - val_mean_absolute_percentage_error: 59.0373
# Epoch 19/100
# 14/14 [==============================] - 0s 10ms/step - loss: 50.9899 - mean_absolute_percentage_error: 50.9899 - val_loss: 54.7606 - val_mean_absolute_percentage_error: 54.7606
# Epoch 20/100
# 14/14 [==============================] - 0s 10ms/step - loss: 50.9442 - mean_absolute_percentage_error: 50.9442 - val_loss: 55.6691 - val_mean_absolute_percentage_error: 55.6691
# Epoch 21/100
# 14/14 [==============================] - 0s 10ms/step - loss: 52.4848 - mean_absolute_percentage_error: 52.4848 - val_loss: 54.5535 - val_mean_absolute_percentage_error: 54.5535
# Epoch 22/100
# 14/14 [==============================] - 0s 10ms/step - loss: 48.2143 - mean_absolute_percentage_error: 48.2143 - val_loss: 55.3599 - val_mean_absolute_percentage_error: 55.3599
# Epoch 23/100
# 14/14 [==============================] - 0s 10ms/step - loss: 49.8575 - mean_absolute_percentage_error: 49.8575 - val_loss: 53.4969 - val_mean_absolute_percentage_error: 53.4969
# Epoch 24/100
# 14/14 [==============================] - 0s 10ms/step - loss: 45.5365 - mean_absolute_percentage_error: 45.5365 - val_loss: 54.4402 - val_mean_absolute_percentage_error: 54.4402
# Epoch 25/100
# 14/14 [==============================] - 0s 10ms/step - loss: 44.8779 - mean_absolute_percentage_error: 44.8779 - val_loss: 54.6993 - val_mean_absolute_percentage_error: 54.6993
# Epoch 26/100
# 14/14 [==============================] - 0s 10ms/step - loss: 45.5929 - mean_absolute_percentage_error: 45.5929 - val_loss: 52.3116 - val_mean_absolute_percentage_error: 52.3116
# Epoch 27/100
# 14/14 [==============================] - 0s 10ms/step - loss: 44.3402 - mean_absolute_percentage_error: 44.3402 - val_loss: 53.8199 - val_mean_absolute_percentage_error: 53.8199
# Epoch 28/100
# 14/14 [==============================] - 0s 11ms/step - loss: 42.5377 - mean_absolute_percentage_error: 42.5377 - val_loss: 56.9426 - val_mean_absolute_percentage_error: 56.9426
# Epoch 29/100
# 14/14 [==============================] - 0s 11ms/step - loss: 41.7730 - mean_absolute_percentage_error: 41.7730 - val_loss: 51.0948 - val_mean_absolute_percentage_error: 51.0948
# Epoch 30/100
# 14/14 [==============================] - 0s 10ms/step - loss: 38.9211 - mean_absolute_percentage_error: 38.9211 - val_loss: 52.2071 - val_mean_absolute_percentage_error: 52.2071
# Epoch 31/100
# 14/14 [==============================] - 0s 10ms/step - loss: 42.5183 - mean_absolute_percentage_error: 42.5183 - val_loss: 50.9657 - val_mean_absolute_percentage_error: 50.9657
# Epoch 32/100
# 14/14 [==============================] - 0s 10ms/step - loss: 37.6507 - mean_absolute_percentage_error: 37.6507 - val_loss: 52.2306 - val_mean_absolute_percentage_error: 52.2306
# Epoch 33/100
# 14/14 [==============================] - 0s 10ms/step - loss: 40.2719 - mean_absolute_percentage_error: 40.2719 - val_loss: 52.2088 - val_mean_absolute_percentage_error: 52.2088
# Epoch 34/100
# 14/14 [==============================] - 0s 10ms/step - loss: 35.9902 - mean_absolute_percentage_error: 35.9902 - val_loss: 54.6579 - val_mean_absolute_percentage_error: 54.6579
# Epoch 35/100
# 14/14 [==============================] - 0s 10ms/step - loss: 38.2267 - mean_absolute_percentage_error: 38.2267 - val_loss: 52.4634 - val_mean_absolute_percentage_error: 52.4634
# Epoch 36/100
# 14/14 [==============================] - 0s 10ms/step - loss: 35.0137 - mean_absolute_percentage_error: 35.0137 - val_loss: 52.8450 - val_mean_absolute_percentage_error: 52.8450
# Epoch 37/100
# 14/14 [==============================] - 0s 9ms/step - loss: 36.0647 - mean_absolute_percentage_error: 36.0647 - val_loss: 52.0520 - val_mean_absolute_percentage_error: 52.0520
# Epoch 38/100
# 14/14 [==============================] - 0s 10ms/step - loss: 34.4134 - mean_absolute_percentage_error: 34.4134 - val_loss: 53.0160 - val_mean_absolute_percentage_error: 53.0160
# Epoch 39/100
# 14/14 [==============================] - 0s 10ms/step - loss: 33.0833 - mean_absolute_percentage_error: 33.0833 - val_loss: 52.7779 - val_mean_absolute_percentage_error: 52.7779
# Epoch 40/100
# 14/14 [==============================] - 0s 10ms/step - loss: 29.9856 - mean_absolute_percentage_error: 29.9856 - val_loss: 51.9919 - val_mean_absolute_percentage_error: 51.9919
# Epoch 41/100
# 14/14 [==============================] - 0s 10ms/step - loss: 31.4020 - mean_absolute_percentage_error: 31.4020 - val_loss: 57.0045 - val_mean_absolute_percentage_error: 57.0045
# Epoch 42/100
# 14/14 [==============================] - 0s 11ms/step - loss: 35.6685 - mean_absolute_percentage_error: 35.6685 - val_loss: 51.8446 - val_mean_absolute_percentage_error: 51.8446
# Epoch 43/100
# 14/14 [==============================] - 0s 10ms/step - loss: 30.4308 - mean_absolute_percentage_error: 30.4308 - val_loss: 54.5336 - val_mean_absolute_percentage_error: 54.5336
# Epoch 44/100
# 14/14 [==============================] - 0s 10ms/step - loss: 27.9149 - mean_absolute_percentage_error: 27.9149 - val_loss: 50.4764 - val_mean_absolute_percentage_error: 50.4764
# Epoch 45/100
# 14/14 [==============================] - 0s 10ms/step - loss: 26.9356 - mean_absolute_percentage_error: 26.9356 - val_loss: 48.3813 - val_mean_absolute_percentage_error: 48.3813
# Epoch 46/100
# 14/14 [==============================] - 0s 10ms/step - loss: 25.0521 - mean_absolute_percentage_error: 25.0521 - val_loss: 49.9376 - val_mean_absolute_percentage_error: 49.9376
# Epoch 47/100
# 14/14 [==============================] - 0s 12ms/step - loss: 27.1109 - mean_absolute_percentage_error: 27.1109 - val_loss: 50.4131 - val_mean_absolute_percentage_error: 50.4131
# Epoch 48/100
# 14/14 [==============================] - 0s 13ms/step - loss: 25.4168 - mean_absolute_percentage_error: 25.4168 - val_loss: 51.2972 - val_mean_absolute_percentage_error: 51.2972
# Epoch 49/100
# 14/14 [==============================] - 0s 13ms/step - loss: 25.5081 - mean_absolute_percentage_error: 25.5081 - val_loss: 49.1497 - val_mean_absolute_percentage_error: 49.1497
# Epoch 50/100
# 14/14 [==============================] - 0s 12ms/step - loss: 24.4713 - mean_absolute_percentage_error: 24.4713 - val_loss: 48.3865 - val_mean_absolute_percentage_error: 48.3865
# Epoch 51/100
# 14/14 [==============================] - 0s 12ms/step - loss: 27.0213 - mean_absolute_percentage_error: 27.0213 - val_loss: 52.3051 - val_mean_absolute_percentage_error: 52.3051
# Epoch 52/100
# 14/14 [==============================] - 0s 12ms/step - loss: 23.8863 - mean_absolute_percentage_error: 23.8863 - val_loss: 48.7591 - val_mean_absolute_percentage_error: 48.7591
# Epoch 53/100
# 14/14 [==============================] - 0s 13ms/step - loss: 23.8810 - mean_absolute_percentage_error: 23.8810 - val_loss: 49.5250 - val_mean_absolute_percentage_error: 49.5250
# Epoch 54/100
# 14/14 [==============================] - 0s 13ms/step - loss: 24.0678 - mean_absolute_percentage_error: 24.0678 - val_loss: 55.7993 - val_mean_absolute_percentage_error: 55.7993
# Epoch 55/100
# 14/14 [==============================] - 0s 12ms/step - loss: 23.5953 - mean_absolute_percentage_error: 23.5953 - val_loss: 50.0003 - val_mean_absolute_percentage_error: 50.0003
# Epoch 56/100
# 14/14 [==============================] - 0s 12ms/step - loss: 23.0000 - mean_absolute_percentage_error: 23.0000 - val_loss: 60.5322 - val_mean_absolute_percentage_error: 60.5322
# Epoch 57/100
# 14/14 [==============================] - 0s 11ms/step - loss: 24.0507 - mean_absolute_percentage_error: 24.0507 - val_loss: 48.3351 - val_mean_absolute_percentage_error: 48.3351
# Epoch 58/100
# 14/14 [==============================] - 0s 12ms/step - loss: 22.8485 - mean_absolute_percentage_error: 22.8485 - val_loss: 56.5710 - val_mean_absolute_percentage_error: 56.5710
# Epoch 59/100
# 14/14 [==============================] - 0s 12ms/step - loss: 21.7560 - mean_absolute_percentage_error: 21.7560 - val_loss: 51.0893 - val_mean_absolute_percentage_error: 51.0893
# Epoch 60/100
# 14/14 [==============================] - 0s 13ms/step - loss: 22.9409 - mean_absolute_percentage_error: 22.9409 - val_loss: 48.7476 - val_mean_absolute_percentage_error: 48.7475
# Epoch 61/100
# 14/14 [==============================] - 0s 12ms/step - loss: 23.2582 - mean_absolute_percentage_error: 23.2582 - val_loss: 50.0209 - val_mean_absolute_percentage_error: 50.0209
# Epoch 62/100
# 14/14 [==============================] - 0s 13ms/step - loss: 21.1308 - mean_absolute_percentage_error: 21.1308 - val_loss: 49.6772 - val_mean_absolute_percentage_error: 49.6772
# Epoch 63/100
# 14/14 [==============================] - 0s 12ms/step - loss: 19.9005 - mean_absolute_percentage_error: 19.9005 - val_loss: 51.6696 - val_mean_absolute_percentage_error: 51.6696
# Epoch 64/100
# 14/14 [==============================] - 0s 10ms/step - loss: 20.3670 - mean_absolute_percentage_error: 20.3670 - val_loss: 47.1971 - val_mean_absolute_percentage_error: 47.1971
# Epoch 65/100
# 14/14 [==============================] - 0s 10ms/step - loss: 20.5666 - mean_absolute_percentage_error: 20.5666 - val_loss: 51.0870 - val_mean_absolute_percentage_error: 51.0870
# Epoch 66/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.5213 - mean_absolute_percentage_error: 18.5213 - val_loss: 54.9777 - val_mean_absolute_percentage_error: 54.9777
# Epoch 67/100
# 14/14 [==============================] - 0s 10ms/step - loss: 19.4617 - mean_absolute_percentage_error: 19.4617 - val_loss: 49.6793 - val_mean_absolute_percentage_error: 49.6793
# Epoch 68/100
# 14/14 [==============================] - 0s 9ms/step - loss: 17.8575 - mean_absolute_percentage_error: 17.8575 - val_loss: 53.2769 - val_mean_absolute_percentage_error: 53.2769
# Epoch 69/100
# 14/14 [==============================] - 0s 10ms/step - loss: 19.6518 - mean_absolute_percentage_error: 19.6518 - val_loss: 57.0431 - val_mean_absolute_percentage_error: 57.0431
# Epoch 70/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.9277 - mean_absolute_percentage_error: 18.9277 - val_loss: 51.4024 - val_mean_absolute_percentage_error: 51.4024
# Epoch 71/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.2134 - mean_absolute_percentage_error: 18.2134 - val_loss: 53.0205 - val_mean_absolute_percentage_error: 53.0205
# Epoch 72/100
# 14/14 [==============================] - 0s 9ms/step - loss: 18.5364 - mean_absolute_percentage_error: 18.5364 - val_loss: 55.5542 - val_mean_absolute_percentage_error: 55.5542
# Epoch 73/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.6576 - mean_absolute_percentage_error: 18.6576 - val_loss: 49.8018 - val_mean_absolute_percentage_error: 49.8018
# Epoch 74/100
# 14/14 [==============================] - 0s 10ms/step - loss: 19.5853 - mean_absolute_percentage_error: 19.5853 - val_loss: 50.4460 - val_mean_absolute_percentage_error: 50.4460
# Epoch 75/100
# 14/14 [==============================] - 0s 10ms/step - loss: 17.7318 - mean_absolute_percentage_error: 17.7318 - val_loss: 50.6090 - val_mean_absolute_percentage_error: 50.6090
# Epoch 76/100
# 14/14 [==============================] - 0s 11ms/step - loss: 17.7817 - mean_absolute_percentage_error: 17.7817 - val_loss: 50.9348 - val_mean_absolute_percentage_error: 50.9348
# Epoch 77/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.2123 - mean_absolute_percentage_error: 18.2123 - val_loss: 55.2441 - val_mean_absolute_percentage_error: 55.2441
# Epoch 78/100
# 14/14 [==============================] - 0s 10ms/step - loss: 20.2219 - mean_absolute_percentage_error: 20.2219 - val_loss: 58.8167 - val_mean_absolute_percentage_error: 58.8167
# Epoch 79/100
# 14/14 [==============================] - 0s 10ms/step - loss: 18.6025 - mean_absolute_percentage_error: 18.6025 - val_loss: 51.5709 - val_mean_absolute_percentage_error: 51.5709
# Epoch 80/100
# 14/14 [==============================] - 0s 10ms/step - loss: 17.9479 - mean_absolute_percentage_error: 17.9479 - val_loss: 60.2015 - val_mean_absolute_percentage_error: 60.2015
# Epoch 81/100
# 14/14 [==============================] - 0s 10ms/step - loss: 16.3843 - mean_absolute_percentage_error: 16.3843 - val_loss: 48.8985 - val_mean_absolute_percentage_error: 48.8985
# Epoch 82/100
# 14/14 [==============================] - 0s 10ms/step - loss: 17.8012 - mean_absolute_percentage_error: 17.8012 - val_loss: 53.3504 - val_mean_absolute_percentage_error: 53.3504
# Epoch 83/100
# 14/14 [==============================] - 0s 10ms/step - loss: 17.4053 - mean_absolute_percentage_error: 17.4053 - val_loss: 51.1362 - val_mean_absolute_percentage_error: 51.1362
# Epoch 84/100
# 14/14 [==============================] - 0s 10ms/step - loss: 15.5472 - mean_absolute_percentage_error: 15.5472 - val_loss: 48.8874 - val_mean_absolute_percentage_error: 48.8874
# Epoch 85/100
# 14/14 [==============================] - 0s 9ms/step - loss: 16.1087 - mean_absolute_percentage_error: 16.1087 - val_loss: 55.6183 - val_mean_absolute_percentage_error: 55.6183
# Epoch 86/100
# 14/14 [==============================] - 0s 9ms/step - loss: 16.3912 - mean_absolute_percentage_error: 16.3912 - val_loss: 51.5012 - val_mean_absolute_percentage_error: 51.5012
# Epoch 87/100
# 14/14 [==============================] - 0s 10ms/step - loss: 17.1737 - mean_absolute_percentage_error: 17.1737 - val_loss: 59.5454 - val_mean_absolute_percentage_error: 59.5454
# Epoch 88/100
# 14/14 [==============================] - 0s 9ms/step - loss: 16.4465 - mean_absolute_percentage_error: 16.4465 - val_loss: 54.3236 - val_mean_absolute_percentage_error: 54.3236
# Epoch 89/100
# 14/14 [==============================] - 0s 9ms/step - loss: 16.2937 - mean_absolute_percentage_error: 16.2937 - val_loss: 57.7489 - val_mean_absolute_percentage_error: 57.7489
# Epoch 90/100
# 14/14 [==============================] - 0s 9ms/step - loss: 17.2796 - mean_absolute_percentage_error: 17.2796 - val_loss: 52.4033 - val_mean_absolute_percentage_error: 52.4033
# Epoch 91/100
# 14/14 [==============================] - 0s 10ms/step - loss: 16.8483 - mean_absolute_percentage_error: 16.8483 - val_loss: 50.9018 - val_mean_absolute_percentage_error: 50.9018
# Epoch 92/100
# 14/14 [==============================] - 0s 10ms/step - loss: 16.9609 - mean_absolute_percentage_error: 16.9609 - val_loss: 49.1106 - val_mean_absolute_percentage_error: 49.1106
# Epoch 93/100
# 14/14 [==============================] - 0s 10ms/step - loss: 15.3571 - mean_absolute_percentage_error: 15.3571 - val_loss: 49.3192 - val_mean_absolute_percentage_error: 49.3192
# Epoch 94/100
# 14/14 [==============================] - 0s 10ms/step - loss: 14.9483 - mean_absolute_percentage_error: 14.9483 - val_loss: 53.3707 - val_mean_absolute_percentage_error: 53.3707
# Epoch 95/100
# 14/14 [==============================] - 0s 10ms/step - loss: 15.7488 - mean_absolute_percentage_error: 15.7488 - val_loss: 54.0545 - val_mean_absolute_percentage_error: 54.0545
# Epoch 96/100
# 14/14 [==============================] - 0s 11ms/step - loss: 15.2332 - mean_absolute_percentage_error: 15.2332 - val_loss: 53.4449 - val_mean_absolute_percentage_error: 53.4449
# Epoch 97/100
# 14/14 [==============================] - 0s 10ms/step - loss: 14.4083 - mean_absolute_percentage_error: 14.4083 - val_loss: 50.7827 - val_mean_absolute_percentage_error: 50.7827
# Epoch 98/100
# 14/14 [==============================] - 0s 10ms/step - loss: 14.9139 - mean_absolute_percentage_error: 14.9139 - val_loss: 57.2829 - val_mean_absolute_percentage_error: 57.2829
# Epoch 99/100
# 14/14 [==============================] - 0s 10ms/step - loss: 14.8798 - mean_absolute_percentage_error: 14.8798 - val_loss: 56.2822 - val_mean_absolute_percentage_error: 56.2822
# Epoch 100/100
# 14/14 [==============================] - 0s 9ms/step - loss: 16.4813 - mean_absolute_percentage_error: 16.4813 - val_loss: 54.0858 - val_mean_absolute_percentage_error: 54.0858

# %%
prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# 4/4 [==============================] - 0s 6ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 54.09%

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
# model.add(Conv2D(64, (3,3), padding='same', input_shape=X_train.shape[1:]))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2,2)))

# input_shape=X_train.shape[1:]

# model.add(Flatten())
model.add(Dense(8, input_shape=X_train.shape[1:], activation='relu'))
# model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('relu'))
model.add(Flatten())

# model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_73"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_77 (Dense)            (None, 64, 64, 8)         32
#
#  dropout_13 (Dropout)        (None, 64, 64, 8)         0
#
#  dense_78 (Dense)            (None, 64, 64, 4)         36
#
#  activation_149 (Activation  (None, 64, 64, 4)         0
#  )
#
#  flatten_37 (Flatten)        (None, 16384)             0
#
#  dense_79 (Dense)            (None, 1)                 16385
#
#  activation_150 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 16453 (64.27 KB)
# Trainable params: 16453 (64.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 21ms/step - loss: 551.5224 - mean_absolute_percentage_error: 551.5224 - val_loss: 385.2518 - val_mean_absolute_percentage_error: 385.2518
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 274.5632 - mean_absolute_percentage_error: 274.5632 - val_loss: 82.2665 - val_mean_absolute_percentage_error: 82.2665
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 136.2742 - mean_absolute_percentage_error: 136.2742 - val_loss: 74.4051 - val_mean_absolute_percentage_error: 74.4051
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 88.8438 - mean_absolute_percentage_error: 88.8438 - val_loss: 69.1781 - val_mean_absolute_percentage_error: 69.1781
# Epoch 5/100
# 14/14 [==============================] - 0s 7ms/step - loss: 83.6404 - mean_absolute_percentage_error: 83.6404 - val_loss: 65.7601 - val_mean_absolute_percentage_error: 65.7601
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 74.1963 - mean_absolute_percentage_error: 74.1963 - val_loss: 70.3749 - val_mean_absolute_percentage_error: 70.3749
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 78.5891 - mean_absolute_percentage_error: 78.5891 - val_loss: 64.8808 - val_mean_absolute_percentage_error: 64.8808
# Epoch 8/100
# 14/14 [==============================] - 0s 8ms/step - loss: 79.1916 - mean_absolute_percentage_error: 79.1916 - val_loss: 68.7256 - val_mean_absolute_percentage_error: 68.7256
# Epoch 9/100
# 14/14 [==============================] - 0s 8ms/step - loss: 68.2816 - mean_absolute_percentage_error: 68.2816 - val_loss: 65.0314 - val_mean_absolute_percentage_error: 65.0314
# Epoch 10/100
# 14/14 [==============================] - 0s 8ms/step - loss: 68.1842 - mean_absolute_percentage_error: 68.1842 - val_loss: 76.0518 - val_mean_absolute_percentage_error: 76.0518
# Epoch 11/100
# 14/14 [==============================] - 0s 8ms/step - loss: 64.2030 - mean_absolute_percentage_error: 64.2030 - val_loss: 65.9066 - val_mean_absolute_percentage_error: 65.9066
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 63.2858 - mean_absolute_percentage_error: 63.2858 - val_loss: 73.3668 - val_mean_absolute_percentage_error: 73.3668
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 62.1878 - mean_absolute_percentage_error: 62.1878 - val_loss: 62.8568 - val_mean_absolute_percentage_error: 62.8568
# Epoch 14/100
# 14/14 [==============================] - 0s 7ms/step - loss: 62.1561 - mean_absolute_percentage_error: 62.1561 - val_loss: 61.8473 - val_mean_absolute_percentage_error: 61.8473
# Epoch 15/100
# 14/14 [==============================] - 0s 9ms/step - loss: 61.4279 - mean_absolute_percentage_error: 61.4279 - val_loss: 60.8594 - val_mean_absolute_percentage_error: 60.8594
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 59.7657 - mean_absolute_percentage_error: 59.7657 - val_loss: 67.8844 - val_mean_absolute_percentage_error: 67.8844
# Epoch 17/100
# 14/14 [==============================] - 0s 8ms/step - loss: 61.8836 - mean_absolute_percentage_error: 61.8836 - val_loss: 70.0044 - val_mean_absolute_percentage_error: 70.0044
# Epoch 18/100
# 14/14 [==============================] - 0s 7ms/step - loss: 57.6926 - mean_absolute_percentage_error: 57.6926 - val_loss: 64.7866 - val_mean_absolute_percentage_error: 64.7866
# Epoch 19/100
# 14/14 [==============================] - 0s 8ms/step - loss: 55.4942 - mean_absolute_percentage_error: 55.4942 - val_loss: 62.3817 - val_mean_absolute_percentage_error: 62.3817
# Epoch 20/100
# 14/14 [==============================] - 0s 8ms/step - loss: 51.5679 - mean_absolute_percentage_error: 51.5679 - val_loss: 63.5356 - val_mean_absolute_percentage_error: 63.5356
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 54.6306 - mean_absolute_percentage_error: 54.6306 - val_loss: 63.6250 - val_mean_absolute_percentage_error: 63.6250
# Epoch 22/100
# 14/14 [==============================] - 0s 8ms/step - loss: 51.9108 - mean_absolute_percentage_error: 51.9108 - val_loss: 63.8767 - val_mean_absolute_percentage_error: 63.8767
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 51.2733 - mean_absolute_percentage_error: 51.2733 - val_loss: 62.7926 - val_mean_absolute_percentage_error: 62.7926
# Epoch 24/100
# 14/14 [==============================] - 0s 9ms/step - loss: 50.8519 - mean_absolute_percentage_error: 50.8519 - val_loss: 61.2349 - val_mean_absolute_percentage_error: 61.2349
# Epoch 25/100
# 14/14 [==============================] - 0s 8ms/step - loss: 51.3879 - mean_absolute_percentage_error: 51.3879 - val_loss: 62.3407 - val_mean_absolute_percentage_error: 62.3407
# Epoch 26/100
# 14/14 [==============================] - 0s 7ms/step - loss: 56.9959 - mean_absolute_percentage_error: 56.9959 - val_loss: 65.7893 - val_mean_absolute_percentage_error: 65.7893
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 55.5928 - mean_absolute_percentage_error: 55.5928 - val_loss: 65.8799 - val_mean_absolute_percentage_error: 65.8799
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 52.9628 - mean_absolute_percentage_error: 52.9628 - val_loss: 62.8588 - val_mean_absolute_percentage_error: 62.8588
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 49.7530 - mean_absolute_percentage_error: 49.7530 - val_loss: 62.8057 - val_mean_absolute_percentage_error: 62.8057
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 48.9017 - mean_absolute_percentage_error: 48.9017 - val_loss: 62.1999 - val_mean_absolute_percentage_error: 62.1999
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 46.6624 - mean_absolute_percentage_error: 46.6624 - val_loss: 63.8787 - val_mean_absolute_percentage_error: 63.8787
# Epoch 32/100
# 14/14 [==============================] - 0s 7ms/step - loss: 45.9673 - mean_absolute_percentage_error: 45.9673 - val_loss: 63.3933 - val_mean_absolute_percentage_error: 63.3933
# Epoch 33/100
# 14/14 [==============================] - 0s 8ms/step - loss: 45.7885 - mean_absolute_percentage_error: 45.7885 - val_loss: 63.6480 - val_mean_absolute_percentage_error: 63.6480
# Epoch 34/100
# 14/14 [==============================] - 0s 8ms/step - loss: 44.9391 - mean_absolute_percentage_error: 44.9391 - val_loss: 65.3935 - val_mean_absolute_percentage_error: 65.3935
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 47.5870 - mean_absolute_percentage_error: 47.5870 - val_loss: 62.3208 - val_mean_absolute_percentage_error: 62.3208
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 45.7580 - mean_absolute_percentage_error: 45.7580 - val_loss: 65.8088 - val_mean_absolute_percentage_error: 65.8088
# Epoch 37/100
# 14/14 [==============================] - 0s 8ms/step - loss: 44.3697 - mean_absolute_percentage_error: 44.3697 - val_loss: 63.4554 - val_mean_absolute_percentage_error: 63.4554
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 44.4797 - mean_absolute_percentage_error: 44.4797 - val_loss: 62.9035 - val_mean_absolute_percentage_error: 62.9035
# Epoch 39/100
# 14/14 [==============================] - 0s 9ms/step - loss: 41.3022 - mean_absolute_percentage_error: 41.3022 - val_loss: 62.3875 - val_mean_absolute_percentage_error: 62.3875
# Epoch 40/100
# 14/14 [==============================] - 0s 8ms/step - loss: 44.4146 - mean_absolute_percentage_error: 44.4146 - val_loss: 62.5411 - val_mean_absolute_percentage_error: 62.5411
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 43.9656 - mean_absolute_percentage_error: 43.9656 - val_loss: 63.1296 - val_mean_absolute_percentage_error: 63.1296
# Epoch 42/100
# 14/14 [==============================] - 0s 8ms/step - loss: 43.1047 - mean_absolute_percentage_error: 43.1047 - val_loss: 64.7581 - val_mean_absolute_percentage_error: 64.7581
# Epoch 43/100
# 14/14 [==============================] - 0s 7ms/step - loss: 42.2078 - mean_absolute_percentage_error: 42.2078 - val_loss: 61.6301 - val_mean_absolute_percentage_error: 61.6301
# Epoch 44/100
# 14/14 [==============================] - 0s 10ms/step - loss: 41.6294 - mean_absolute_percentage_error: 41.6294 - val_loss: 61.5717 - val_mean_absolute_percentage_error: 61.5717
# Epoch 45/100
# 14/14 [==============================] - 0s 11ms/step - loss: 39.3983 - mean_absolute_percentage_error: 39.3983 - val_loss: 59.1647 - val_mean_absolute_percentage_error: 59.1647
# Epoch 46/100
# 14/14 [==============================] - 0s 10ms/step - loss: 39.4672 - mean_absolute_percentage_error: 39.4672 - val_loss: 62.5061 - val_mean_absolute_percentage_error: 62.5061
# Epoch 47/100
# 14/14 [==============================] - 0s 10ms/step - loss: 37.5675 - mean_absolute_percentage_error: 37.5675 - val_loss: 60.0717 - val_mean_absolute_percentage_error: 60.0717
# Epoch 48/100
# 14/14 [==============================] - 0s 9ms/step - loss: 40.2953 - mean_absolute_percentage_error: 40.2953 - val_loss: 61.3786 - val_mean_absolute_percentage_error: 61.3786
# Epoch 49/100
# 14/14 [==============================] - 0s 13ms/step - loss: 40.8860 - mean_absolute_percentage_error: 40.8860 - val_loss: 61.3230 - val_mean_absolute_percentage_error: 61.3230
# Epoch 50/100
# 14/14 [==============================] - 0s 10ms/step - loss: 39.4562 - mean_absolute_percentage_error: 39.4562 - val_loss: 59.1784 - val_mean_absolute_percentage_error: 59.1784
# Epoch 51/100
# 14/14 [==============================] - 0s 10ms/step - loss: 40.4933 - mean_absolute_percentage_error: 40.4933 - val_loss: 62.1527 - val_mean_absolute_percentage_error: 62.1527
# Epoch 52/100
# 14/14 [==============================] - 0s 13ms/step - loss: 37.3644 - mean_absolute_percentage_error: 37.3644 - val_loss: 61.9285 - val_mean_absolute_percentage_error: 61.9285
# Epoch 53/100
# 14/14 [==============================] - 0s 10ms/step - loss: 36.1116 - mean_absolute_percentage_error: 36.1116 - val_loss: 61.0943 - val_mean_absolute_percentage_error: 61.0943
# Epoch 54/100
# 14/14 [==============================] - 0s 10ms/step - loss: 39.7602 - mean_absolute_percentage_error: 39.7602 - val_loss: 60.9912 - val_mean_absolute_percentage_error: 60.9912
# Epoch 55/100
# 14/14 [==============================] - 0s 11ms/step - loss: 37.4136 - mean_absolute_percentage_error: 37.4136 - val_loss: 60.1405 - val_mean_absolute_percentage_error: 60.1405
# Epoch 56/100
# 14/14 [==============================] - 0s 11ms/step - loss: 37.2994 - mean_absolute_percentage_error: 37.2994 - val_loss: 60.0932 - val_mean_absolute_percentage_error: 60.0932
# Epoch 57/100
# 14/14 [==============================] - 0s 10ms/step - loss: 36.9801 - mean_absolute_percentage_error: 36.9801 - val_loss: 60.5240 - val_mean_absolute_percentage_error: 60.5240
# Epoch 58/100
# 14/14 [==============================] - 0s 10ms/step - loss: 34.9709 - mean_absolute_percentage_error: 34.9709 - val_loss: 57.7776 - val_mean_absolute_percentage_error: 57.7776
# Epoch 59/100
# 14/14 [==============================] - 0s 10ms/step - loss: 35.2642 - mean_absolute_percentage_error: 35.2642 - val_loss: 60.8030 - val_mean_absolute_percentage_error: 60.8030
# Epoch 60/100
# 14/14 [==============================] - 0s 11ms/step - loss: 36.4895 - mean_absolute_percentage_error: 36.4895 - val_loss: 60.1489 - val_mean_absolute_percentage_error: 60.1489
# Epoch 61/100
# 14/14 [==============================] - 0s 10ms/step - loss: 35.3497 - mean_absolute_percentage_error: 35.3497 - val_loss: 60.1501 - val_mean_absolute_percentage_error: 60.1501
# Epoch 62/100
# 14/14 [==============================] - 0s 10ms/step - loss: 36.1287 - mean_absolute_percentage_error: 36.1287 - val_loss: 60.9399 - val_mean_absolute_percentage_error: 60.9399
# Epoch 63/100
# 14/14 [==============================] - 0s 11ms/step - loss: 37.5172 - mean_absolute_percentage_error: 37.5172 - val_loss: 60.2958 - val_mean_absolute_percentage_error: 60.2958
# Epoch 64/100
# 14/14 [==============================] - 0s 9ms/step - loss: 34.7166 - mean_absolute_percentage_error: 34.7166 - val_loss: 60.2905 - val_mean_absolute_percentage_error: 60.2905
# Epoch 65/100
# 14/14 [==============================] - 0s 7ms/step - loss: 35.0376 - mean_absolute_percentage_error: 35.0376 - val_loss: 57.3203 - val_mean_absolute_percentage_error: 57.3203
# Epoch 66/100
# 14/14 [==============================] - 0s 8ms/step - loss: 37.1349 - mean_absolute_percentage_error: 37.1349 - val_loss: 59.5158 - val_mean_absolute_percentage_error: 59.5158
# Epoch 67/100
# 14/14 [==============================] - 0s 8ms/step - loss: 36.9908 - mean_absolute_percentage_error: 36.9908 - val_loss: 60.3429 - val_mean_absolute_percentage_error: 60.3429
# Epoch 68/100
# 14/14 [==============================] - 0s 8ms/step - loss: 36.4562 - mean_absolute_percentage_error: 36.4562 - val_loss: 58.9509 - val_mean_absolute_percentage_error: 58.9509
# Epoch 69/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.8190 - mean_absolute_percentage_error: 33.8190 - val_loss: 58.1951 - val_mean_absolute_percentage_error: 58.1951
# Epoch 70/100
# 14/14 [==============================] - 0s 8ms/step - loss: 35.6202 - mean_absolute_percentage_error: 35.6202 - val_loss: 60.4935 - val_mean_absolute_percentage_error: 60.4935
# Epoch 71/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.9408 - mean_absolute_percentage_error: 33.9408 - val_loss: 59.8947 - val_mean_absolute_percentage_error: 59.8947
# Epoch 72/100
# 14/14 [==============================] - 0s 8ms/step - loss: 35.0663 - mean_absolute_percentage_error: 35.0663 - val_loss: 59.0838 - val_mean_absolute_percentage_error: 59.0838
# Epoch 73/100
# 14/14 [==============================] - 0s 7ms/step - loss: 33.9323 - mean_absolute_percentage_error: 33.9323 - val_loss: 60.6915 - val_mean_absolute_percentage_error: 60.6915
# Epoch 74/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.8033 - mean_absolute_percentage_error: 32.8033 - val_loss: 59.6161 - val_mean_absolute_percentage_error: 59.6161
# Epoch 75/100
# 14/14 [==============================] - 0s 8ms/step - loss: 34.1373 - mean_absolute_percentage_error: 34.1373 - val_loss: 60.8215 - val_mean_absolute_percentage_error: 60.8215
# Epoch 76/100
# 14/14 [==============================] - 0s 8ms/step - loss: 34.8029 - mean_absolute_percentage_error: 34.8029 - val_loss: 59.4934 - val_mean_absolute_percentage_error: 59.4934
# Epoch 77/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.3928 - mean_absolute_percentage_error: 33.3928 - val_loss: 59.3099 - val_mean_absolute_percentage_error: 59.3099
# Epoch 78/100
# 14/14 [==============================] - 0s 8ms/step - loss: 31.0457 - mean_absolute_percentage_error: 31.0457 - val_loss: 59.5751 - val_mean_absolute_percentage_error: 59.5751
# Epoch 79/100
# 14/14 [==============================] - 0s 8ms/step - loss: 30.9765 - mean_absolute_percentage_error: 30.9765 - val_loss: 57.8848 - val_mean_absolute_percentage_error: 57.8848
# Epoch 80/100
# 14/14 [==============================] - 0s 9ms/step - loss: 33.9463 - mean_absolute_percentage_error: 33.9463 - val_loss: 58.2874 - val_mean_absolute_percentage_error: 58.2874
# Epoch 81/100
# 14/14 [==============================] - 0s 9ms/step - loss: 34.6645 - mean_absolute_percentage_error: 34.6645 - val_loss: 60.6930 - val_mean_absolute_percentage_error: 60.6930
# Epoch 82/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.7863 - mean_absolute_percentage_error: 33.7863 - val_loss: 60.6546 - val_mean_absolute_percentage_error: 60.6546
# Epoch 83/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.7587 - mean_absolute_percentage_error: 33.7587 - val_loss: 60.4840 - val_mean_absolute_percentage_error: 60.4840
# Epoch 84/100
# 14/14 [==============================] - 0s 7ms/step - loss: 31.1217 - mean_absolute_percentage_error: 31.1217 - val_loss: 59.9480 - val_mean_absolute_percentage_error: 59.9480
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.6300 - mean_absolute_percentage_error: 32.6300 - val_loss: 60.4611 - val_mean_absolute_percentage_error: 60.4611
# Epoch 86/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.1812 - mean_absolute_percentage_error: 32.1812 - val_loss: 57.7575 - val_mean_absolute_percentage_error: 57.7575
# Epoch 87/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.7053 - mean_absolute_percentage_error: 32.7053 - val_loss: 59.5828 - val_mean_absolute_percentage_error: 59.5828
# Epoch 88/100
# 14/14 [==============================] - 0s 8ms/step - loss: 31.8568 - mean_absolute_percentage_error: 31.8568 - val_loss: 60.4392 - val_mean_absolute_percentage_error: 60.4392
# Epoch 89/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.1485 - mean_absolute_percentage_error: 32.1485 - val_loss: 58.7320 - val_mean_absolute_percentage_error: 58.7320
# Epoch 90/100
# 14/14 [==============================] - 0s 8ms/step - loss: 30.9157 - mean_absolute_percentage_error: 30.9157 - val_loss: 60.1362 - val_mean_absolute_percentage_error: 60.1362
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 32.0207 - mean_absolute_percentage_error: 32.0207 - val_loss: 57.5532 - val_mean_absolute_percentage_error: 57.5532
# Epoch 92/100
# 14/14 [==============================] - 0s 8ms/step - loss: 31.3255 - mean_absolute_percentage_error: 31.3255 - val_loss: 58.2320 - val_mean_absolute_percentage_error: 58.2320
# Epoch 93/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.0177 - mean_absolute_percentage_error: 32.0177 - val_loss: 56.8944 - val_mean_absolute_percentage_error: 56.8944
# Epoch 94/100
# 14/14 [==============================] - 0s 7ms/step - loss: 31.7893 - mean_absolute_percentage_error: 31.7893 - val_loss: 58.5435 - val_mean_absolute_percentage_error: 58.5435
# Epoch 95/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.6957 - mean_absolute_percentage_error: 32.6957 - val_loss: 59.8605 - val_mean_absolute_percentage_error: 59.8605
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 32.5018 - mean_absolute_percentage_error: 32.5018 - val_loss: 61.4027 - val_mean_absolute_percentage_error: 61.4027
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 34.5957 - mean_absolute_percentage_error: 34.5957 - val_loss: 57.8015 - val_mean_absolute_percentage_error: 57.8015
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 33.5992 - mean_absolute_percentage_error: 33.5992 - val_loss: 59.2164 - val_mean_absolute_percentage_error: 59.2164
# Epoch 99/100
# 14/14 [==============================] - 0s 7ms/step - loss: 30.2152 - mean_absolute_percentage_error: 30.2152 - val_loss: 61.1352 - val_mean_absolute_percentage_error: 61.1352
# Epoch 100/100
# 14/14 [==============================] - 0s 8ms/step - loss: 31.6050 - mean_absolute_percentage_error: 31.6050 - val_loss: 58.8628 - val_mean_absolute_percentage_error: 58.8628

# %%
prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# 4/4 [==============================] - 0s 4ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 58.86%

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
model.add(Dense(8, input_shape=X_train.shape[1:], activation='softmax'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('softmax'))


# model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_75"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_83 (Dense)            (None, 64, 64, 8)         32
#
#  flatten_39 (Flatten)        (None, 32768)             0
#
#  dropout_15 (Dropout)        (None, 32768)             0
#
#  dense_84 (Dense)            (None, 4)                 131076
#
#  activation_153 (Activation  (None, 4)                 0
#  )
#
#  dense_85 (Dense)            (None, 1)                 5
#
#  activation_154 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 131113 (512.16 KB)
# Trainable params: 131113 (512.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 28ms/step - loss: 184.0783 - mean_absolute_percentage_error: 184.0783 - val_loss: 76.0125 - val_mean_absolute_percentage_error: 76.0125
# Epoch 2/100
# 14/14 [==============================] - 0s 11ms/step - loss: 80.0279 - mean_absolute_percentage_error: 80.0279 - val_loss: 122.4297 - val_mean_absolute_percentage_error: 122.4297
# Epoch 3/100
# 14/14 [==============================] - 0s 10ms/step - loss: 105.8915 - mean_absolute_percentage_error: 105.8915 - val_loss: 165.1406 - val_mean_absolute_percentage_error: 165.1406
# Epoch 4/100
# 14/14 [==============================] - 0s 10ms/step - loss: 136.7664 - mean_absolute_percentage_error: 136.7664 - val_loss: 67.5543 - val_mean_absolute_percentage_error: 67.5543
# Epoch 5/100
# 14/14 [==============================] - 0s 10ms/step - loss: 94.8003 - mean_absolute_percentage_error: 94.8003 - val_loss: 68.4233 - val_mean_absolute_percentage_error: 68.4233
# Epoch 6/100
# 14/14 [==============================] - 0s 10ms/step - loss: 79.7822 - mean_absolute_percentage_error: 79.7822 - val_loss: 63.7476 - val_mean_absolute_percentage_error: 63.7476
# Epoch 7/100
# 14/14 [==============================] - 0s 10ms/step - loss: 80.7954 - mean_absolute_percentage_error: 80.7954 - val_loss: 104.7760 - val_mean_absolute_percentage_error: 104.7760
# Epoch 8/100
# 14/14 [==============================] - 0s 10ms/step - loss: 99.5125 - mean_absolute_percentage_error: 99.5125 - val_loss: 67.7926 - val_mean_absolute_percentage_error: 67.7926
# Epoch 9/100
# 14/14 [==============================] - 0s 11ms/step - loss: 120.6658 - mean_absolute_percentage_error: 120.6658 - val_loss: 94.1414 - val_mean_absolute_percentage_error: 94.1414
# Epoch 10/100
# 14/14 [==============================] - 0s 10ms/step - loss: 95.1260 - mean_absolute_percentage_error: 95.1260 - val_loss: 103.8124 - val_mean_absolute_percentage_error: 103.8124
# Epoch 11/100
# 14/14 [==============================] - 0s 11ms/step - loss: 79.8111 - mean_absolute_percentage_error: 79.8111 - val_loss: 68.4125 - val_mean_absolute_percentage_error: 68.4125
# Epoch 12/100
# 14/14 [==============================] - 0s 10ms/step - loss: 76.9096 - mean_absolute_percentage_error: 76.9096 - val_loss: 68.7630 - val_mean_absolute_percentage_error: 68.7630
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 74.1433 - mean_absolute_percentage_error: 74.1433 - val_loss: 70.5607 - val_mean_absolute_percentage_error: 70.5607
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2627 - mean_absolute_percentage_error: 70.2627 - val_loss: 67.3347 - val_mean_absolute_percentage_error: 67.3347
# Epoch 15/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4997 - mean_absolute_percentage_error: 70.4997 - val_loss: 67.7279 - val_mean_absolute_percentage_error: 67.7279
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3480 - mean_absolute_percentage_error: 70.3480 - val_loss: 68.7299 - val_mean_absolute_percentage_error: 68.7299
# Epoch 17/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2341 - mean_absolute_percentage_error: 70.2341 - val_loss: 69.4705 - val_mean_absolute_percentage_error: 69.4705
# Epoch 18/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2613 - mean_absolute_percentage_error: 70.2613 - val_loss: 68.9202 - val_mean_absolute_percentage_error: 68.9202
# Epoch 19/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4332 - mean_absolute_percentage_error: 70.4332 - val_loss: 69.4407 - val_mean_absolute_percentage_error: 69.4407
# Epoch 20/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.1876 - mean_absolute_percentage_error: 70.1876 - val_loss: 68.6789 - val_mean_absolute_percentage_error: 68.6789
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4415 - mean_absolute_percentage_error: 70.4415 - val_loss: 67.9861 - val_mean_absolute_percentage_error: 67.9861
# Epoch 22/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4056 - mean_absolute_percentage_error: 70.4056 - val_loss: 69.3257 - val_mean_absolute_percentage_error: 69.3257
# Epoch 23/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2250 - mean_absolute_percentage_error: 70.2250 - val_loss: 69.1665 - val_mean_absolute_percentage_error: 69.1665
# Epoch 24/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2488 - mean_absolute_percentage_error: 70.2488 - val_loss: 68.8223 - val_mean_absolute_percentage_error: 68.8223
# Epoch 25/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6743 - mean_absolute_percentage_error: 70.6743 - val_loss: 67.7726 - val_mean_absolute_percentage_error: 67.7726
# Epoch 26/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3169 - mean_absolute_percentage_error: 70.3169 - val_loss: 70.8558 - val_mean_absolute_percentage_error: 70.8558
# Epoch 27/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4026 - mean_absolute_percentage_error: 70.4026 - val_loss: 70.0833 - val_mean_absolute_percentage_error: 70.0833
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2641 - mean_absolute_percentage_error: 70.2641 - val_loss: 68.0442 - val_mean_absolute_percentage_error: 68.0442
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3540 - mean_absolute_percentage_error: 70.3540 - val_loss: 68.8909 - val_mean_absolute_percentage_error: 68.8909
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2617 - mean_absolute_percentage_error: 70.2617 - val_loss: 69.8712 - val_mean_absolute_percentage_error: 69.8712
# Epoch 31/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2896 - mean_absolute_percentage_error: 70.2896 - val_loss: 69.3271 - val_mean_absolute_percentage_error: 69.3271
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2457 - mean_absolute_percentage_error: 70.2457 - val_loss: 68.6087 - val_mean_absolute_percentage_error: 68.6087
# Epoch 33/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3758 - mean_absolute_percentage_error: 70.3758 - val_loss: 69.2115 - val_mean_absolute_percentage_error: 69.2115
# Epoch 34/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4074 - mean_absolute_percentage_error: 70.4074 - val_loss: 68.3111 - val_mean_absolute_percentage_error: 68.3111
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3677 - mean_absolute_percentage_error: 70.3677 - val_loss: 69.8246 - val_mean_absolute_percentage_error: 69.8246
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2878 - mean_absolute_percentage_error: 70.2878 - val_loss: 69.0884 - val_mean_absolute_percentage_error: 69.0884
# Epoch 37/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3835 - mean_absolute_percentage_error: 70.3835 - val_loss: 68.5506 - val_mean_absolute_percentage_error: 68.5506
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2677 - mean_absolute_percentage_error: 70.2677 - val_loss: 69.6584 - val_mean_absolute_percentage_error: 69.6584
# Epoch 39/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3913 - mean_absolute_percentage_error: 70.3913 - val_loss: 69.7327 - val_mean_absolute_percentage_error: 69.7327
# Epoch 40/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5409 - mean_absolute_percentage_error: 70.5409 - val_loss: 68.6789 - val_mean_absolute_percentage_error: 68.6789
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 71.1685 - mean_absolute_percentage_error: 71.1685 - val_loss: 71.9869 - val_mean_absolute_percentage_error: 71.9869
# Epoch 42/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4473 - mean_absolute_percentage_error: 70.4473 - val_loss: 67.6935 - val_mean_absolute_percentage_error: 67.6935
# Epoch 43/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3681 - mean_absolute_percentage_error: 70.3681 - val_loss: 68.6775 - val_mean_absolute_percentage_error: 68.6775
# Epoch 44/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3462 - mean_absolute_percentage_error: 70.3462 - val_loss: 69.4837 - val_mean_absolute_percentage_error: 69.4837
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.6207 - mean_absolute_percentage_error: 70.6207 - val_loss: 70.5836 - val_mean_absolute_percentage_error: 70.5836
# Epoch 46/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3415 - mean_absolute_percentage_error: 70.3415 - val_loss: 68.2282 - val_mean_absolute_percentage_error: 68.2282
# Epoch 47/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3760 - mean_absolute_percentage_error: 70.3760 - val_loss: 68.7557 - val_mean_absolute_percentage_error: 68.7557
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.1393 - mean_absolute_percentage_error: 70.1393 - val_loss: 70.7491 - val_mean_absolute_percentage_error: 70.7491
# Epoch 49/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.7702 - mean_absolute_percentage_error: 70.7702 - val_loss: 69.0076 - val_mean_absolute_percentage_error: 69.0076
# Epoch 50/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3891 - mean_absolute_percentage_error: 70.3891 - val_loss: 69.7213 - val_mean_absolute_percentage_error: 69.7213
# Epoch 51/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3617 - mean_absolute_percentage_error: 70.3617 - val_loss: 69.9210 - val_mean_absolute_percentage_error: 69.9210
# Epoch 52/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2533 - mean_absolute_percentage_error: 70.2533 - val_loss: 68.9132 - val_mean_absolute_percentage_error: 68.9132
# Epoch 53/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6684 - mean_absolute_percentage_error: 70.6684 - val_loss: 67.9249 - val_mean_absolute_percentage_error: 67.9249
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4369 - mean_absolute_percentage_error: 70.4369 - val_loss: 70.1560 - val_mean_absolute_percentage_error: 70.1560
# Epoch 55/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3564 - mean_absolute_percentage_error: 70.3564 - val_loss: 69.4954 - val_mean_absolute_percentage_error: 69.4954
# Epoch 56/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2923 - mean_absolute_percentage_error: 70.2923 - val_loss: 67.9776 - val_mean_absolute_percentage_error: 67.9776
# Epoch 57/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4238 - mean_absolute_percentage_error: 70.4238 - val_loss: 69.0564 - val_mean_absolute_percentage_error: 69.0564
# Epoch 58/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2778 - mean_absolute_percentage_error: 70.2778 - val_loss: 68.6688 - val_mean_absolute_percentage_error: 68.6688
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3874 - mean_absolute_percentage_error: 70.3874 - val_loss: 69.4507 - val_mean_absolute_percentage_error: 69.4507
# Epoch 60/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2138 - mean_absolute_percentage_error: 70.2138 - val_loss: 69.4091 - val_mean_absolute_percentage_error: 69.4091
# Epoch 61/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.1490 - mean_absolute_percentage_error: 70.1490 - val_loss: 68.1081 - val_mean_absolute_percentage_error: 68.1081
# Epoch 62/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.1352 - mean_absolute_percentage_error: 70.1352 - val_loss: 69.3558 - val_mean_absolute_percentage_error: 69.3558
# Epoch 63/100
# 14/14 [==============================] - 0s 8ms/step - loss: 69.6338 - mean_absolute_percentage_error: 69.6338 - val_loss: 63.9325 - val_mean_absolute_percentage_error: 63.9325
# Epoch 64/100
# 14/14 [==============================] - 0s 8ms/step - loss: 69.0429 - mean_absolute_percentage_error: 69.0429 - val_loss: 61.6582 - val_mean_absolute_percentage_error: 61.6582
# Epoch 65/100
# 14/14 [==============================] - 0s 8ms/step - loss: 67.0290 - mean_absolute_percentage_error: 67.0290 - val_loss: 81.1474 - val_mean_absolute_percentage_error: 81.1474
# Epoch 66/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2864 - mean_absolute_percentage_error: 70.2864 - val_loss: 64.8658 - val_mean_absolute_percentage_error: 64.8658
# Epoch 67/100
# 14/14 [==============================] - 0s 7ms/step - loss: 66.7934 - mean_absolute_percentage_error: 66.7934 - val_loss: 57.7475 - val_mean_absolute_percentage_error: 57.7475
# Epoch 68/100
# 14/14 [==============================] - 0s 7ms/step - loss: 67.6507 - mean_absolute_percentage_error: 67.6507 - val_loss: 65.9991 - val_mean_absolute_percentage_error: 65.9991
# Epoch 69/100
# 14/14 [==============================] - 0s 8ms/step - loss: 72.1754 - mean_absolute_percentage_error: 72.1754 - val_loss: 68.3366 - val_mean_absolute_percentage_error: 68.3366
# Epoch 70/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3085 - mean_absolute_percentage_error: 70.3085 - val_loss: 68.3663 - val_mean_absolute_percentage_error: 68.3663
# Epoch 71/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3889 - mean_absolute_percentage_error: 70.3889 - val_loss: 69.7579 - val_mean_absolute_percentage_error: 69.7579
# Epoch 72/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4344 - mean_absolute_percentage_error: 70.4344 - val_loss: 69.4327 - val_mean_absolute_percentage_error: 69.4327
# Epoch 73/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.6627 - mean_absolute_percentage_error: 70.6627 - val_loss: 67.4249 - val_mean_absolute_percentage_error: 67.4249
# Epoch 74/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.6613 - mean_absolute_percentage_error: 70.6613 - val_loss: 69.6758 - val_mean_absolute_percentage_error: 69.6758
# Epoch 75/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2733 - mean_absolute_percentage_error: 70.2733 - val_loss: 69.2637 - val_mean_absolute_percentage_error: 69.2637
# Epoch 76/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.8619 - mean_absolute_percentage_error: 70.8619 - val_loss: 67.7932 - val_mean_absolute_percentage_error: 67.7932
# Epoch 77/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4464 - mean_absolute_percentage_error: 70.4464 - val_loss: 70.0210 - val_mean_absolute_percentage_error: 70.0210
# Epoch 78/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6938 - mean_absolute_percentage_error: 70.6938 - val_loss: 68.9758 - val_mean_absolute_percentage_error: 68.9758
# Epoch 79/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5422 - mean_absolute_percentage_error: 70.5422 - val_loss: 70.1904 - val_mean_absolute_percentage_error: 70.1904
# Epoch 80/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3395 - mean_absolute_percentage_error: 70.3395 - val_loss: 69.2587 - val_mean_absolute_percentage_error: 69.2587
# Epoch 81/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2945 - mean_absolute_percentage_error: 70.2945 - val_loss: 69.5332 - val_mean_absolute_percentage_error: 69.5332
# Epoch 82/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4854 - mean_absolute_percentage_error: 70.4854 - val_loss: 69.1930 - val_mean_absolute_percentage_error: 69.1930
# Epoch 83/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3116 - mean_absolute_percentage_error: 70.3116 - val_loss: 69.2326 - val_mean_absolute_percentage_error: 69.2326
# Epoch 84/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3759 - mean_absolute_percentage_error: 70.3759 - val_loss: 68.6393 - val_mean_absolute_percentage_error: 68.6393
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2724 - mean_absolute_percentage_error: 70.2724 - val_loss: 68.7378 - val_mean_absolute_percentage_error: 68.7378
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2702 - mean_absolute_percentage_error: 70.2702 - val_loss: 68.8521 - val_mean_absolute_percentage_error: 68.8521
# Epoch 87/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3423 - mean_absolute_percentage_error: 70.3423 - val_loss: 68.3466 - val_mean_absolute_percentage_error: 68.3466
# Epoch 88/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2850 - mean_absolute_percentage_error: 70.2850 - val_loss: 69.7697 - val_mean_absolute_percentage_error: 69.7697
# Epoch 89/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4683 - mean_absolute_percentage_error: 70.4683 - val_loss: 70.2355 - val_mean_absolute_percentage_error: 70.2355
# Epoch 90/100
# 14/14 [==============================] - 0s 8ms/step - loss: 71.2211 - mean_absolute_percentage_error: 71.2211 - val_loss: 67.1488 - val_mean_absolute_percentage_error: 67.1488
# Epoch 91/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3029 - mean_absolute_percentage_error: 70.3029 - val_loss: 70.5897 - val_mean_absolute_percentage_error: 70.5897
# Epoch 92/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5670 - mean_absolute_percentage_error: 70.5670 - val_loss: 69.4567 - val_mean_absolute_percentage_error: 69.4567
# Epoch 93/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5933 - mean_absolute_percentage_error: 70.5933 - val_loss: 66.2950 - val_mean_absolute_percentage_error: 66.2950
# Epoch 94/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6650 - mean_absolute_percentage_error: 70.6650 - val_loss: 67.9872 - val_mean_absolute_percentage_error: 67.9872
# Epoch 95/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4594 - mean_absolute_percentage_error: 70.4594 - val_loss: 71.6747 - val_mean_absolute_percentage_error: 71.6747
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3412 - mean_absolute_percentage_error: 70.3412 - val_loss: 69.1164 - val_mean_absolute_percentage_error: 69.1164
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6497 - mean_absolute_percentage_error: 70.6497 - val_loss: 69.0613 - val_mean_absolute_percentage_error: 69.0613
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2539 - mean_absolute_percentage_error: 70.2539 - val_loss: 71.4947 - val_mean_absolute_percentage_error: 71.4947
# Epoch 99/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5158 - mean_absolute_percentage_error: 70.5158 - val_loss: 68.1948 - val_mean_absolute_percentage_error: 68.1948
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2878 - mean_absolute_percentage_error: 70.2878 - val_loss: 68.7724 - val_mean_absolute_percentage_error: 68.7724

# %%
prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# 4/4 [==============================] - 0s 3ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 68.77%
