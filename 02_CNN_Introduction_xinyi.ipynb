# %% [markdown]
# <a href="https://colab.research.google.com/github/zniihgnexy/DL_code/blob/main/02_CNN_Introduction_xinyi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Convolutional Neural Networks
#
# This tutorial addresses the basic concepts regarding Convolutional Neural Networks and their implementation using the Keras framework.
# Convolutional Neural Networks (CNNs) are a class of feed-forward artificial neural architecture. They are applied to analyse visual 2D imagery, meaning that we can feed images directly into a CNN without the need to flatten them into a 1D vector as done in the previous tutorial.
# CNNs have revolutionised the field of computer vision in the last decade. In 2012 Alex Krizhevsky introduced the AlexNet architecture to win the ImageNet Challenge (one of the most important competitions on image classification within the Computer Vision community), by reducing the top-5 error more than 10 percentage points, which was an incredible improvement at that time. As of now, CNNs are used not only on image classification but in many other computer vision tasks.
#
# ![](https://cdn-5f733ed3c1ac190fbc56ef88.closte.com/wp-content/uploads/2017/03/alexnet_small-1.png)
#
# The image above is from [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/) and shows the proposed AlexNet architecture. It is composed of 5 convolutional layers followed by 3 fully connected layers. Nowadays, we can find much deeper and more complex architectures, which outperform AlexNet on the ImageNet Challenge.

# %% [markdown]
# ## CNN Structure
#
# The basic pipeline of common CNNs consists of an image as input and a stack of convolutional layers that extract a feature representation from the input image. The final shape of the image representation is conditioned on the type of problem/task that the architecture is facing. For instance, the output of the last layer in a classification problem is a probability vector. Each dimension of the probability vector represents how likely is that the input image belongs to a specific class. However, the architecture design is up to us, and therefore, we could code a network that outputs a single value for regression problems, or that generates a new image map for semantic segmentation. Now, let's dig in a bit into CNN and introduce some layers that are widely used.

# %% [markdown]
# ### 2D Convolutional Layer
#
# The most common layer in any CNN architecture is the 2D convolutional layer. Convolutional layers are specifically designed to extract features from images or even extract features from previously extracted features. As shown in the following illustration, 2D convolutions apply the same filter to the full image. And therefore, due to its nature, 2D convolutional filters exploit the local information presented in images, making them a powerful tool for image analysis.
#
# ![](https://cdn-images-1.medium.com/max/800/1*Fw-ehcNBR9byHtho-Rxbtw.gif)
#
# Image [source](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1).
#
# The latest deep learning frameworks have made possible the integration of convolutional layers easily on our architectures with only a single line of code. We will address here how 2D convolutions work since full understanding is needed to comprehend how any CNN operates. The following images and some explanations can be further explored on the original [Irhum Shafkat's blog](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1) or in the [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/) book. Both are strongly recommended.
#
# To understand 2D convolutions, we need to define first what a kernel is. Kernels are simply matrices of numbers. The numbers on the kernels are the so-called weights, and the weights on the kernels change as we train the network. Hence, network training aims to optimise the network's parameters (update the kernel weights) such that the cost function is minimised.
#
# The 2D convolution operation takes the network's kernels and "slides" them over the input image (alike to a sliding window) as in the following image from [PyImageSearch](https://www.pyimagesearch.com/2015/03/23/sliding-windows-for-object-detection-with-python-and-opencv/) blog:
#
# ![](https://pyimagesearch.com/wp-content/uploads/2014/10/sliding_window_example.gif)
#
# In each step, the network performs an element-wise multiplication with the elements that are currently on. The results of this elementwise multiplication are added to obtain the output value of the operation. CNNs repeat previous step for all the positions of the sliding window, composing at the end the feature map. This generated feature map can go through another 2D convolutional layer and create more powerful features.
#
# >
#
# ![](https://cdn-images-1.medium.com/max/800/1*Zx-ZMLKab7VOCQTxdZ1OAw.gif)
#
# >
# The previous image shows the 2D convolution operation. Thus, the new feature values are the weighted sum of all the elements in the sliding window after the elementwise multiplication between input and kernel.  The bigger the size of the kernel is, the more feature elements contribute to the final output value. In contrast to fully connected layers, where a new feature value is a weighted sum over **all** input values, as mentioned, 2D convolutions compute features based on local areas. In other words, instead of looking at every input component, they consider only features coming from close locations.
#
# In the above example, the input image on the left has a size of 5x5 and the dimension of the resulting feature map is 3x3, showing that the size of the output maps is not always equal to the input. Hence, the output size can be computed by doing:
#
# $O = W - K + 1$,
#
# where $O$ is the output height/length, $W$ is the input height/length and $K$ is the kernel size. The output size is not only conditioned on the input size but also on the kernel size. Check in the following code cell how the output feature map shape changes as you increase the kernel size. In Keras, we define the layer by using `Conv2D` from `keras.layers` (documentation [here](https://keras.io/layers/convolutional/#conv2d)).

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1)))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 36ms/step
# Input size: (100, 100)
# Output size: (98, 98)

# %% [markdown]
# Moreover, the kernel size and the input size are not the only parameters affecting the output size. We are going to introduce two extra elements that change the size of the output map: the padding and the stride.

# %% [markdown]
# ### Adding Padding to Input Features
#
# In some tasks, such as [image translation](https://arxiv.org/pdf/1611.07004.pdf), we need the output size to be equal to the input size. The solution to that is using padding, where extra edges are added to the input features so that the dimension is not reduced after the convolutional layer. Normally those pixels have $0$ value (termed zero-padding), but depending on the application other methods could be used, e.g., reflection or symmetric padding.
#
# ![](https://cdn-images-1.medium.com/max/800/1*1okwhewf5KCtIPaFib4XaA.gif)
#
# If padding is used, the new output size can be computed by doing:
#
# $O = W - K + 2P+ 1$,
#
# where $P$ is the padding value. $P$ must be set in concordance with the kernel size if dimensionality wants to be preserved. Padding can be added to the `Conv2d` layer in Keras by using the padding argument and selecting one of the two settings: `valid`, which is the default value and means no padding; and `same`, which adapts the padding value to have the same output size as input size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Input size: (100, 100)
# Output size: (100, 100)

# %% [markdown]
# ### Using Stride in Convolutional Layers
#
# The stride operation allows the convolutional layers to skip some of the sliding windows explained above. Hence, instead of jumping one pixel apart, we can define the number of skipped elements before computing the weighting sum between the kernel's weights and input features. A stride of 1 means that features will be extracted from all windows a pixel apart, so basically, every single window is computed. A stride of 2 means that we are selecting windows 2 pixels apart, skipping every other window in the process. Strides reduce the number of computations and consequently the size of the output map. In practice, as we go deeper into the CNN, the spatial size of the feature map gets smaller while the number of channels increases. Moreover, we can further reduce the size of the feature map using pooling operations, which we introduce later in this tutorial.
#
# ![](https://cdn-images-1.medium.com/max/800/1*BMngs93_rm2_BpJFH2mS0Q.gif)
#
# If strides are used, the new output size can be computed as:
#
# $O = \dfrac{W - K + 2P}{S}+ 1$,
#
# where $S$ is the stride value. The stride is set in the layer by using the `strides` argument.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# Input size: (100, 100)
# Output size: (50, 50)

# %% [markdown]
# ## Differences Between Kernel and Filters
#
# The examples above take as input a single-channel image and compute a feature map with also one channel. However, when dealing with RGB images or feature maps, the input is no longer a single-channel map but, instead, they can have multiple channels. In the case of an RGB image, for each 2D convolution, we will need to define 3 kernels to interact with each of the image's channel colours. This group of kernels is called a filter. Thus, a filter is a collection of kernels that produces a single output.
#
# As a regular practice when defining Deep Learning models, we increase the number of filters in each convolutional layer as we go deeper into the model. Due to the element-wise multiplication, the number of kernels on each filter must be the same that the number of channels in the input feature map. Keras already deals with the number of kernels inside each filter. Keras keeps track of the input size in each convolutional layer unlike other frameworks (Pytorch or TensorFlow). Hence, in Keras, we must only decide the number of filters (output channels) in each layer.
#
# The next figure shows how the convolution is performed when having three input channels. First, one filter uses its three independent kernels to convolve with the RGB channels of the input image:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*8dx6nxpUh2JqvYWPadTwMQ.gif)
#
# Next, each of the processed feature maps is added together to obtain a single channel:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*CYB2dyR3EhFs1xNLK8ewiA.gif)
#
# Finally, we add the bias term to obtain the feature map. There is a single bias for the full output channel map. This operation is repeated for all the filters inside the convolutional layer.
#
# Now, we show how to use a `Conv2D` layer that takes an input image with 3 channels and generates an output map with 32 channels.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# ## Activation Functions
#
# As seen in previous tutorials, after a `Dense` layer we usually can find an activation function. We introduce here how to use them after `Conv2D` layers. Those activation functions are a set of operators that maps the feature values to a new set of values, the mapping depends on the function at hand. The main reason for using activation functions is that they add non-linearities to the network, giving more expressive power to the network, which will be able to reproduce more complex functions.
#
#
# The complete list of activation functions that Keras offers can be found [here](https://keras.io/activations/). We introduce here some of them:
#
# *  **Sigmoid Function** sets the output in the range (0, 1). The sigmoid function is widely used in binary classification problems since its output can be taken as a probability value. `keras.activations.sigmoid(x)`:
#
# >![](https://i.ibb.co/Ph8dsTv/sigmoid.png)
#
# *  **Tanh Function** is a logistic function as sigmoid, but the range of the tanh function is (-1, 1). Contrary to sigmoid function, where the values close to 0 are set around 0.5, in the tanh function they will be still mapped around the 0 value. `keras.activations.tanh(x)`:
#
# >![](https://i.ibb.co/68g7LpL/tanh.png)
#
# *  **ReLU Function** is the most common activation function you can find in any current CNN as in general works better than the rest. The range of this function is in \[0, inf). It sets all negative values to 0 and hence is computationally easy to implement. As a drawback, during training some neurons *die*, meaning that the output is 0 for all available data points and no gradient is propagated there. `keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)`:
#
# >![](https://i.ibb.co/Zd9H8Z4/relu.png)
#
# *  **LeakyReLU Function** is a modified version of the ReLU activation above, which attempts to solve the problem of dying neurons that ReLU has. While ReLU does not backpropagate negative values, Leaky ReLU smooths those values without setting them to 0. That allows the gradients to backpropagate through the network even for negative values. `keras.layers.LeakyReLU(alpha=0.3)`:
#
# >![](https://i.ibb.co/dmnJ6h1/leakyrelu.png)
#
# *  **Softmax Function** is another widely activation function for multi-class classification problems and usually is employed as the last activation function in the classification model. This function sets all of the output elements to the range (0, 1). However, the softmax function does not take independently the input values to map it into its probability value. Softmax Function takes an un-normalized vector, $s$, and normalizes it into a probability distribution, $p$, following the softmax expression. As the output is a probability, the output elements add up to 1. `keras.activations.softmax(x, axis=-1)`. Thus, the output value $p_i$ is computed as:
#
# > $p_{i} = \dfrac{e^{s_i}}{\sum_{\substack{j}}^{N} e^{s_j}}$

# %% [markdown]
# The following example shows the feature maps before and after of the ReLU activation function. All values that are negative are set to 0 after the activation function.

# %%
import numpy as np
import keras
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential, Model
from keras.layers import Conv2D, Activation

# Generate dummy data
input_feature = np.random.random((1, 3, 3, 1)) - 0.5

# input: 3x3 image with 1 channel -> (3, 3, 1) tensor.
# This applies a 1 convolution filter of size 3x3 each.
# This applies a ReLU activation function
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(3, 3, 1), padding='same', strides=1, name='conv'))
model.add(Activation('relu'))

model_before_ReLU = Model(inputs=model.input, outputs=model.get_layer('conv').output)

output_feature = model_before_ReLU.predict(input_feature)
output_ReLu_feature = model.predict(input_feature)

print('Output Network without activation function')
print(output_feature)

print('')
print('Output Network after ReLU activation function')
print(output_ReLu_feature)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# Output Network without activation function
# [[[[ 0.40398538]
#    [ 0.01319184]
#    [-0.06418546]]
#
#   [[-0.16383685]
#    [-0.40022048]
#    [-0.00307947]]
#
#   [[-0.60181457]
#    [ 0.14866754]
#    [-0.14245063]]]]
#
# Output Network after ReLU activation function
# [[[[0.40398538]
#    [0.01319184]
#    [0.        ]]
#
#   [[0.        ]
#    [0.        ]
#    [0.        ]]
#
#   [[0.        ]
#    [0.14866754]
#    [0.        ]]]]

# %% [markdown]
# ## Pooling Layer
#
# It is a common practice to insert a pooling layer between convolutional layers in CNNs. In a standard CNN architecture, we set the feature sizes to become smaller progressively to reduce the computation in the networks, and to merge the information from different spatial locations. To reduce the feature map sizes, we can either use bigger stride size in the convolutional layers or we can use pooling layers. Pooling layers perform a spatial sliding window and apply an operation to reduce the spatial size. Those operations vary depending on the architecture, being the max, mean and min pooling the most typical ones. Here, we will explain the max pooling, although all the others work similarly. Max pooling keeps only the max value in a neighbourhood, where the neighbourhood is defined by the size of the kernel. Let's visualise it, the next example shows the result of a Max Pooling layer with a 2x2 kernel and a stride of 2.
#
# ![](https://i.ibb.co/Xp454S4/MaxPool.png)
#
# As in convolutional layers, the final size is conditioned to the stride size of the pooling layer. However, contrary to convolutional layers, pooling layers operate independently on each of the input channels, without modifying the depth of the feature maps. To add max pooling to our model we need to import `MaxPooling2d` from `keras.layers` and define the stride and pooling size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=1 applies applies stride of 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 [==============================] - 0s 45ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# # Example: Classification on MNIST
#
# As opposed to the *Introduction to Keras* tutorial, in this section, we show how to perform image classification when the input data is a 2D image instead of a flat 1D vector.
#
# As discussed above, Convolutional Neural Networks aim to extract and exploit the local relationships on 2D maps, hence, CNNs are much more convenient for images than Multi-layer Perceptron models.
#
# First of all, we load the MNIST dataset from Keras' framework. The definition of the data is almost identical than in the Keras tutorial, although this time we are not reshaping the input images into a 1D vector.

# %%
# !pip install keras.utils
# Out:
# Requirement already satisfied: keras.utils in /usr/local/lib/python3.10/dist-packages (1.0.13)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras.utils) (2.15.0)

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from tensorflow.python.keras.utils import np_utils
from keras.datasets import mnist
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import numpy as np

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

shape = x_train.shape

# Normalize and reshape the input images
x_train = np.expand_dims(x_train.astype('float32'), -1)
x_test = np.expand_dims(x_test.astype('float32'), -1)

x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))
# Out:
# Image shape: (28, 28, 1)
# Total number of training samples: 60000
# Total number of validation samples: 10000

# %% [markdown]
# As illustrated in the cell, this time the input image before the model is 28x28x1.
#
# Now we can define a model composed of convolutional layers, activation functions, and maxpool operators:

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

# %% [markdown]
# As explained in the previous tutorial, in a classification problem, the output of the model is a probability vector. Each dimension of the vector indicates how likely is that the input image belongs to a specific class.
#
# Up to now, the resulting feature map of the model is a map with the shape *Batch x Weight' x Height' x Channel*, and it needs to be mapped into a vector with shape *Batch x Num Classes*. A common technique to process this mapping is to add a Flatten layer that will reshape the feature map to *Batch x (Weight' * Height' * Channel)*. Following the Flatten layer, we add a dense layer which maps this new feature map to the desired output size.

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# %% [markdown]
# Let's visualize the output shape in each layer.

# %%
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 28, 28, 16)        160
#
#  activation_9 (Activation)   (None, 28, 28, 16)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 14, 14, 16)        0
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 14, 14, 16)        2320
#
#  activation_10 (Activation)  (None, 14, 14, 16)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 7, 7, 16)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_1 (Dense)             (None, 10)                7850
#
#  activation_11 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 10330 (40.35 KB)
# Trainable params: 10330 (40.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Finally, we can train our CNN and check its performance on MNIST.

# %%
# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)
# opt = tf.keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=10,  verbose=0)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Validation loss: 0.08112094551324844
# Validation accuracy: 0.9739000201225281

# %% [markdown]
# # Coursework

# %% [markdown]
# ## Task 1: Classification
#
# At this point, we know what is a CNN, how they work, and the components needed to design them. In this first task, we want you to create a CNN that is able to outperform the Multi-layer Perceptron model from Tutorial 1. For the first part of the coursework, we train on CIFAR10, a  classical dataset for image classification. Note that in these tutorials, we mainly use the official test sets of several standard datasets as our validation data. The reason we use the given test sets as validation data for the tutorials is that is an easy way to make sure that we all work with the same split and report results using the same data. However, in a proper machine learning setup, your validation set should be separate from the test set, so you can tune the model/parameters on the validation set and then check the final performance in the test set. Thus, even though the variables are `x_test` and `y_test`, they represent our validation set.
#
# Let's first load the dataset and visualise some examples:

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(X_train.shape[1:]))
print('Total number of training samples: {0}'.format(X_train.shape[0]))
print('Total number of validation samples: {0}'.format(X_test.shape[0]))

# Let's visualize some examples
N=5
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
items = list(range(0, 10))
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    axes[row,col].imshow(X_train[idx], cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    y_target = int(y_train[idx])
    target = str(items[y_target])
    axes[row,col].set_title(target)
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000

# %% [markdown]
# CIFAR10 contains 50,000 32x32 color training images, labeled over 10 categories and 10,000 test images. As mentioned, we use those test images as our validation set in this tutorial. We need to preprocess the images for the 1D neural network defined in the previous tutorial:

# %%
# Preprocess dataset for a 1D neural network
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the image
X_train /= 255
X_test /= 255

X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2]*3)
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]*3)

print('New X_train shape: {0}'.format(X_train_flatten.shape))

Y_train_class = np_utils.to_categorical(y_train, 10)
Y_test_class = np_utils.to_categorical(y_test, 10)

print('New Y_train shape: {0}'.format(Y_train_class.shape))
# Out:
# New X_train shape: (50000, 3072)
# New Y_train shape: (50000, 10)

# %% [markdown]
# Now, we are ready to define the Multi-layer Perceptron model and train it.

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(X_train_flatten.shape[1:])))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(X_train_flatten, Y_train_class, batch_size=32, epochs=20)

score = model.evaluate(X_test_flatten, Y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.9372 - accuracy: 0.2936
# Epoch 2/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.7503 - accuracy: 0.3682
# Epoch 3/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6762 - accuracy: 0.3974
# Epoch 4/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6218 - accuracy: 0.4176
# Epoch 5/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5815 - accuracy: 0.4342
# Epoch 6/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5505 - accuracy: 0.4463
# Epoch 7/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5239 - accuracy: 0.4540
# Epoch 8/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.5002 - accuracy: 0.4631
# Epoch 9/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4785 - accuracy: 0.4694
# Epoch 10/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4586 - accuracy: 0.4768
# Epoch 11/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4418 - accuracy: 0.4826
# Epoch 12/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4253 - accuracy: 0.4908
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4100 - accuracy: 0.4941
# Epoch 14/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3959 - accuracy: 0.5008
# Epoch 15/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3829 - accuracy: 0.5054
# Epoch 16/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3691 - accuracy: 0.5090
# Epoch 17/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3573 - accuracy: 0.5149
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3460 - accuracy: 0.5172
# Epoch 19/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3346 - accuracy: 0.5206
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3237 - accuracy: 0.5268
# Validation loss: 1.4776495695114136
# Validation accuracy: 0.4749000072479248

# %% [markdown]
# ### Problem Definition
#
# In this exercise, you are asked to test several CNN architectures in the code provided below. Do not modify the optimizer, loss used or parameters related to the training such as the learning rate, they will be investigated in future tutorials. You must focus on the architecture itself: number of convolutional layers, number of filters in every layer, activation functions, pooling operators, among others. Batch Normalization and Dropout layers, which are quite used in CNN architectures, will be also investigated in a future tutorial so you do not have to discuss them.
#
#
# **Report**:
# *   Present a bar figure with the training and validation accuracies for different design choices. Discuss only the parameters that have a significant influence on the network's performance. Explain any discrepancy between training and validation accuracies.
# *   Present a sketch that introduces your best architecture. See some examples on how to display networks in [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)


# . . .
model = Sequential()

model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# . . .


# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# Epoch 1/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 2.0293 - accuracy: 0.2826
# Epoch 2/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.7534 - accuracy: 0.3905
# Epoch 3/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.6317 - accuracy: 0.4293
# Epoch 4/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.5536 - accuracy: 0.4544
# Epoch 5/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4974 - accuracy: 0.4718
# Epoch 6/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.4555 - accuracy: 0.4875
# Epoch 7/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.4233 - accuracy: 0.4989
# Epoch 8/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3967 - accuracy: 0.5071
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3760 - accuracy: 0.5146
# Epoch 10/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3578 - accuracy: 0.5225
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.3413 - accuracy: 0.5273
# Epoch 12/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3262 - accuracy: 0.5342
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3113 - accuracy: 0.5394
# Epoch 14/20
# 1563/1563 [==============================] - 5s 3ms/step - loss: 1.2977 - accuracy: 0.5426
# Epoch 15/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2840 - accuracy: 0.5490
# Epoch 16/20
# 1563/1563 [==============================] - 5s 4ms/step - loss: 1.2727 - accuracy: 0.5549
# Epoch 17/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2600 - accuracy: 0.5593
# Epoch 18/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2493 - accuracy: 0.5638
# Epoch 19/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2386 - accuracy: 0.5681
# Epoch 20/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2286 - accuracy: 0.5731
# Validation loss: 1.249979019165039
# Validation accuracy: 0.5615000128746033

# %%
print(x_train.size)
print('Input size: ({:}, {:}, {:})'.format(x_train.shape[1], x_train.shape[2], x_train.shape[3]))

print(x_test.size)
print('Input size: ({:}, {:}, {:})'.format(x_test.shape[1], x_test.shape[2], x_test.shape[3]))
# Out:
# 153600000
# Input size: (32, 32, 3)
# 30720000
# Input size: (32, 32, 3)

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

# . . .

model = Sequential()

#layer 1
model.add(Conv2D(96, (11,11), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

#layer 2
model.add(Conv2D(96, (5,5), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3,3)))

#layer 3
model.add(Conv2D(256, (3,3), padding='same'))
model.add(Activation('relu'))

#layer 4
model.add(Conv2D(256, (3,3), padding='same', strides=1))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))

# . . .


# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/rmsprop.py:144: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/20
# Exception ignored in: <function _xla_gc_callback at 0x78648c8a2dd0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 97, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:
# 1563/1563 [==============================] - 41s 7ms/step - loss: 1.7145 - accuracy: 0.3759
# Epoch 2/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3855 - accuracy: 0.5034
# Epoch 3/20
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.2214 - accuracy: 0.5643
# Epoch 4/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0955 - accuracy: 0.6144
# Epoch 5/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9934 - accuracy: 0.6513
# Epoch 6/20
# 1563/1563 [==============================] - 12s 8ms/step - loss: 0.9113 - accuracy: 0.6791
# Epoch 7/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8405 - accuracy: 0.7043
# Epoch 8/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7736 - accuracy: 0.7299
# Epoch 9/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7163 - accuracy: 0.7491
# Epoch 10/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6584 - accuracy: 0.7700
# Epoch 11/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6059 - accuracy: 0.7892
# Epoch 12/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5532 - accuracy: 0.8072
# Epoch 13/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.5060 - accuracy: 0.8255
# Epoch 14/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4574 - accuracy: 0.8424
# Epoch 15/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.4150 - accuracy: 0.8571
# Epoch 16/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3720 - accuracy: 0.8707
# Epoch 17/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.3319 - accuracy: 0.8855
# Epoch 18/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2917 - accuracy: 0.8994
# Epoch 19/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2578 - accuracy: 0.9109
# Epoch 20/20
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.2265 - accuracy: 0.9214
# Validation loss: 1.1784065961837769
# Validation accuracy: 0.70660001039505

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization
from tensorflow.python.keras.utils import np_utils
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples : {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=16, input_shape=x_train.shape[1:], kernel_size=(11,11),\
 strides=(4,4), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation before passing it to the next layer
# model.add(BatchNormalization())

# 3rd Convolutional Layer
model.add(Conv2D(filters=96, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Batch Normalisation
# model.add(BatchNormalization())

# 5th Convolutional Layer
model.add(Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='same'))
model.add(Activation('relu'))
# Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
# Batch Normalisation
# model.add(BatchNormalization())

# Passing it to a dense layer
model.add(Flatten())
# 1st Dense Layer
model.add(Dense(256))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))
# Batch Normalisation
# model.add(BatchNormalization())

# 2nd Dense Layer
model.add(Dense(256))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
# model.add(BatchNormalization())

# 3rd Dense Layer
model.add(Dense(100))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))
# Batch Normalisation
# model.add(BatchNormalization())

# Output Layer
model.add(Dense(10))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = tf.keras.optimizers.legacy.RMSprop(learning_rate=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=20)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples : 10000
# Epoch 1/20
# 1563/1563 [==============================] - 9s 5ms/step - loss: 2.1102 - accuracy: 0.1968
# Epoch 2/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.8592 - accuracy: 0.3011
# Epoch 3/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.7311 - accuracy: 0.3621
# Epoch 4/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.6394 - accuracy: 0.4015
# Epoch 5/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.5774 - accuracy: 0.4259
# Epoch 6/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5280 - accuracy: 0.4478
# Epoch 7/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.4805 - accuracy: 0.4665
# Epoch 8/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4459 - accuracy: 0.4811
# Epoch 9/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.4144 - accuracy: 0.4930
# Epoch 10/20
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.3838 - accuracy: 0.5064
# Epoch 11/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3548 - accuracy: 0.5199
# Epoch 12/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3326 - accuracy: 0.5256
# Epoch 13/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3109 - accuracy: 0.5359
# Epoch 14/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.2881 - accuracy: 0.5439
# Epoch 15/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2725 - accuracy: 0.5526
# Epoch 16/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2540 - accuracy: 0.5578
# Epoch 17/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2334 - accuracy: 0.5682
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.2173 - accuracy: 0.5728
# Epoch 19/20
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1981 - accuracy: 0.5803
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.1847 - accuracy: 0.5871
# Validation loss: 1.2387131452560425
# Validation accuracy: 0.5619000196456909

# %% [markdown]
# ---
# ---
#
# ## Task 2: Regression
#
# Now we face a regression task instead of a classification problem. Loss function, activations, and dataset will change in the following task. Thus, instead of having one vector with the probabilities of each class, in this regression problem, the output is a single scalar.
#
# For this second task, we chose the task of estimating house prices based on input images. To get the data run the following script, which clones Ahmed and Moustafa’s [repository](https://github.com/emanhamed/Houses-dataset) into colmap.

# %%
# !git clone https://github.com/emanhamed/Houses-dataset
# %cd /content/Houses-dataset/Houses\ Dataset
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165
# Receiving objects: 100% (2166/2166), 176.26 MiB | 27.27 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# Updating files: 100% (2144/2144), done.
# /content/Houses-dataset/Houses Dataset

# %% [markdown]
# This dataset contains four images of the house (kitchen, frontal, bedroom and bathroom), and attributes (number of bedrooms, number of bathrooms, zip code...). For our exercise, we only use the images of the house. We start with front door images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed

house_section = 'bathroom' # select between: kitchen, frontal, bedroom or bathroom
print('We have selected {} images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.'.format(house_section))
images = []
for i_im in range(1, 536):
  image = cv2.imread(str(i_im)+'_'+house_section+'.jpg')
  image = cv2.resize(image, (64, 64))
  images.append(image)

labels = []
f = open('HousesInfo.txt', "r")
for x in f:
  label = (x).split(' ')[-1].split('\n')[0]
  labels.append(label)

# Let's visualize some examples
N=3
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    tmp = cv2.cvtColor(images[idx],cv2.COLOR_BGR2RGB)
    axes[row,col].imshow(tmp, cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    target = int(labels[idx])
    axes[row,col].set_title(str(target) + '$')
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# We have selected bathroom images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.

# %% [markdown]
# Prepare the dataset for training the model:

# %%
seed(1234)
images = np.asarray(images).astype('float32')
labels = np.asarray(labels).astype('float32')

# Normalize the image
max_price = labels.max()
images /= 255.
labels /= max_price

random_idx = np.random.permutation(len(images))
images = images[random_idx]
labels = labels[random_idx]

split_size_val = int(0.8*len(images))
X_train, X_val = images[:split_size_val], images[split_size_val+1:]
Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

# Print shape of training and val images
print('X_train image shape: {0}'.format(X_train.shape))
print('X_val image shape: {0}'.format(X_val.shape))

# Print shape of training and val labels
print('Y_train labels shape: {0}'.format(Y_train.shape))
print('Y_val labels shape: {0}'.format(Y_val.shape))
# Out:
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)

# %% [markdown]
# ### Problem Definition
#
# Similar to the previous task, you are asked to design a CNN architecture able to perform the estimation of house prices based on the `frontal` house image. Design a new model by changing parameters such as the number of convolutional layers, activation functions, strides, or pooling operators, among others.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .

model.add(Conv2D(96, (3,3), padding='same', input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('softmax'))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_83 (Conv2D)          (None, 64, 64, 96)        2688
#
#  activation_186 (Activation  (None, 64, 64, 96)        0
#  )
#
#  max_pooling2d_62 (MaxPooli  (None, 32, 32, 96)        0
#  ng2D)
#
#  conv2d_84 (Conv2D)          (None, 32, 32, 16)        13840
#
#  activation_187 (Activation  (None, 32, 32, 16)        0
#  )
#
#  max_pooling2d_63 (MaxPooli  (None, 16, 16, 16)        0
#  ng2D)
#
#  flatten_48 (Flatten)        (None, 4096)              0
#
#  dense_123 (Dense)           (None, 1)                 4097
#
#  activation_188 (Activation  (None, 1)                 0
#  )
#
#  flatten_49 (Flatten)        (None, 1)                 0
#
#  dense_124 (Dense)           (None, 1)                 2
#
#  activation_189 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 20627 (80.57 KB)
# Trainable params: 20627 (80.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 2s 47ms/step - loss: 2741.3933 - mean_absolute_percentage_error: 2741.3933 - val_loss: 2327.4187 - val_mean_absolute_percentage_error: 2327.4187
# Epoch 2/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2681.5918 - mean_absolute_percentage_error: 2681.5918 - val_loss: 2276.5767 - val_mean_absolute_percentage_error: 2276.5767
# Epoch 3/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2622.0269 - mean_absolute_percentage_error: 2622.0269 - val_loss: 2225.0015 - val_mean_absolute_percentage_error: 2225.0015
# Epoch 4/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2562.2385 - mean_absolute_percentage_error: 2562.2385 - val_loss: 2173.9607 - val_mean_absolute_percentage_error: 2173.9607
# Epoch 5/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2502.6821 - mean_absolute_percentage_error: 2502.6821 - val_loss: 2123.7566 - val_mean_absolute_percentage_error: 2123.7566
# Epoch 6/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2443.3640 - mean_absolute_percentage_error: 2443.3640 - val_loss: 2072.8027 - val_mean_absolute_percentage_error: 2072.8027
# Epoch 7/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2384.0171 - mean_absolute_percentage_error: 2384.0171 - val_loss: 2021.8800 - val_mean_absolute_percentage_error: 2021.8800
# Epoch 8/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2323.3984 - mean_absolute_percentage_error: 2323.3984 - val_loss: 1972.2104 - val_mean_absolute_percentage_error: 1972.2104
# Epoch 9/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2264.5371 - mean_absolute_percentage_error: 2264.5371 - val_loss: 1919.6805 - val_mean_absolute_percentage_error: 1919.6805
# Epoch 10/100
# 14/14 [==============================] - 0s 10ms/step - loss: 2203.8186 - mean_absolute_percentage_error: 2203.8186 - val_loss: 1869.5404 - val_mean_absolute_percentage_error: 1869.5404
# Epoch 11/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2146.1221 - mean_absolute_percentage_error: 2146.1221 - val_loss: 1818.5566 - val_mean_absolute_percentage_error: 1818.5566
# Epoch 12/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2085.7346 - mean_absolute_percentage_error: 2085.7346 - val_loss: 1768.9941 - val_mean_absolute_percentage_error: 1768.9941
# Epoch 13/100
# 14/14 [==============================] - 0s 9ms/step - loss: 2026.5245 - mean_absolute_percentage_error: 2026.5245 - val_loss: 1716.7223 - val_mean_absolute_percentage_error: 1716.7223
# Epoch 14/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1966.5687 - mean_absolute_percentage_error: 1966.5687 - val_loss: 1665.8140 - val_mean_absolute_percentage_error: 1665.8140
# Epoch 15/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1907.9517 - mean_absolute_percentage_error: 1907.9517 - val_loss: 1615.7869 - val_mean_absolute_percentage_error: 1615.7869
# Epoch 16/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1849.3497 - mean_absolute_percentage_error: 1849.3497 - val_loss: 1566.0688 - val_mean_absolute_percentage_error: 1566.0688
# Epoch 17/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1790.2108 - mean_absolute_percentage_error: 1790.2108 - val_loss: 1515.5867 - val_mean_absolute_percentage_error: 1515.5867
# Epoch 18/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1732.1216 - mean_absolute_percentage_error: 1732.1216 - val_loss: 1465.2460 - val_mean_absolute_percentage_error: 1465.2460
# Epoch 19/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1673.8726 - mean_absolute_percentage_error: 1673.8726 - val_loss: 1415.1605 - val_mean_absolute_percentage_error: 1415.1605
# Epoch 20/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1615.4307 - mean_absolute_percentage_error: 1615.4307 - val_loss: 1365.5503 - val_mean_absolute_percentage_error: 1365.5503
# Epoch 21/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1556.2993 - mean_absolute_percentage_error: 1556.2993 - val_loss: 1316.6462 - val_mean_absolute_percentage_error: 1316.6462
# Epoch 22/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1499.1481 - mean_absolute_percentage_error: 1499.1481 - val_loss: 1266.4900 - val_mean_absolute_percentage_error: 1266.4900
# Epoch 23/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1439.9884 - mean_absolute_percentage_error: 1439.9884 - val_loss: 1216.2684 - val_mean_absolute_percentage_error: 1216.2684
# Epoch 24/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1381.6792 - mean_absolute_percentage_error: 1381.6792 - val_loss: 1166.1281 - val_mean_absolute_percentage_error: 1166.1281
# Epoch 25/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1321.7820 - mean_absolute_percentage_error: 1321.7820 - val_loss: 1117.3724 - val_mean_absolute_percentage_error: 1117.3724
# Epoch 26/100
# 14/14 [==============================] - 0s 9ms/step - loss: 1264.0387 - mean_absolute_percentage_error: 1264.0387 - val_loss: 1065.7869 - val_mean_absolute_percentage_error: 1065.7869
# Epoch 27/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1204.5400 - mean_absolute_percentage_error: 1204.5400 - val_loss: 1013.7093 - val_mean_absolute_percentage_error: 1013.7093
# Epoch 28/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1144.0710 - mean_absolute_percentage_error: 1144.0710 - val_loss: 963.0373 - val_mean_absolute_percentage_error: 963.0373
# Epoch 29/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1084.7664 - mean_absolute_percentage_error: 1084.7664 - val_loss: 912.5145 - val_mean_absolute_percentage_error: 912.5145
# Epoch 30/100
# 14/14 [==============================] - 0s 10ms/step - loss: 1024.7576 - mean_absolute_percentage_error: 1024.7576 - val_loss: 861.6360 - val_mean_absolute_percentage_error: 861.6360
# Epoch 31/100
# 14/14 [==============================] - 0s 10ms/step - loss: 965.2615 - mean_absolute_percentage_error: 965.2615 - val_loss: 810.2102 - val_mean_absolute_percentage_error: 810.2102
# Epoch 32/100
# 14/14 [==============================] - 0s 10ms/step - loss: 905.2761 - mean_absolute_percentage_error: 905.2761 - val_loss: 760.1419 - val_mean_absolute_percentage_error: 760.1419
# Epoch 33/100
# 14/14 [==============================] - 0s 9ms/step - loss: 846.9670 - mean_absolute_percentage_error: 846.9670 - val_loss: 709.1904 - val_mean_absolute_percentage_error: 709.1904
# Epoch 34/100
# 14/14 [==============================] - 0s 10ms/step - loss: 787.2831 - mean_absolute_percentage_error: 787.2831 - val_loss: 659.7607 - val_mean_absolute_percentage_error: 659.7607
100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2715 - mean_absolute_percentage_error: 70.2715 - val_loss: 69.6666 - val_mean_absolute_percentage_error: 69.6666
# Epoch 53/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4511 - mean_absolute_percentage_error: 70.4511 - val_loss: 68.4104 - val_mean_absolute_percentage_error: 68.4104
# Epoch 54/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3266 - mean_absolute_percentage_error: 70.3266 - val_loss: 69.0051 - val_mean_absolute_percentage_error: 69.0051
# Epoch 55/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2499 - mean_absolute_percentage_error: 70.2499 - val_loss: 69.2169 - val_mean_absolute_percentage_error: 69.2169
# Epoch 56/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2320 - mean_absolute_percentage_error: 70.2320 - val_loss: 69.0746 - val_mean_absolute_percentage_error: 69.0746
# Epoch 57/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2862 - mean_absolute_percentage_error: 70.2862 - val_loss: 69.2224 - val_mean_absolute_percentage_error: 69.2224
# Epoch 58/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2497 - mean_absolute_percentage_error: 70.2497 - val_loss: 68.9999 - val_mean_absolute_percentage_error: 68.9999
# Epoch 59/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2745 - mean_absolute_percentage_error: 70.2745 - val_loss: 69.0857 - val_mean_absolute_percentage_error: 69.0857
# Epoch 60/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2266 - mean_absolute_percentage_error: 70.2266 - val_loss: 69.2991 - val_mean_absolute_percentage_error: 69.2991
# Epoch 61/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2305 - mean_absolute_percentage_error: 70.2305 - val_loss: 69.1318 - val_mean_absolute_percentage_error: 69.1318
# Epoch 62/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2678 - mean_absolute_percentage_error: 70.2678 - val_loss: 69.6761 - val_mean_absolute_percentage_error: 69.6761
# Epoch 63/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2493 - mean_absolute_percentage_error: 70.2493 - val_loss: 69.2129 - val_mean_absolute_percentage_error: 69.2129
# Epoch 64/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2328 - mean_absolute_percentage_error: 70.2328 - val_loss: 69.4223 - val_mean_absolute_percentage_error: 69.4223
# Epoch 65/100
# 14/14 [==============================] - 0s 13ms/step - loss: 70.2208 - mean_absolute_percentage_error: 70.2208 - val_loss: 68.8123 - val_mean_absolute_percentage_error: 68.8123
# Epoch 66/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2914 - mean_absolute_percentage_error: 70.2914 - val_loss: 68.5254 - val_mean_absolute_percentage_error: 68.5254
# Epoch 67/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2545 - mean_absolute_percentage_error: 70.2545 - val_loss: 69.6033 - val_mean_absolute_percentage_error: 69.6033
# Epoch 68/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2687 - mean_absolute_percentage_error: 70.2687 - val_loss: 69.9689 - val_mean_absolute_percentage_error: 69.9689
# Epoch 69/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.3241 - mean_absolute_percentage_error: 70.3241 - val_loss: 70.0178 - val_mean_absolute_percentage_error: 70.0178
# Epoch 70/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.4804 - mean_absolute_percentage_error: 70.4804 - val_loss: 70.5134 - val_mean_absolute_percentage_error: 70.5134
# Epoch 71/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3297 - mean_absolute_percentage_error: 70.3297 - val_loss: 70.0569 - val_mean_absolute_percentage_error: 70.0569
# Epoch 72/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2648 - mean_absolute_percentage_error: 70.2648 - val_loss: 69.4908 - val_mean_absolute_percentage_error: 69.4908
# Epoch 73/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3306 - mean_absolute_percentage_error: 70.3306 - val_loss: 68.5099 - val_mean_absolute_percentage_error: 68.5099
# Epoch 74/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3777 - mean_absolute_percentage_error: 70.3777 - val_loss: 69.1917 - val_mean_absolute_percentage_error: 69.1917
# Epoch 75/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2669 - mean_absolute_percentage_error: 70.2669 - val_loss: 69.4117 - val_mean_absolute_percentage_error: 69.4117
# Epoch 76/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.5855 - mean_absolute_percentage_error: 70.5855 - val_loss: 68.0414 - val_mean_absolute_percentage_error: 68.0414
# Epoch 77/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3478 - mean_absolute_percentage_error: 70.3478 - val_loss: 69.1604 - val_mean_absolute_percentage_error: 69.1604
# Epoch 78/100
# 14/14 [==============================] - 0s 13ms/step - loss: 70.3915 - mean_absolute_percentage_error: 70.3915 - val_loss: 68.9022 - val_mean_absolute_percentage_error: 68.9022
# Epoch 79/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3287 - mean_absolute_percentage_error: 70.3287 - val_loss: 69.6057 - val_mean_absolute_percentage_error: 69.6057
# Epoch 80/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2387 - mean_absolute_percentage_error: 70.2387 - val_loss: 69.7085 - val_mean_absolute_percentage_error: 69.7085
# Epoch 81/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2847 - mean_absolute_percentage_error: 70.2847 - val_loss: 69.7899 - val_mean_absolute_percentage_error: 69.7899
# Epoch 82/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.3405 - mean_absolute_percentage_error: 70.3405 - val_loss: 69.4227 - val_mean_absolute_percentage_error: 69.4227
# Epoch 83/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2295 - mean_absolute_percentage_error: 70.2295 - val_loss: 69.0896 - val_mean_absolute_percentage_error: 69.0896
# Epoch 84/100
# 14/14 [==============================] - 0s 14ms/step - loss: 70.2960 - mean_absolute_percentage_error: 70.2960 - val_loss: 68.8518 - val_mean_absolute_percentage_error: 68.8518
# Epoch 85/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2464 - mean_absolute_percentage_error: 70.2464 - val_loss: 68.9694 - val_mean_absolute_percentage_error: 68.9694
# Epoch 86/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2400 - mean_absolute_percentage_error: 70.2400 - val_loss: 69.0430 - val_mean_absolute_percentage_error: 69.0430
# Epoch 87/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2755 - mean_absolute_percentage_error: 70.2755 - val_loss: 68.7840 - val_mean_absolute_percentage_error: 68.7840
# Epoch 88/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2580 - mean_absolute_percentage_error: 70.2580 - val_loss: 69.2477 - val_mean_absolute_percentage_error: 69.2477
# Epoch 89/100
# 14/14 [==============================] - 0s 16ms/step - loss: 70.3960 - mean_absolute_percentage_error: 70.3960 - val_loss: 70.1357 - val_mean_absolute_percentage_error: 70.1357
# Epoch 90/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.7303 - mean_absolute_percentage_error: 70.7303 - val_loss: 68.0948 - val_mean_absolute_percentage_error: 68.0948
# Epoch 91/100
# 14/14 [==============================] - 0s 13ms/step - loss: 70.2444 - mean_absolute_percentage_error: 70.2444 - val_loss: 69.6366 - val_mean_absolute_percentage_error: 69.6366
# Epoch 92/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.4765 - mean_absolute_percentage_error: 70.4765 - val_loss: 70.1836 - val_mean_absolute_percentage_error: 70.1836
# Epoch 93/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2519 - mean_absolute_percentage_error: 70.2519 - val_loss: 68.0845 - val_mean_absolute_percentage_error: 68.0845
# Epoch 94/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4849 - mean_absolute_percentage_error: 70.4849 - val_loss: 68.0210 - val_mean_absolute_percentage_error: 68.0210
# Epoch 95/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.1674 - mean_absolute_percentage_error: 70.1674 - val_loss: 70.5848 - val_mean_absolute_percentage_error: 70.5848
# Epoch 96/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4520 - mean_absolute_percentage_error: 70.4520 - val_loss: 70.4756 - val_mean_absolute_percentage_error: 70.4756
# Epoch 97/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.5079 - mean_absolute_percentage_error: 70.5079 - val_loss: 68.7982 - val_mean_absolute_percentage_error: 68.7982
# Epoch 98/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2122 - mean_absolute_percentage_error: 70.2122 - val_loss: 69.5734 - val_mean_absolute_percentage_error: 69.5734
# Epoch 99/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2898 - mean_absolute_percentage_error: 70.2898 - val_loss: 69.4780 - val_mean_absolute_percentage_error: 69.4780
# Epoch 100/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2314 - mean_absolute_percentage_error: 70.2314 - val_loss: 69.2121 - val_mean_absolute_percentage_error: 69.2121

# %% [markdown]
# The metric used in this problem to evaluate the performance is the same we used for training the model, the mean absolute percentage error. Mean absolute percentage error is defined as $\frac{100}{n} \sum_n \frac{|\hat{y} - y|}{|y|}$ where $y$ is the ground-truth, $\hat{y}$ is the estimation of the model and `n` the number of elements in the set we are evaluating.

# %%
prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# 4/4 [==============================] - 0s 4ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 69.21%

# %% [markdown]
# **Report**:
#
#
# *   Propose a CNN architecture that has an estimation error in the validation set below 75%.
# *   Present a figure showing the training and validation loss vs the number of training epochs for different architectural design choices. Discuss the gap between the training and validation loss depending on the proposed architecture.
# *   Report a table with results when using any of the other images from the house (kitchen, bedroom, and bathroom).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)
import io
from IPython.display import display, Image
import tempfile

chanDim = -1
model = Sequential()

# . . .
model.add(Conv2D(32, (3,3), padding='same', input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(128, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(650))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(784))
model.add(Activation('relu'))

model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)

# Extract training and validation loss from the history
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create a plot for training and validation loss vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(training_loss) + 1), training_loss, label='Training Loss')
plt.plot(range(1, len(validation_loss) + 1), validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))

with tempfile.NamedTemporaryFile(suffix='.png', delete=True) as temp_file:
    # Use plot_model to save the model diagram to the temporary file
    tf.keras.utils.plot_model(
        model,
        to_file=temp_file.name,
        show_shapes=True,
        show_dtype=False,
        show_layer_names=True,
        rankdir="TB",
        expand_nested=True,
        dpi=96,
        layer_range=None,
        show_layer_activations=True
    )

    # Read the image from the temporary file and display it
    temp_file.seek(0)  # Move to the beginning of the file before reading
    display(Image(temp_file.read()))
# Out:
# Model: "sequential_74"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_115 (Conv2D)         (None, 64, 64, 32)        896
#
#  activation_292 (Activation  (None, 64, 64, 32)        0
#  )
#
#  max_pooling2d_94 (MaxPooli  (None, 32, 32, 32)        0
#  ng2D)
#
#  conv2d_116 (Conv2D)         (None, 32, 32, 64)        18496
#
#  activation_293 (Activation  (None, 32, 32, 64)        0
#  )
#
#  max_pooling2d_95 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  conv2d_117 (Conv2D)         (None, 16, 16, 128)       73856
#
#  activation_294 (Activation  (None, 16, 16, 128)       0
#  )
#
#  max_pooling2d_96 (MaxPooli  (None, 8, 8, 128)         0
#  ng2D)
#
#  flatten_91 (Flatten)        (None, 8192)              0
#
#  dense_218 (Dense)           (None, 650)               5325450
#
#  activation_295 (Activation  (None, 650)               0
#  )
#
#  dropout_88 (Dropout)        (None, 650)               0
#
#  dense_219 (Dense)           (None, 784)               510384
#
#  activation_296 (Activation  (None, 784)               0
#  )
#
#  flatten_92 (Flatten)        (None, 784)               0
#
#  dense_220 (Dense)           (None, 1)                 785
#
#  activation_297 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 5929867 (22.62 MB)
# Trainable params: 5929867 (22.62 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 3s 46ms/step - loss: 716.3374 - mean_absolute_percentage_error: 716.3374 - val_loss: 63.3616 - val_mean_absolute_percentage_error: 63.3616
# Epoch 2/100
# 14/14 [==============================] - 0s 24ms/step - loss: 71.6260 - mean_absolute_percentage_error: 71.6260 - val_loss: 72.0247 - val_mean_absolute_percentage_error: 72.0247
# Epoch 3/100
# 14/14 [==============================] - 0s 15ms/step - loss: 70.3656 - mean_absolute_percentage_error: 70.3656 - val_loss: 65.5742 - val_mean_absolute_percentage_error: 65.5742
# Epoch 4/100
# 14/14 [==============================] - 0s 16ms/step - loss: 71.2029 - mean_absolute_percentage_error: 71.2029 - val_loss: 68.3900 - val_mean_absolute_percentage_error: 68.3900
# Epoch 5/100
# 14/14 [==============================] - 0s 15ms/step - loss: 70.0586 - mean_absolute_percentage_error: 70.0586 - val_loss: 65.3677 - val_mean_absolute_percentage_error: 65.3677
# Epoch 6/100
# 14/14 [==============================] - 0s 17ms/step - loss: 69.1695 - mean_absolute_percentage_error: 69.1695 - val_loss: 63.5132 - val_mean_absolute_percentage_error: 63.5132
# Epoch 7/100
# 14/14 [==============================] - 0s 13ms/step - loss: 76.5487 - mean_absolute_percentage_error: 76.5487 - val_loss: 64.2566 - val_mean_absolute_percentage_error: 64.2566
# Epoch 8/100
# 14/14 [==============================] - 0s 12ms/step - loss: 67.8269 - mean_absolute_percentage_error: 67.8269 - val_loss: 62.6122 - val_mean_absolute_percentage_error: 62.6122
# Epoch 9/100
# 14/14 [==============================] - 0s 11ms/step - loss: 67.5193 - mean_absolute_percentage_error: 67.5193 - val_loss: 57.6228 - val_mean_absolute_percentage_error: 57.6228
# Epoch 10/100
# 14/14 [==============================] - 0s 11ms/step - loss: 65.0559 - mean_absolute_percentage_error: 65.0559 - val_loss: 60.5374 - val_mean_absolute_percentage_error: 60.5374
# Epoch 11/100
# 14/14 [==============================] - 0s 11ms/step - loss: 62.2966 - mean_absolute_percentage_error: 62.2966 - val_loss: 59.0291 - val_mean_absolute_percentage_error: 59.0291
# Epoch 12/100
# 14/14 [==============================] - 0s 10ms/step - loss: 62.2577 - mean_absolute_percentage_error: 62.2577 - val_loss: 58.3057 - val_mean_absolute_percentage_error: 58.3057
# Epoch 13/100
# 14/14 [==============================] - 0s 12ms/step - loss: 59.7378 - mean_absolute_percentage_error: 59.7378 - val_loss: 58.7125 - val_mean_absolute_percentage_error: 58.7125
# Epoch 14/100
# 14/14 [==============================] - 0s 10ms/step - loss: 58.1040 - mean_absolute_percentage_error: 58.1040 - val_loss: 58.1550 - val_mean_absolute_percentage_error: 58.1550
# Epoch 15/100
# 14/14 [==============================] - 0s 10ms/step - loss: 57.8226 - mean_absolute_percentage_error: 57.8226 - val_loss: 60.0000 - val_mean_absolute_percentage_error: 60.0000
# Epoch 16/100
# 14/14 [==============================] - 0s 9ms/step - loss: 55.5980 - mean_absolute_percentage_error: 55.5980 - val_loss: 61.6923 - val_mean_absolute_percentage_error: 61.6923
# Epoch 17/100
# 14/14 [==============================] - 0s 10ms/step - loss: 51.9042 - mean_absolute_percentage_error: 51.9042 - val_loss: 76.9307 - val_mean_absolute_percentage_error: 76.9307
# Epoch 18/100
# 14/14 [==============================] - 0s 10ms/step - loss: 56.0696 - mean_absolute_percentage_error: 56.0696 - val_loss: 56.2200 - val_mean_absolute_percentage_error: 56.2200
# Epoch 19/100
# 14/14 [==============================] - 0s 10ms/step - loss: 49.9083 - mean_absolute_percentage_error: 49.9083 - val_loss: 53.6305 - val_mean_absolute_percentage_error: 53.6305
# Epoch 20/100
# 14/14 [==============================] - 0s 10ms/step - loss: 52.0654 - mean_absolute_percentage_error: 52.0654 - val_loss: 56.1032 - val_mean_absolute_percentage_error: 56.1032
# Epoch 21/100
# 14/14 [==============================] - 0s 10ms/step - loss: 49.5358 - mean_absolute_percentage_error: 49.5358 - val_loss: 57.7709 - val_mean_absolute_percentage_error: 57.7709
# Epoch 22/100
# 14/14 [==============================] - 0s 10ms/step - loss: 49.4072 - mean_absolute_percentage_error: 49.4072 - val_loss: 57.9842 - val_mean_absolute_percentage_error: 57.9842
# Epoch 23/100
# 14/14 [==============================] - 0s 10ms/step - loss: 46.4112 - mean_absolute_percentage_error: 46.4112 - val_loss: 53.8135 - val_mean_absolute_percentage_error: 53.8135
# Epoch 24/100
# 14/14 [==============================] - 0s 10ms/step - loss: 49.1681 - mean_absolute_percentage_error: 49.1681 - val_loss: 55.3912 - val_mean_absolute_percentage_error: 55.3912
# Epoch 25/100
# 14/14 [==============================] - 0s 10ms/step - loss: 47.1994 - mean_absolute_percentage_error: 47.1994 - val_loss: 54.6996 - val_mean_absolute_percentage_error: 54.6996
# Epoch 26/100
# 14/14 [==============================] - 0s 10ms/step - loss: 43.5550 - mean_absolute_percentage_error: 43.5550 - val_loss: 54.3309 - val_mean_absolute_percentage_error: 54.3309
# Epoch 27/100
# 14/14 [==============================] - 0s 11ms/step - loss: 44.6043 - mean_absolute_percentage_error: 44.6043 - val_loss: 57.8645 - val_mean_absolute_percentage_error: 57.8645
# Epoch 28/100
# 14/14 [==============================] - 0s 12ms/step - loss: 40.6450 - mean_absolute_percentage_error: 40.6450 - val_loss: 54.2471 - val_mean_absolute_percentage_error: 54.2471
# Epoch 29/100
# 14/14 [==============================] - 0s 11ms/step - loss: 42.0554 - mean_absolute_percentage_error: 42.0554 - val_loss: 56.1733 - val_mean_absolute_percentage_error: 56.1733
# Epoch 30/100
# Epoch 47/100
# 14/14 [==============================] - 0s 10ms/step - loss: 30.2223 - mean_absolute_percentage_error: 30.2223 - val_loss: 54.6687 - val_mean_absolute_percentage_error: 54.6687
# Epoch 48/100
# 14/14 [==============================] - 0s 13ms/step - loss: 29.6712 - mean_absolute_percentage_error: 29.6712 - val_loss: 61.6171 - val_mean_absolute_percentage_error: 61.6171
# Epoch 49/100
# 14/14 [==============================] - 0s 11ms/step - loss: 30.3526 - mean_absolute_percentage_error: 30.3526 - val_loss: 63.1959 - val_mean_absolute_percentage_error: 63.1959
# Epoch 50/100
# 14/14 [==============================] - 0s 11ms/step - loss: 27.7622 - mean_absolute_percentage_error: 27.7622 - val_loss: 62.1701 - val_mean_absolute_percentage_error: 62.1701
# Epoch 51/100
# 14/14 [==============================] - 0s 10ms/step - loss: 26.3334 - mean_absolute_percentage_error: 26.3334 - val_loss: 60.7390 - val_mean_absolute_percentage_error: 60.7390
# Epoch 52/100
# 14/14 [==============================] - 0s 13ms/step - loss: 25.2312 - mean_absolute_percentage_error: 25.2312 - val_loss: 55.9998 - val_mean_absolute_percentage_error: 55.9998
# Epoch 53/100
# 14/14 [==============================] - 0s 10ms/step - loss: 26.7156 - mean_absolute_percentage_error: 26.7156 - val_loss: 59.7973 - val_mean_absolute_percentage_error: 59.7973
# Epoch 54/100
# 14/14 [==============================] - 0s 11ms/step - loss: 26.1785 - mean_absolute_percentage_error: 26.1785 - val_loss: 65.3500 - val_mean_absolute_percentage_error: 65.3500
# Epoch 55/100
# 14/14 [==============================] - 0s 10ms/step - loss: 28.0373 - mean_absolute_percentage_error: 28.0373 - val_loss: 62.4986 - val_mean_absolute_percentage_error: 62.4986
# Epoch 56/100
# 14/14 [==============================] - 0s 10ms/step - loss: 26.1758 - mean_absolute_percentage_error: 26.1758 - val_loss: 55.5482 - val_mean_absolute_percentage_error: 55.5482
# Epoch 57/100
# 14/14 [==============================] - 0s 10ms/step - loss: 25.0284 - mean_absolute_percentage_error: 25.0284 - val_loss: 70.7353 - val_mean_absolute_percentage_error: 70.7353
# Epoch 58/100
# 14/14 [==============================] - 0s 13ms/step - loss: 25.8437 - mean_absolute_percentage_error: 25.8437 - val_loss: 66.6631 - val_mean_absolute_percentage_error: 66.6631
# Epoch 59/100
# 14/14 [==============================] - 0s 13ms/step - loss: 25.1524 - mean_absolute_percentage_error: 25.1524 - val_loss: 54.3911 - val_mean_absolute_percentage_error: 54.3911
# Epoch 60/100
# 14/14 [==============================] - 0s 13ms/step - loss: 24.7600 - mean_absolute_percentage_error: 24.7600 - val_loss: 53.8711 - val_mean_absolute_percentage_error: 53.8711
# Epoch 61/100
# 14/14 [==============================] - 0s 14ms/step - loss: 23.8649 - mean_absolute_percentage_error: 23.8649 - val_loss: 57.2623 - val_mean_absolute_percentage_error: 57.2623
# Epoch 62/100
# 14/14 [==============================] - 0s 13ms/step - loss: 22.4045 - mean_absolute_percentage_error: 22.4045 - val_loss: 61.1202 - val_mean_absolute_percentage_error: 61.1202
# Epoch 96/100
# 14/14 [==============================] - 0s 12ms/step - loss: 16.5955 - mean_absolute_percentage_error: 16.5955 - val_loss: 58.2539 - val_mean_absolute_percentage_error: 58.2539
# Epoch 97/100
# 14/14 [==============================] - 0s 10ms/step - loss: 16.7146 - mean_absolute_percentage_error: 16.7146 - val_loss: 54.0390 - val_mean_absolute_percentage_error: 54.0390
# Epoch 98/100
# 14/14 [==============================] - 0s 10ms/step - loss: 15.8695 - mean_absolute_percentage_error: 15.8695 - val_loss: 55.8887 - val_mean_absolute_percentage_error: 55.8887
# Epoch 99/100
# 14/14 [==============================] - 0s 10ms/step - loss: 16.6502 - mean_absolute_percentage_error: 16.6502 - val_loss: 58.7582 - val_mean_absolute_percentage_error: 58.7582
# Epoch 100/100
# 14/14 [==============================] - 0s 10ms/step - loss: 15.7359 - mean_absolute_percentage_error: 15.7359 - val_loss: 60.8259 - val_mean_absolute_percentage_error: 60.8259
# 4/4 [==============================] - 0s 4ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 60.83%

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
# model.add(Conv2D(64, (3,3), padding='same', input_shape=X_train.shape[1:]))
# model.add(Activation('relu'))
# model.add(MaxPooling2D(pool_size=(2,2)))

# input_shape=X_train.shape[1:]

# model.add(Flatten())
model.add(Dense(8, input_shape=X_train.shape[1:], activation='relu'))
# model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('relu'))
model.add(Flatten())

# model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)

# Extract training and validation loss from the history
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create a plot for training and validation loss vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(training_loss) + 1), training_loss, label='Training Loss')
plt.plot(range(1, len(validation_loss) + 1), validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# Model: "sequential_59"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_173 (Dense)           (None, 64, 64, 8)         32
#
#  dropout_73 (Dropout)        (None, 64, 64, 8)         0
#
#  dense_174 (Dense)           (None, 64, 64, 4)         36
#
#  activation_230 (Activation  (None, 64, 64, 4)         0
#  )
#
#  flatten_68 (Flatten)        (None, 16384)             0
#
#  dense_175 (Dense)           (None, 1)                 16385
#
#  activation_231 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 16453 (64.27 KB)
# Trainable params: 16453 (64.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 22ms/step - loss: 128.8386 - mean_absolute_percentage_error: 128.8386 - val_loss: 90.7917 - val_mean_absolute_percentage_error: 90.7917
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 108.1428 - mean_absolute_percentage_error: 108.1428 - val_loss: 97.7316 - val_mean_absolute_percentage_error: 97.7316
# Epoch 3/100
# 14/14 [==============================] - 0s 7ms/step - loss: 109.5658 - mean_absolute_percentage_error: 109.5658 - val_loss: 99.9916 - val_mean_absolute_percentage_error: 99.9916
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 92.1533 - mean_absolute_percentage_error: 92.1533 - val_loss: 99.1662 - val_mean_absolute_percentage_error: 99.1662
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 84.2813 - mean_absolute_percentage_error: 84.2813 - val_loss: 98.9201 - val_mean_absolute_percentage_error: 98.9201
# Epoch 6/100
# 14/14 [==============================] - 0s 7ms/step - loss:
# Epoch 87/100
# 14/14 [==============================] - 0s 11ms/step - loss: 32.6780 - mean_absolute_percentage_error: 32.6780 - val_loss: 74.9970 - val_mean_absolute_percentage_error: 74.9970
# Epoch 88/100
# 14/14 [==============================] - 0s 10ms/step - loss: 33.9578 - mean_absolute_percentage_error: 33.9578 - val_loss: 72.2187 - val_mean_absolute_percentage_error: 72.2187
# Epoch 89/100
# 14/14 [==============================] - 0s 11ms/step - loss: 36.1705 - mean_absolute_percentage_error: 36.1705 - val_loss: 75.4530 - val_mean_absolute_percentage_error: 75.4530
# Epoch 90/100
# 14/14 [==============================] - 0s 10ms/step - loss: 33.2292 - mean_absolute_percentage_error: 33.2292 - val_loss: 71.3784 - val_mean_absolute_percentage_error: 71.3784
# Epoch 91/100
# 14/14 [==============================] - 0s 10ms/step - loss: 32.0047 - mean_absolute_percentage_error: 32.0047 - val_loss: 73.5001 - val_mean_absolute_percentage_error: 73.5001
# Epoch 92/100
# 14/14 [==============================] - 0s 10ms/step - loss: 32.3456 - mean_absolute_percentage_error: 32.3456 - val_loss: 74.9637 - val_mean_absolute_percentage_error: 74.9637
# Epoch 93/100
# 14/14 [==============================] - 0s 11ms/step - loss: 33.1475 - mean_absolute_percentage_error: 33.1475 - val_loss: 74.6054 - val_mean_absolute_percentage_error: 74.6054
# Epoch 94/100
# 14/14 [==============================] - 0s 10ms/step - loss: 34.3007 - mean_absolute_percentage_error: 34.3007 - val_loss: 74.6306 - val_mean_absolute_percentage_error: 74.6306
# Epoch 95/100
# 14/14 [==============================] - 0s 11ms/step - loss: 32.8280 - mean_absolute_percentage_error: 32.8280 - val_loss: 70.4561 - val_mean_absolute_percentage_error: 70.4561
# Epoch 96/100
# 14/14 [==============================] - 0s 9ms/step - loss: 31.4355 - mean_absolute_percentage_error: 31.4355 - val_loss: 72.7761 - val_mean_absolute_percentage_error: 72.7761
# Epoch 97/100
# 14/14 [==============================] - 0s 11ms/step - loss: 32.6130 - mean_absolute_percentage_error: 32.6130 - val_loss: 73.4812 - val_mean_absolute_percentage_error: 73.4812
# Epoch 98/100
# 14/14 [==============================] - 0s 12ms/step - loss: 32.8103 - mean_absolute_percentage_error: 32.8103 - val_loss: 73.9914 - val_mean_absolute_percentage_error: 73.9914
# Epoch 99/100
# 14/14 [==============================] - 0s 10ms/step - loss: 33.5757 - mean_absolute_percentage_error: 33.5757 - val_loss: 73.2926 - val_mean_absolute_percentage_error: 73.2926
# Epoch 100/100
# 14/14 [==============================] - 0s 13ms/step - loss: 33.0833 - mean_absolute_percentage_error: 33.0833 - val_loss: 73.4028 - val_mean_absolute_percentage_error: 73.4028
# 4/4 [==============================] - 0s 5ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 73.40%

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
model.add(Dense(8, input_shape=X_train.shape[1:], activation='softmax'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('softmax'))


# model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)

# Extract training and validation loss from the history
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create a plot for training and validation loss vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(training_loss) + 1), training_loss, label='Training Loss')
plt.plot(range(1, len(validation_loss) + 1), validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# Model: "sequential_61"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_179 (Dense)           (None, 64, 64, 8)         32
#
#  flatten_70 (Flatten)        (None, 32768)             0
#
#  dropout_75 (Dropout)        (None, 32768)             0
#
#  dense_180 (Dense)           (None, 4)                 131076
#
#  activation_234 (Activation  (None, 4)                 0
#  )
#
#  dense_181 (Dense)           (None, 1)                 5
#
#  activation_235 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 131113 (512.16 KB)
# Trainable params: 131113 (512.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 19ms/step - loss: 201.3903 - mean_absolute_percentage_error: 201.3903 - val_loss: 104.8222 - val_mean_absolute_percentage_error: 104.8222
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 83.8172 - mean_absolute_percentage_error: 83.8172 - val_loss: 68.6764 - val_mean_absolute_percentage_error: 68.6764
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6546 - mean_absolute_percentage_error: 70.6546 - val_loss: 65.4700 - val_mean_absolute_percentage_error: 65.4700
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 71.3258 - mean_absolute_percentage_error: 71.3258 - val_loss: 66.4020 - val_mean_absolute_percentage_error: 66.4020
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6871 - mean_absolute_percentage_error: 70.6871 - val_loss: 68.5290 - val_mean_absolute_percentage_error: 68.5290
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3253 - mean_absolute_percentage_error: 70.3253 - val_loss: 69.8857 - val_mean_absolute_percentage_error: 69.8857
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3909 - mean_absolute_percentage_error: 70.3909 - val_loss: 69.8370 - val_mean_absolute_percentage_error: 69.8370
# Epoch 8/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2838 - mean_absolute_percentage_error: 70.2838 - val_loss: 68.2763 - val_mean_absolute_percentage_error: 68.2763
# Epoch 9/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2486 - mean_absolute_percentage_error: 70.2486 - val_loss: 69.8953 - val_mean_absolute_percentage_error: 69.8953
# Epoch 10/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2921 - mean_absolute_percentage_error: 70.2921 - val_loss: 69.4814 - val_mean_absolute_percentage_error: 69.4814
# Epoch 11/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2532 - mean_absolute_percentage_error: 70.2532 - val_loss: 69.3341 - val_mean_absolute_percentage_error: 69.3341
# Epoch 12/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2638 - mean_absolute_percentage_error: 70.2638 - val_loss: 68.1013 - val_mean_absolute_percentage_error: 68.1013
# Epoch 13/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2034 - mean_absolute_percentage_error: 70.2034 - val_loss: 69.5325 - val_mean_absolute_percentage_error: 69.5325
# Epoch 14/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3687 - mean_absolute_percentage_error: 70.3687 - val_loss: 69.8761 - val_mean_absolute_percentage_error: 69.8761
# Epoch 15/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2194 - mean_absolute_percentage_error: 70.2194 - val_loss: 68.2105 - val_mean_absolute_percentage_error: 68.2105
# Epoch 16/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3330 - mean_absolute_percentage_error: 70.3330 - val_loss: 68.7935 - val_mean_absolute_percentage_error: 68.7935
# Epoch 17/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2547 - mean_absolute_percentage_error: 70.2547 - val_loss: 69.5478 - val_mean_absolute_percentage_error: 69.5478
# Epoch 18/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2888 - mean_absolute_percentage_error: 70.2888 - val_loss: 68.7796 - val_mean_absolute_percentage_error: 68.7796
# Epoch 19/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5067 - mean_absolute_percentage_error: 70.5067 - val_loss: 69.4452 - val_mean_absolute_percentage_error: 69.4452
# Epoch 20/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.1916 - mean_absolute_percentage_error: 70.1916 - val_loss: 68.4612 - val_mean_absolute_percentage_error: 68.4612
# Epoch 21/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.5417 - mean_absolute_percentage_error: 70.5417 - val_loss: 67.6480 - val_mean_absolute_percentage_error: 67.6480
# Epoch 22/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5069 - mean_absolute_percentage_error: 70.5069 - val_loss: 69.5541 - val_mean_absolute_percentage_error: 69.5541
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2348 - mean_absolute_percentage_error: 70.2348 - val_loss: 69.1572 - val_mean_absolute_percentage_error: 69.1572
# Epoch 24/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2627 - mean_absolute_percentage_error: 70.2627 - val_loss: 68.6200 - val_mean_absolute_percentage_error: 68.6200
# Epoch 25/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6830 - mean_absolute_percentage_error: 70.6830 - val_loss: 67.8540 - val_mean_absolute_percentage_error: 67.8540
# Epoch 26/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3413 - mean_absolute_percentage_error: 70.3413 - val_loss: 71.7661 - val_mean_absolute_percentage_error: 71.7661
# Epoch 27/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5405 - mean_absolute_percentage_error: 70.5405 - val_loss: 69.7679 - val_mean_absolute_percentage_error: 69.7679
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3174 - mean_absolute_percentage_error: 70.3174 - val_loss: 67.1214 - val_mean_absolute_percentage_error: 67.1214
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5846 - mean_absolute_percentage_error: 70.5846 - val_loss: 69.0155 - val_mean_absolute_percentage_error: 69.0155
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2790 - mean_absolute_percentage_error: 70.2790 - val_loss: 69.8878 - val_mean_absolute_percentage_error: 69.8878
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2810 - mean_absolute_percentage_error: 70.2810 - val_loss: 68.9810 - val_mean_absolute_percentage_error: 68.9810
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2789 - mean_absolute_percentage_error: 70.2789 - val_loss: 68.6654 - val_mean_absolute_percentage_error: 68.6654
# Epoch 33/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3990 - mean_absolute_percentage_error: 70.3990 - val_loss: 69.3186 - val_mean_absolute_percentage_error: 69.3186
# Epoch 34/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4436 - mean_absolute_percentage_error: 70.4436 - val_loss: 68.2919 - val_mean_absolute_percentage_error: 68.2919
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4572 - mean_absolute_percentage_error: 70.4572 - val_loss: 70.3127 - val_mean_absolute_percentage_error: 70.3127
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3010 - mean_absolute_percentage_error: 70.3010 - val_loss: 69.0376 - val_mean_absolute_percentage_error: 69.0376
# Epoch 37/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4212 - mean_absolute_percentage_error: 70.4212 - val_loss: 68.5739 - val_mean_absolute_percentage_error: 68.5739
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3110 - mean_absolute_percentage_error: 70.3110 - val_loss: 69.7904 - val_mean_absolute_percentage_error: 69.7904
# Epoch 39/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4431 - mean_absolute_percentage_error: 70.4431 - val_loss: 69.6480 - val_mean_absolute_percentage_error: 69.6480
# Epoch 40/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.6997 - mean_absolute_percentage_error: 70.6997 - val_loss: 68.3471 - val_mean_absolute_percentage_error: 68.3471
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 71.3005 - mean_absolute_percentage_error: 71.3005 - val_loss: 71.8953 - val_mean_absolute_percentage_error: 71.8953
# Epoch 42/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5563 - mean_absolute_percentage_error: 70.5563 - val_loss: 66.8245 - val_mean_absolute_percentage_error: 66.8245
# Epoch 43/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.5668 - mean_absolute_percentage_error: 70.5668 - val_loss: 68.2953 - val_mean_absolute_percentage_error: 68.2953
# Epoch 44/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3400 - mean_absolute_percentage_error: 70.3400 - val_loss: 69.7935 - val_mean_absolute_percentage_error: 69.7935
# Epoch 45/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.7668 - mean_absolute_percentage_error: 70.7668 - val_loss: 70.8641 - val_mean_absolute_percentage_error: 70.8641
# Epoch 46/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4161 - mean_absolute_percentage_error: 70.4161 - val_loss: 68.0657 - val_mean_absolute_percentage_error: 68.0657
# Epoch 47/100
# 14/14 [==============================] - 0s 14ms/step - loss: 70.2941 - mean_absolute_percentage_error: 70.2941 - val_loss: 69.3314 - val_mean_absolute_percentage_error: 69.3314
# Epoch 48/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2602 - mean_absolute_percentage_error: 70.2602 - val_loss: 70.7773 - val_mean_absolute_percentage_error: 70.7773
# Epoch 49/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.8452 - mean_absolute_percentage_error: 70.8452 - val_loss: 69.0070 - val_mean_absolute_percentage_error: 69.0070
# Epoch 50/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.4095 - mean_absolute_percentage_error: 70.4095 - val_loss: 70.0553 - val_mean_absolute_percentage_error: 70.0553
# Epoch 51/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.4235 - mean_absolute_percentage_error: 70.4235 - val_loss: 69.8727 - val_mean_absolute_percentage_error: 69.8727
# Epoch 52/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2636 - mean_absolute_percentage_error: 70.2636 - val_loss: 68.8690 - val_mean_absolute_percentage_error: 68.8690
# Epoch 53/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.7318 - mean_absolute_percentage_error: 70.7318 - val_loss: 67.9642 - val_mean_absolute_percentage_error: 67.9642
# Epoch 54/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.4929 - mean_absolute_percentage_error: 70.4929 - val_loss: 70.6174 - val_mean_absolute_percentage_error: 70.6174
# Epoch 55/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3862 - mean_absolute_percentage_error: 70.3862 - val_loss: 69.3238 - val_mean_absolute_percentage_error: 69.3238
# Epoch 56/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.3178 - mean_absolute_percentage_error: 70.3178 - val_loss: 68.1433 - val_mean_absolute_percentage_error: 68.1433
# Epoch 57/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4705 - mean_absolute_percentage_error: 70.4705 - val_loss: 68.9712 - val_mean_absolute_percentage_error: 68.9712
# Epoch 58/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3395 - mean_absolute_percentage_error: 70.3395 - val_loss: 68.6589 - val_mean_absolute_percentage_error: 68.6589
# Epoch 59/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2998 - mean_absolute_percentage_error: 70.2998 - val_loss: 69.7695 - val_mean_absolute_percentage_error: 69.7695
# Epoch 60/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2484 - mean_absolute_percentage_error: 70.2484 - val_loss: 69.3282 - val_mean_absolute_percentage_error: 69.3282
# Epoch 61/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2835 - mean_absolute_percentage_error: 70.2835 - val_loss: 68.6658 - val_mean_absolute_percentage_error: 68.6658
# Epoch 62/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4228 - mean_absolute_percentage_error: 70.4228 - val_loss: 70.2537 - val_mean_absolute_percentage_error: 70.2537
# Epoch 63/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3481 - mean_absolute_percentage_error: 70.3481 - val_loss: 68.8295 - val_mean_absolute_percentage_error: 68.8295
# Epoch 64/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.3393 - mean_absolute_percentage_error: 70.3393 - val_loss: 69.9094 - val_mean_absolute_percentage_error: 69.9094
# Epoch 65/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2521 - mean_absolute_percentage_error: 70.2521 - val_loss: 68.1618 - val_mean_absolute_percentage_error: 68.1618
# Epoch 66/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4142 - mean_absolute_percentage_error: 70.4142 - val_loss: 68.6753 - val_mean_absolute_percentage_error: 68.6753
# Epoch 67/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4528 - mean_absolute_percentage_error: 70.4528 - val_loss: 70.1710 - val_mean_absolute_percentage_error: 70.1710
# Epoch 68/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.3199 - mean_absolute_percentage_error: 70.3199 - val_loss: 69.3142 - val_mean_absolute_percentage_error: 69.3142
# Epoch 69/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3573 - mean_absolute_percentage_error: 70.3573 - val_loss: 69.4243 - val_mean_absolute_percentage_error: 69.4243
# Epoch 70/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.6568 - mean_absolute_percentage_error: 70.6568 - val_loss: 69.6437 - val_mean_absolute_percentage_error: 69.6437
# Epoch 71/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3050 - mean_absolute_percentage_error: 70.3050 - val_loss: 69.3934 - val_mean_absolute_percentage_error: 69.3934
# Epoch 72/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4645 - mean_absolute_percentage_error: 70.4645 - val_loss: 69.3824 - val_mean_absolute_percentage_error: 69.3824
# Epoch 73/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.5072 - mean_absolute_percentage_error: 70.5072 - val_loss: 68.2718 - val_mean_absolute_percentage_error: 68.2718
# Epoch 74/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.5519 - mean_absolute_percentage_error: 70.5519 - val_loss: 69.7742 - val_mean_absolute_percentage_error: 69.7742
# Epoch 75/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.2230 - mean_absolute_percentage_error: 70.2230 - val_loss: 68.9150 - val_mean_absolute_percentage_error: 68.9150
# Epoch 76/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.9354 - mean_absolute_percentage_error: 70.9354 - val_loss: 67.8143 - val_mean_absolute_percentage_error: 67.8143
# Epoch 77/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4988 - mean_absolute_percentage_error: 70.4988 - val_loss: 70.3126 - val_mean_absolute_percentage_error: 70.3126
# Epoch 78/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.8848 - mean_absolute_percentage_error: 70.8848 - val_loss: 68.5481 - val_mean_absolute_percentage_error: 68.5481
# Epoch 79/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5531 - mean_absolute_percentage_error: 70.5531 - val_loss: 69.6779 - val_mean_absolute_percentage_error: 69.6779
# Epoch 80/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2916 - mean_absolute_percentage_error: 70.2916 - val_loss: 69.0998 - val_mean_absolute_percentage_error: 69.0998
# Epoch 81/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2976 - mean_absolute_percentage_error: 70.2976 - val_loss: 69.4220 - val_mean_absolute_percentage_error: 69.4220
# Epoch 82/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5244 - mean_absolute_percentage_error: 70.5244 - val_loss: 69.2698 - val_mean_absolute_percentage_error: 69.2698
# Epoch 83/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3128 - mean_absolute_percentage_error: 70.3128 - val_loss: 69.2071 - val_mean_absolute_percentage_error: 69.2071
# Epoch 84/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3884 - mean_absolute_percentage_error: 70.3884 - val_loss: 68.5366 - val_mean_absolute_percentage_error: 68.5366
# Epoch 85/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3015 - mean_absolute_percentage_error: 70.3015 - val_loss: 69.0318 - val_mean_absolute_percentage_error: 69.0318
# Epoch 86/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2696 - mean_absolute_percentage_error: 70.2696 - val_loss: 69.2749 - val_mean_absolute_percentage_error: 69.2749
# Epoch 87/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3370 - mean_absolute_percentage_error: 70.3370 - val_loss: 68.7429 - val_mean_absolute_percentage_error: 68.7429
# Epoch 88/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2786 - mean_absolute_percentage_error: 70.2786 - val_loss: 69.9772 - val_mean_absolute_percentage_error: 69.9772
# Epoch 89/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4739 - mean_absolute_percentage_error: 70.4739 - val_loss: 70.1924 - val_mean_absolute_percentage_error: 70.1924
# Epoch 90/100
# 14/14 [==============================] - 0s 7ms/step - loss: 71.3234 - mean_absolute_percentage_error: 71.3234 - val_loss: 66.9534 - val_mean_absolute_percentage_error: 66.9534
# Epoch 91/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3222 - mean_absolute_percentage_error: 70.3222 - val_loss: 70.6602 - val_mean_absolute_percentage_error: 70.6602
# Epoch 92/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.6154 - mean_absolute_percentage_error: 70.6154 - val_loss: 69.4400 - val_mean_absolute_percentage_error: 69.4400
# Epoch 93/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5948 - mean_absolute_percentage_error: 70.5948 - val_loss: 66.3612 - val_mean_absolute_percentage_error: 66.3612
# Epoch 94/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5763 - mean_absolute_percentage_error: 70.5763 - val_loss: 68.2975 - val_mean_absolute_percentage_error: 68.2975
# Epoch 95/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6321 - mean_absolute_percentage_error: 70.6321 - val_loss: 72.0375 - val_mean_absolute_percentage_error: 72.0375
# Epoch 96/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3638 - mean_absolute_percentage_error: 70.3638 - val_loss: 69.0161 - val_mean_absolute_percentage_error: 69.0161
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.7265 - mean_absolute_percentage_error: 70.7265 - val_loss: 69.0001 - val_mean_absolute_percentage_error: 69.0001
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2357 - mean_absolute_percentage_error: 70.2357 - val_loss: 71.2188 - val_mean_absolute_percentage_error: 71.2188
# Epoch 99/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5101 - mean_absolute_percentage_error: 70.5101 - val_loss: 67.9964 - val_mean_absolute_percentage_error: 67.9964
# Epoch 100/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2957 - mean_absolute_percentage_error: 70.2957 - val_loss: 68.9241 - val_mean_absolute_percentage_error: 68.9241
# 4/4 [==============================] - 0s 3ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 68.92%

# %%
# 68
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.python.keras.utils import np_utils
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
tf.random.set_seed(1234)

chanDim = -1
model = Sequential()

# . . .
model.add(Dense(8, input_shape=X_train.shape[1:], activation='softmax'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('softmax'))


# model.add(Flatten())
model.add(Dense(1))
model.add(Activation('linear'))

# . . .

model.summary()
opt = tf.optimizers.legacy.Adam(lr=1e-3, decay=1e-3 / 200)
model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# train the model
print("[INFO] training model...")
history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)

# Extract training and validation loss from the history
training_loss = history.history['loss']
validation_loss = history.history['val_loss']

# Create a plot for training and validation loss vs. epochs
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(training_loss) + 1), training_loss, label='Training Loss')
plt.plot(range(1, len(validation_loss) + 1), validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

prices_predicted = model.predict(X_val).flatten()
print(prices_predicted.shape)
print(Y_val.shape)
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
# Out:
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_191 (Dense)           (None, 64, 64, 8)         32
#
#  flatten_74 (Flatten)        (None, 32768)             0
#
#  dropout_79 (Dropout)        (None, 32768)             0
#
#  dense_192 (Dense)           (None, 4)                 131076
#
#  activation_242 (Activation  (None, 4)                 0
#  )
#
#  dense_193 (Dense)           (None, 1)                 5
#
#  activation_243 (Activation  (None, 1)                 0
#  )
#
# =================================================================
# Total params: 131113 (512.16 KB)
# Trainable params: 131113 (512.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# [INFO] training model...
# Epoch 1/100
# 14/14 [==============================] - 1s 21ms/step - loss: 308.0281 - mean_absolute_percentage_error: 308.0281 - val_loss: 150.1691 - val_mean_absolute_percentage_error: 150.1691
# Epoch 2/100
# 14/14 [==============================] - 0s 9ms/step - loss: 178.8221 - mean_absolute_percentage_error: 178.8221 - val_loss: 109.3221 - val_mean_absolute_percentage_error: 109.3221
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 133.8381 - mean_absolute_percentage_error: 133.8381 - val_loss: 83.0790 - val_mean_absolute_percentage_error: 83.0790
# Epoch 4/100
# 14/14 [==============================] - 0s 8ms/step - loss: 103.4897 - mean_absolute_percentage_error: 103.4897 - val_loss: 70.9052 - val_mean_absolute_percentage_error: 70.9052
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 85.2894 - mean_absolute_percentage_error: 85.2894 - val_loss: 64.8558 - val_mean_absolute_percentage_error: 64.8558
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 74.3925 - mean_absolute_percentage_error: 74.3925 - val_loss: 65.7491 - val_mean_absolute_percentage_error: 65.7491
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.9722 - mean_absolute_percentage_error: 70.9722 - val_loss: 70.4406 - val_mean_absolute_percentage_error: 70.4406
# Epoch 8/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2979 - mean_absolute_percentage_error: 70.2979 - val_loss: 69.3176 - val_mean_absolute_percentage_error: 69.3176
# Epoch 9/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2452 - mean_absolute_percentage_error: 70.2452 - val_loss: 69.8570 - val_mean_absolute_percentage_error: 69.8570
# Epoch 10/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2948 - mean_absolute_percentage_error: 70.2948 - val_loss: 69.5613 - val_mean_absolute_percentage_error: 69.5613
# Epoch 11/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2679 - mean_absolute_percentage_error: 70.2679 - val_loss: 69.6508 - val_mean_absolute_percentage_error: 69.6508
# Epoch 12/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2629 - mean_absolute_percentage_error: 70.2629 - val_loss: 68.3323 - val_mean_absolute_percentage_error: 68.3323
# Epoch 13/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.2382 - mean_absolute_percentage_error: 70.2382 - val_loss: 69.2084 - val_mean_absolute_percentage_error: 69.2084
# Epoch 14/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3250 - mean_absolute_percentage_error: 70.3250 - val_loss: 69.7808 - val_mean_absolute_percentage_error: 69.7808
# Epoch 15/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2175 - mean_absolute_percentage_error: 70.2175 - val_loss: 68.3871 - val_mean_absolute_percentage_error: 68.3871
# Epoch 16/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3087 - mean_absolute_percentage_error: 70.3087 - val_loss: 68.6876 - val_mean_absolute_percentage_error: 68.6876
# Epoch 17/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2667 - mean_absolute_percentage_error: 70.2667 - val_loss: 69.5827 - val_mean_absolute_percentage_error: 69.5827
# Epoch 18/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2616 - mean_absolute_percentage_error: 70.2616 - val_loss: 69.2692 - val_mean_absolute_percentage_error: 69.2692
# Epoch 19/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.4526 - mean_absolute_percentage_error: 70.4526 - val_loss: 69.4808 - val_mean_absolute_percentage_error: 69.4808
# Epoch 20/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.1674 - mean_absolute_percentage_error: 70.1674 - val_loss: 68.3274 - val_mean_absolute_percentage_error: 68.3274
# Epoch 21/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5335 - mean_absolute_percentage_error: 70.5335 - val_loss: 67.5640 - val_mean_absolute_percentage_error: 67.5640
# Epoch 22/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.5137 - mean_absolute_percentage_error: 70.5137 - val_loss: 69.4416 - val_mean_absolute_percentage_error: 69.4416
# Epoch 23/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2377 - mean_absolute_percentage_error: 70.2377 - val_loss: 69.2327 - val_mean_absolute_percentage_error: 69.2327
# Epoch 24/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2514 - mean_absolute_percentage_error: 70.2514 - val_loss: 68.5433 - val_mean_absolute_percentage_error: 68.5433
# Epoch 25/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6074 - mean_absolute_percentage_error: 70.6074 - val_loss: 67.9989 - val_mean_absolute_percentage_error: 67.9989
# Epoch 26/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3197 - mean_absolute_percentage_error: 70.3197 - val_loss: 71.2856 - val_mean_absolute_percentage_error: 71.2856
# Epoch 27/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4184 - mean_absolute_percentage_error: 70.4184 - val_loss: 69.7920 - val_mean_absolute_percentage_error: 69.7920
# Epoch 28/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2787 - mean_absolute_percentage_error: 70.2787 - val_loss: 67.6262 - val_mean_absolute_percentage_error: 67.6262
# Epoch 29/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4453 - mean_absolute_percentage_error: 70.4453 - val_loss: 69.1384 - val_mean_absolute_percentage_error: 69.1384
# Epoch 30/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2839 - mean_absolute_percentage_error: 70.2839 - val_loss: 70.0772 - val_mean_absolute_percentage_error: 70.0772
# Epoch 31/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2801 - mean_absolute_percentage_error: 70.2801 - val_loss: 68.9139 - val_mean_absolute_percentage_error: 68.9139
# Epoch 32/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2775 - mean_absolute_percentage_error: 70.2775 - val_loss: 68.4907 - val_mean_absolute_percentage_error: 68.4907
# Epoch 33/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3964 - mean_absolute_percentage_error: 70.3964 - val_loss: 69.1563 - val_mean_absolute_percentage_error: 69.1563
# Epoch 34/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4283 - mean_absolute_percentage_error: 70.4283 - val_loss: 68.3387 - val_mean_absolute_percentage_error: 68.3387
# Epoch 35/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4233 - mean_absolute_percentage_error: 70.4233 - val_loss: 70.1217 - val_mean_absolute_percentage_error: 70.1217
# Epoch 36/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3054 - mean_absolute_percentage_error: 70.3054 - val_loss: 69.2830 - val_mean_absolute_percentage_error: 69.2830
# Epoch 37/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.3978 - mean_absolute_percentage_error: 70.3978 - val_loss: 68.6861 - val_mean_absolute_percentage_error: 68.6861
# Epoch 38/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3020 - mean_absolute_percentage_error: 70.3020 - val_loss: 69.7037 - val_mean_absolute_percentage_error: 69.7037
# Epoch 39/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4240 - mean_absolute_percentage_error: 70.4240 - val_loss: 69.5460 - val_mean_absolute_percentage_error: 69.5460
# Epoch 40/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.6726 - mean_absolute_percentage_error: 70.6726 - val_loss: 68.3318 - val_mean_absolute_percentage_error: 68.3318
# Epoch 41/100
# 14/14 [==============================] - 0s 8ms/step - loss: 71.3513 - mean_absolute_percentage_error: 71.3513 - val_loss: 72.3409 - val_mean_absolute_percentage_error: 72.3409
# Epoch 42/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4895 - mean_absolute_percentage_error: 70.4895 - val_loss: 67.7199 - val_mean_absolute_percentage_error: 67.7199
# Epoch 43/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3687 - mean_absolute_percentage_error: 70.3687 - val_loss: 68.8579 - val_mean_absolute_percentage_error: 68.8579
# Epoch 44/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3491 - mean_absolute_percentage_error: 70.3491 - val_loss: 69.7503 - val_mean_absolute_percentage_error: 69.7503
# Epoch 45/100
# 14/14 [==============================] - 0s 7ms/step - loss: 70.7655 - mean_absolute_percentage_error: 70.7655 - val_loss: 70.9965 - val_mean_absolute_percentage_error: 70.9965
# Epoch 46/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4220 - mean_absolute_percentage_error: 70.4220 - val_loss: 68.0284 - val_mean_absolute_percentage_error: 68.0284
# Epoch 47/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3211 - mean_absolute_percentage_error: 70.3211 - val_loss: 69.1361 - val_mean_absolute_percentage_error: 69.1361
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2304 - mean_absolute_percentage_error: 70.2304 - val_loss: 70.7630 - val_mean_absolute_percentage_error: 70.7630
# Epoch 49/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.7776 - mean_absolute_percentage_error: 70.7776 - val_loss: 69.2752 - val_mean_absolute_percentage_error: 69.2752
# Epoch 50/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4198 - mean_absolute_percentage_error: 70.4198 - val_loss: 70.0379 - val_mean_absolute_percentage_error: 70.0379
# Epoch 51/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4102 - mean_absolute_percentage_error: 70.4102 - val_loss: 69.8255 - val_mean_absolute_percentage_error: 69.8255
# Epoch 52/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3592 - mean_absolute_percentage_error: 70.3592 - val_loss: 69.3688 - val_mean_absolute_percentage_error: 69.3688
# Epoch 53/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.8281 - mean_absolute_percentage_error: 70.8281 - val_loss: 67.6341 - val_mean_absolute_percentage_error: 67.6341
# Epoch 54/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5403 - mean_absolute_percentage_error: 70.5403 - val_loss: 70.3406 - val_mean_absolute_percentage_error: 70.3406
# Epoch 55/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.4769 - mean_absolute_percentage_error: 70.4769 - val_loss: 69.6519 - val_mean_absolute_percentage_error: 69.6519
# Epoch 56/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3485 - mean_absolute_percentage_error: 70.3485 - val_loss: 67.8570 - val_mean_absolute_percentage_error: 67.8570
# Epoch 57/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4895 - mean_absolute_percentage_error: 70.4895 - val_loss: 68.9441 - val_mean_absolute_percentage_error: 68.9441
# Epoch 58/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3323 - mean_absolute_percentage_error: 70.3323 - val_loss: 68.7579 - val_mean_absolute_percentage_error: 68.7579
# Epoch 59/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.4056 - mean_absolute_percentage_error: 70.4056 - val_loss: 69.4580 - val_mean_absolute_percentage_error: 69.4580
# Epoch 60/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2909 - mean_absolute_percentage_error: 70.2909 - val_loss: 69.4774 - val_mean_absolute_percentage_error: 69.4774
# Epoch 61/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2728 - mean_absolute_percentage_error: 70.2728 - val_loss: 68.6618 - val_mean_absolute_percentage_error: 68.6618
# Epoch 62/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4050 - mean_absolute_percentage_error: 70.4050 - val_loss: 70.1361 - val_mean_absolute_percentage_error: 70.1361
# Epoch 63/100
# 14/14 [==============================] - 0s 13ms/step - loss: 70.3477 - mean_absolute_percentage_error: 70.3477 - val_loss: 68.7666 - val_mean_absolute_percentage_error: 68.7666
# Epoch 64/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3724 - mean_absolute_percentage_error: 70.3724 - val_loss: 70.2128 - val_mean_absolute_percentage_error: 70.2128
# Epoch 65/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2543 - mean_absolute_percentage_error: 70.2543 - val_loss: 68.3268 - val_mean_absolute_percentage_error: 68.3268
# Epoch 66/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3983 - mean_absolute_percentage_error: 70.3983 - val_loss: 68.6832 - val_mean_absolute_percentage_error: 68.6832
# Epoch 67/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4250 - mean_absolute_percentage_error: 70.4250 - val_loss: 70.2649 - val_mean_absolute_percentage_error: 70.2649
# Epoch 68/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3250 - mean_absolute_percentage_error: 70.3250 - val_loss: 69.0871 - val_mean_absolute_percentage_error: 69.0871
# Epoch 69/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3165 - mean_absolute_percentage_error: 70.3165 - val_loss: 69.2973 - val_mean_absolute_percentage_error: 69.2973
# Epoch 70/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.6771 - mean_absolute_percentage_error: 70.6771 - val_loss: 70.0169 - val_mean_absolute_percentage_error: 70.0169
# Epoch 71/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3397 - mean_absolute_percentage_error: 70.3397 - val_loss: 69.6852 - val_mean_absolute_percentage_error: 69.6852
# Epoch 72/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4430 - mean_absolute_percentage_error: 70.4430 - val_loss: 69.4519 - val_mean_absolute_percentage_error: 69.4519
# Epoch 73/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.5319 - mean_absolute_percentage_error: 70.5319 - val_loss: 68.0428 - val_mean_absolute_percentage_error: 68.0428
# Epoch 74/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.5611 - mean_absolute_percentage_error: 70.5611 - val_loss: 69.8429 - val_mean_absolute_percentage_error: 69.8429
# Epoch 75/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2353 - mean_absolute_percentage_error: 70.2353 - val_loss: 69.0860 - val_mean_absolute_percentage_error: 69.0860
# Epoch 76/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.8945 - mean_absolute_percentage_error: 70.8945 - val_loss: 67.8988 - val_mean_absolute_percentage_error: 67.8988
# Epoch 77/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4922 - mean_absolute_percentage_error: 70.4922 - val_loss: 70.3371 - val_mean_absolute_percentage_error: 70.3371
# Epoch 78/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.8657 - mean_absolute_percentage_error: 70.8657 - val_loss: 68.6081 - val_mean_absolute_percentage_error: 68.6081
# Epoch 79/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.5478 - mean_absolute_percentage_error: 70.5478 - val_loss: 69.7095 - val_mean_absolute_percentage_error: 69.7095
# Epoch 80/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2921 - mean_absolute_percentage_error: 70.2921 - val_loss: 69.1447 - val_mean_absolute_percentage_error: 69.1447
# Epoch 81/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2990 - mean_absolute_percentage_error: 70.2990 - val_loss: 69.4593 - val_mean_absolute_percentage_error: 69.4593
# Epoch 82/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.5165 - mean_absolute_percentage_error: 70.5165 - val_loss: 69.3110 - val_mean_absolute_percentage_error: 69.3110
# Epoch 83/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3101 - mean_absolute_percentage_error: 70.3101 - val_loss: 69.2497 - val_mean_absolute_percentage_error: 69.2497
# Epoch 84/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3841 - mean_absolute_percentage_error: 70.3841 - val_loss: 68.5938 - val_mean_absolute_percentage_error: 68.5938
# Epoch 85/100
# 14/14 [==============================] - 0s 12ms/step - loss: 70.2767 - mean_absolute_percentage_error: 70.2767 - val_loss: 68.6932 - val_mean_absolute_percentage_error: 68.6932
# Epoch 86/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.2747 - mean_absolute_percentage_error: 70.2747 - val_loss: 68.8138 - val_mean_absolute_percentage_error: 68.8138
# Epoch 87/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.3504 - mean_absolute_percentage_error: 70.3504 - val_loss: 68.6697 - val_mean_absolute_percentage_error: 68.6697
# Epoch 88/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2718 - mean_absolute_percentage_error: 70.2718 - val_loss: 69.9788 - val_mean_absolute_percentage_error: 69.9788
# Epoch 89/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.4729 - mean_absolute_percentage_error: 70.4729 - val_loss: 70.2151 - val_mean_absolute_percentage_error: 70.2151
# Epoch 90/100
# 14/14 [==============================] - 0s 10ms/step - loss: 71.2884 - mean_absolute_percentage_error: 71.2884 - val_loss: 67.0299 - val_mean_absolute_percentage_error: 67.0299
# Epoch 91/100
# 14/14 [==============================] - 0s 10ms/step - loss: 70.3151 - mean_absolute_percentage_error: 70.3151 - val_loss: 70.6826 - val_mean_absolute_percentage_error: 70.6826
# Epoch 92/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.6167 - mean_absolute_percentage_error: 70.6167 - val_loss: 69.4821 - val_mean_absolute_percentage_error: 69.4821
# Epoch 93/100
# 14/14 [==============================] - 0s 11ms/step - loss: 70.6272 - mean_absolute_percentage_error: 70.6272 - val_loss: 66.1630 - val_mean_absolute_percentage_error: 66.1630
# Epoch 94/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.6524 - mean_absolute_percentage_error: 70.6524 - val_loss: 68.1483 - val_mean_absolute_percentage_error: 68.1483
# Epoch 95/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5785 - mean_absolute_percentage_error: 70.5785 - val_loss: 71.8876 - val_mean_absolute_percentage_error: 71.8876
# Epoch 96/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.3526 - mean_absolute_percentage_error: 70.3526 - val_loss: 68.9607 - val_mean_absolute_percentage_error: 68.9607
# Epoch 97/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.7250 - mean_absolute_percentage_error: 70.7250 - val_loss: 68.9516 - val_mean_absolute_percentage_error: 68.9516
# Epoch 98/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.2689 - mean_absolute_percentage_error: 70.2689 - val_loss: 71.8631 - val_mean_absolute_percentage_error: 71.8631
# Epoch 99/100
# 14/14 [==============================] - 0s 8ms/step - loss: 70.5665 - mean_absolute_percentage_error: 70.5665 - val_loss: 68.4058 - val_mean_absolute_percentage_error: 68.4058
# Epoch 100/100
# 14/14 [==============================] - 0s 9ms/step - loss: 70.2726 - mean_absolute_percentage_error: 70.2726 - val_loss: 68.9534 - val_mean_absolute_percentage_error: 68.9534
# 4/4 [==============================] - 0s 3ms/step
# (106,)
# (106,)
# Predicting house prices - Estimation Error: 68.95%

# %%
# Data from the updated table
models = [
    'Only-fully-connection',
    'Single-convolution',
    'Multi-convolution',
    'Multi-activation-changing',
    'best-performed'
]
accuracy = [0.4749, 0.5615, 0.689, 0.699, 0.70]

# Plotting the bar graph for accuracy
plt.figure(figsize=(5,5))
plt.bar(models, accuracy, color='b', alpha=0.6)

# Title and labels
plt.title('Accuracy of Different Models')
plt.ylabel('Accuracy (%)')
plt.xlabel('Model')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Add the actual value on top of each bar
for i, acc in enumerate(accuracy):
    plt.text(i, acc, f"{acc}%", ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Data from the updated table
models = [
    'Only-fully-connection',
    'Single-convolution',
    'Multi-convolution',
    'Multi-activation-changing',
    'best-performed'
]
Loss = [1.47, 1.249, 1.322, 1.34, 1.178]

plt.figure(figsize=(5,5))
plt.bar(models, Loss, color='b', alpha=0.6)

plt.title('validation loss of Different Models')
plt.ylabel('loss')
plt.xlabel('Model')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)
e:\master-2\DL\DL_code\CNN_results.txt
# Add the actual value on top of each bar
for i, loss in enumerate(Loss):
    plt.text(i, loss, f"{loss}%", ha='center', va='bottom')

# Show the plot
plt.tight_layout()
plt.show()
